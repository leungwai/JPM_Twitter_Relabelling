# %% [markdown]
# Leung Wai Liu <br>
# JPMorgan AI Research <br>
# August 9, 2022 <br>
# Manual Annotation Prep

# %%
import pandas as pd

# %%
train_label_dataset = pd.read_csv('logs/TRAIN_relabelled_data_spacy_pass_entire_sentence_no_break_apart.tsv', sep='\t')
train_label_dataset
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0      poutine                11              11  ['PROPN']        ['NOUN']
# 1       friday                 7               7  ['PROPN']       ['PROPN']
# 2     @user444                17              17  ['PROPN']           ['X']
# 3    @user1598                 1               1  ['PROPN']       ['PROPN']
# 4       gospel                 7               7  ['PROPN']       ['PROPN']
# ..         ...               ...             ...        ...             ...
# 966    @user70                 3               3  ['PROPN']       ['PROPN']
# 967   @user660                 5               5  ['PROPN']           ['X']
# 968  @user2046                 0               0  ['PROPN']           ['X']
# 969  @user2242                20              20  ['PROPN']           ['X']
# 970   @user317                 0               0  ['PROPN']       ['PROPN']
#
# ...

# %%
train_single_phrase_dataset = train_label_dataset.drop(train_label_dataset[train_label_dataset['Start Word Index'] != train_label_dataset['End Word Index']].index)
train_single_phrase_dataset
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0      poutine                11              11  ['PROPN']        ['NOUN']
# 1       friday                 7               7  ['PROPN']       ['PROPN']
# 2     @user444                17              17  ['PROPN']           ['X']
# 3    @user1598                 1               1  ['PROPN']       ['PROPN']
# 4       gospel                 7               7  ['PROPN']       ['PROPN']
# ..         ...               ...             ...        ...             ...
# 966    @user70                 3               3  ['PROPN']       ['PROPN']
# 967   @user660                 5               5  ['PROPN']           ['X']
# 968  @user2046                 0               0  ['PROPN']           ['X']
# 969  @user2242                20              20  ['PROPN']           ['X']
# 970   @user317                 0               0  ['PROPN']       ['PROPN']
#
# ...

# %%
train_single_phrase_dataset.to_csv('logs/TRAIN_SINGLE_twitter_label.tsv', sep='\t', index=False)

# %%
train_multiple_phrase_dataset = train_label_dataset.drop(train_label_dataset[train_label_dataset['Start Word Index'] == train_label_dataset['End Word Index']].index)
train_multiple_phrase_dataset
# Out:
#                       Word  Start Word Index  End Word Index  \
# 9    #harrypotter marathon                 0               1
# 261     early bird special                 0               2
# 291       oem window mount                 2               4
# 293             monday nov                14              15
# 299       fitness business                 5               6
# 300              four loko                11              12
# 328         prime minister                13              14
# 333           #mnd charity                16              17
# 340            lil webbies                10              11
# 493              dojo news                 0               1
# 499                zig zag                25              26
# 510            guilty gear                 5               6
# 536           yella habibi                12              13
# 542                 po ako                 5               6
# ...

# %%
train_multiple_phrase_dataset.to_csv('logs/TRAIN_MULTIPLE_twitter_label.tsv', sep='\t', index=False)

# %%
val_label_dataset = pd.read_csv('logs/VAL_relabelled_data_spacy_pass_entire_sentence_no_break_apart.tsv', sep='\t')
val_label_dataset
# Out:
#           Word  Start Word Index  End Word Index           POS Label  \
# 0           tc                 0               0           ['PROPN']
# 1    @user1373                 3               3           ['PROPN']
# 2     @user182                 4               4           ['PROPN']
# 3    @user2559                 5               5           ['PROPN']
# 4     @user505                 2               2           ['PROPN']
# ..         ...               ...             ...                 ...
# 430      light                11              11           ['PROPN']
# 431  @user1695                 0               0           ['PROPN']
# 432       tueh                10              10           ['PROPN']
# 433  touch ups                 4               5  ['PROPN', 'PROPN']
# 434    @user76                 0               0           ['PROPN']
#
#       Spacy POS Label   Final POS Label   NER Label Spacy NER Label  \
# 0               ['X']             ['X']       ['O']              []
# ...

# %%
val_single_phrase_dataset = val_label_dataset.drop(val_label_dataset[val_label_dataset['Start Word Index'] != val_label_dataset['End Word Index']].index)
val_single_phrase_dataset
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0           tc                 0               0  ['PROPN']           ['X']
# 1    @user1373                 3               3  ['PROPN']           ['X']
# 2     @user182                 4               4  ['PROPN']           ['X']
# 3    @user2559                 5               5  ['PROPN']           ['X']
# 4     @user505                 2               2  ['PROPN']       ['PROPN']
# ..         ...               ...             ...        ...             ...
# 429    battery                 9               9  ['PROPN']        ['NOUN']
# 430      light                11              11  ['PROPN']        ['NOUN']
# 431  @user1695                 0               0  ['PROPN']       ['PROPN']
# 432       tueh                10              10  ['PROPN']           ['X']
# 434    @user76                 0               0  ['PROPN']       ['PROPN']
#
# ...

# %%
val_single_phrase_dataset.to_csv('logs/VAL_SINGLE_twitter_label.tsv', sep='\t', index=False)

# %%
val_multiple_phrase_dataset = val_label_dataset.drop(val_label_dataset[val_label_dataset['Start Word Index'] == val_label_dataset['End Word Index']].index)
val_multiple_phrase_dataset
# Out:
#                               Word  Start Word Index  End Word Index  \
# 7    nonfiction stories collection                 7               9
# 85               roger smith hotel                 5               7
# 92                   cfa risk mgmt                 0               2
# 101                   lapierre btg                20              21
# 115    bacon cheeseburger perogies                 4               6
# 116               pumpkin perogies                10              11
# 147                    trinity ave                 4               5
# 179                      t/y usher                16              17
# 196                 prime minister                 3               4
# 209                         fan up                 1               2
# 223          #brewers minor league                 3               5
# 230                    bloody mary                 0               1
# 244               #cherrybay party                 4               5
# ...

# %%
val_multiple_phrase_dataset.to_csv('logs/VAL_MULTIPLE_twitter_label.tsv', sep='\t', index=False)

# %%
test_label_dataset = pd.read_csv('logs/TEST_relabelled_data_spacy_pass_entire_sentence_no_break_apart.tsv', sep='\t')
test_label_dataset
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0     @user415                11              11  ['PROPN']           ['X']
# 1    @user1136                11              11  ['PROPN']       ['PROPN']
# 2          xb1                13              13  ['PROPN']        ['NOUN']
# 3    @user1071                15              15  ['PROPN']        ['NOUN']
# 4     @user718                18              18  ['PROPN']       ['PROPN']
# ..         ...               ...             ...        ...             ...
# 702    ireland                 5               5  ['PROPN']       ['PROPN']
# 703  @user1311                 0               0  ['PROPN']       ['PROPN']
# 704  @user1132                 0               0  ['PROPN']       ['PROPN']
# 705          t                 9               9  ['PROPN']        ['NOUN']
# 706  @user1812                 0               0  ['PROPN']       ['PROPN']
#
# ...

# %%
test_single_phrase_dataset = test_label_dataset.drop(test_label_dataset[test_label_dataset['Start Word Index'] != test_label_dataset['End Word Index']].index)
test_single_phrase_dataset
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0     @user415                11              11  ['PROPN']           ['X']
# 1    @user1136                11              11  ['PROPN']       ['PROPN']
# 2          xb1                13              13  ['PROPN']        ['NOUN']
# 3    @user1071                15              15  ['PROPN']        ['NOUN']
# 4     @user718                18              18  ['PROPN']       ['PROPN']
# ..         ...               ...             ...        ...             ...
# 702    ireland                 5               5  ['PROPN']       ['PROPN']
# 703  @user1311                 0               0  ['PROPN']       ['PROPN']
# 704  @user1132                 0               0  ['PROPN']       ['PROPN']
# 705          t                 9               9  ['PROPN']        ['NOUN']
# 706  @user1812                 0               0  ['PROPN']       ['PROPN']
#
# ...

# %%
test_single_phrase_dataset.to_csv('logs/TEST_SINGLE_twitter_label.tsv', sep='\t', index=False)

# %%
test_multiple_phrase_dataset = test_label_dataset.drop(test_label_dataset[test_label_dataset['Start Word Index'] == test_label_dataset['End Word Index']].index)
test_multiple_phrase_dataset
# Out:
#                                  Word  Start Word Index  End Word Index  \
# 82                         taco shell                 6               7
# 86                      amateur radio                 0               1
# 99                          mr. mikes                 3               4
# 104                dentist procedures                 9              10
# 138                 wednesday special                 0               1
# 143  x8w x8c x8g rc quadcopter banana                12              17
# 151                        morse code                11              12
# 155                      #marwat saeb                22              23
# 167              scrubbing dish cloth                12              14
# 186                       t20 cricket                18              19
# 226                     one direction                19              20
# 265                        early bird                 3               4
# ...

# %%
test_multiple_phrase_dataset.to_csv('logs/TEST_MULTIPLE_twitter_label.tsv', sep='\t', index=False)
