# %% [markdown]
# Leung Wai Liu <br>
# JPMorgan AI Research <br>
# August 15, 2022 <br>
# Integrated Results Back Into Dataset VAL

# %%
import pandas as pd
import numpy as np

# %%
original_dataset = pd.read_csv('logs/combined_val_labels_FINAL_NUMBERS.tsv', sep='\t')
original_dataset
# Out:
#      Sentence Index       Word  Start Word Index  End Word Index  \
# 0                10         tc                 0               0
# 1                11  @user1373                 3               3
# 2                11   @user182                 4               4
# 3                12  @user2559                 5               5
# 4                16   @user505                 2               2
# ..              ...        ...               ...             ...
# 430             697      light                11              11
# 431             704  @user1695                 0               0
# 432             706       tueh                10              10
# 433             708  touch ups                 4               5
# 434               6    @user76                 0               0
#
#               POS Label   NER Label  \
# 0             ['PROPN']       ['O']
# 1             ['PROPN']       ['O']
# 2             ['PROPN']       ['O']
# 3             ['PROPN']       ['O']
# 4             ['PROPN']       ['O']
# ..                  ...         ...
# 430           ['PROPN']       ['O']
# 431           ['PROPN']       ['O']
# 432           ['PROPN']       ['O']
# 433  ['PROPN', 'PROPN']  ['O', 'O']
# 434           ['PROPN']       ['O']
#
#                                                  Tweet  \
# 0    tc : facebook ’s timeline is changing again , ...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    rt @user1836 : @user1373 @user182 at a minimum...
# 3    1 week to go ! @user2559 full weekend tickets ...
# 4    !!!!! " @user505 : #yoursexisweak if i fall as...
# ..                                                 ...
# 430  2500 lumen led flashlight cree xml t6 torch re...
# 431                        @user1695 i miss you sm wtf
# 432  rt @user61 : in the capital ! in 2016 ! tueh ....
# 433  i 've just unlocked touch ups achievement in p...
# 434                 @user76 or the who . * runs away *
#
#                                       Tweet POS Labels  \
# 0    ['PROPN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'A...
# 1    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 2    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 3    ['NUM', 'NOUN', 'PART', 'VERB', 'PUNCT', 'PROP...
# 4    ['PUNCT', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'S...
# ..                                                 ...
# 430  ['NUM', 'PROPN', 'PROPN', 'NOUN', 'PROPN', 'PR...
# 431   ['PROPN', 'PRON', 'VERB', 'PRON', 'ADV', 'INTJ']
# 432  ['X', 'X', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PUN...
# 433  ['PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'PROPN...
# 434  ['PROPN', 'CCONJ', 'DET', 'NOUN', 'PUNCT', 'PU...
#
#                                       Tweet NER Labels
# 0    ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', '...
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ..                                                 ...
# 430  ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', '...
# 431                     ['O', 'O', 'O', 'O', 'O', 'O']
# 432  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 433  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MI...
# 434  ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O...
#
# [435 rows x 9 columns]

# %%
original_dataset.index.name='Orig Index'
original_dataset
# Out:
#             Sentence Index       Word  Start Word Index  End Word Index  \
# Orig Index
# 0                       10         tc                 0               0
# 1                       11  @user1373                 3               3
# 2                       11   @user182                 4               4
# 3                       12  @user2559                 5               5
# 4                       16   @user505                 2               2
# ...                    ...        ...               ...             ...
# 430                    697      light                11              11
# 431                    704  @user1695                 0               0
# 432                    706       tueh                10              10
# 433                    708  touch ups                 4               5
# 434                      6    @user76                 0               0
#
#                      POS Label   NER Label  \
# Orig Index
# 0                    ['PROPN']       ['O']
# 1                    ['PROPN']       ['O']
# 2                    ['PROPN']       ['O']
# 3                    ['PROPN']       ['O']
# 4                    ['PROPN']       ['O']
# ...                        ...         ...
# 430                  ['PROPN']       ['O']
# 431                  ['PROPN']       ['O']
# 432                  ['PROPN']       ['O']
# 433         ['PROPN', 'PROPN']  ['O', 'O']
# 434                  ['PROPN']       ['O']
#
#                                                         Tweet  \
# Orig Index
# 0           tc : facebook ’s timeline is changing again , ...
# 1           rt @user1836 : @user1373 @user182 at a minimum...
# 2           rt @user1836 : @user1373 @user182 at a minimum...
# 3           1 week to go ! @user2559 full weekend tickets ...
# 4           !!!!! " @user505 : #yoursexisweak if i fall as...
# ...                                                       ...
# 430         2500 lumen led flashlight cree xml t6 torch re...
# 431                               @user1695 i miss you sm wtf
# 432         rt @user61 : in the capital ! in 2016 ! tueh ....
# 433         i 've just unlocked touch ups achievement in p...
# 434                        @user76 or the who . * runs away *
#
#                                              Tweet POS Labels  \
# Orig Index
# 0           ['PROPN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'A...
# 1           ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 2           ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 3           ['NUM', 'NOUN', 'PART', 'VERB', 'PUNCT', 'PROP...
# 4           ['PUNCT', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'S...
# ...                                                       ...
# 430         ['NUM', 'PROPN', 'PROPN', 'NOUN', 'PROPN', 'PR...
# 431          ['PROPN', 'PRON', 'VERB', 'PRON', 'ADV', 'INTJ']
# 432         ['X', 'X', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PUN...
# 433         ['PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'PROPN...
# 434         ['PROPN', 'CCONJ', 'DET', 'NOUN', 'PUNCT', 'PU...
#
#                                              Tweet NER Labels
# Orig Index
# 0           ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', '...
# 1           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ...                                                       ...
# 430         ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', '...
# 431                            ['O', 'O', 'O', 'O', 'O', 'O']
# 432         ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 433         ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MI...
# 434         ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O...
#
# [435 rows x 9 columns]

# %%
val_agree = pd.read_csv('../../JPM_Twitter_Relabelling/Twitter Relabelled Files/Combined Val Files/combined_val_agree.tsv', sep='\t')
val_agree
# Out:
#      Unnamed: 0       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1373                 3               3  ['PROPN']
# 1             2   @user182                 4               4  ['PROPN']
# 2             4   @user505                 2               2  ['PROPN']
# 3            10  @user2586                 9               9  ['PROPN']
# 4            11    @user42                 0               0  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 275         405  @user1105                12              12  ['PROPN']
# 276         408    @user21                18              18  ['PROPN']
# 277         411  @user1695                 0               0  ['PROPN']
# 278         412       tueh                10              10  ['PROPN']
# 279         413    @user76                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1             ['X']           ['X']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3         ['PROPN']       ['PROPN']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 275       ['PROPN']       ['PROPN']     ['O']              []
# 276           ['X']           ['X']     ['O']              []
# 277       ['PROPN']       ['PROPN']     ['O']              []
# 278           ['X']           ['X']     ['O']              []
# 279       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    rt @user1836 : @user1373 @user182 at a minimum...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    !!!!! " @user505 : #yoursexisweak if i fall as...
# 3    :'-d face that grinds rt @user1122 : ladies - ...
# 4    @user42 he stay drinkin it . he be burpin nshi...
# ..                                                 ...
# 275  rt @user1430 : happy #supersoulsunday tweet 💜 ...
# 276  rt @user2438 : it was an incredible concert gu...
# 277                        @user1695 i miss you sm wtf
# 278  rt @user61 : in the capital ! in 2016 ! tueh ....
# 279                 @user76 or the who . * runs away *
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    rt @user1836 : <[@user1373]> @user182 at a min...              B-PER
# 1    rt @user1836 : @user1373 <[@user182]> at a min...              B-PER
# 2    !!!!! " <[@user505]> : #yoursexisweak if i fal...              B-PER
# 3    :'-d face that grinds rt @user1122 : ladies - ...              B-PER
# 4    <[@user42]> he stay drinkin it . he be burpin ...              B-PER
# ..                                                 ...                ...
# 275  rt @user1430 : happy #supersoulsunday tweet 💜 ...              B-PER
# 276  rt @user2438 : it was an incredible concert gu...              B-PER
# 277                    <[@user1695]> i miss you sm wtf              B-PER
# 278  rt @user61 : in the capital ! in 2016 ! <[tueh...                  O
# 279             <[@user76]> or the who . * runs away *              B-PER
#
#     LW NER Label Alec NER Label LW Additional Notes
# 0          B-PER          B-PER                 NaN
# 1          B-PER          B-PER                 NaN
# 2          B-PER          B-PER                 NaN
# 3          B-PER          B-PER                 NaN
# 4          B-PER          B-PER                 NaN
# ..           ...            ...                 ...
# 275        B-PER          B-PER                 NaN
# 276        B-PER          B-PER                 NaN
# 277        B-PER          B-PER                 NaN
# 278            O              O                 NaN
# 279        B-PER          B-PER                 NaN
#
# [280 rows x 15 columns]

# %%
val_agree = val_agree.rename(columns={'Unnamed: 0': 'Orig Index'})
val_agree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1373                 3               3  ['PROPN']
# 1             2   @user182                 4               4  ['PROPN']
# 2             4   @user505                 2               2  ['PROPN']
# 3            10  @user2586                 9               9  ['PROPN']
# 4            11    @user42                 0               0  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 275         405  @user1105                12              12  ['PROPN']
# 276         408    @user21                18              18  ['PROPN']
# 277         411  @user1695                 0               0  ['PROPN']
# 278         412       tueh                10              10  ['PROPN']
# 279         413    @user76                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1             ['X']           ['X']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3         ['PROPN']       ['PROPN']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 275       ['PROPN']       ['PROPN']     ['O']              []
# 276           ['X']           ['X']     ['O']              []
# 277       ['PROPN']       ['PROPN']     ['O']              []
# 278           ['X']           ['X']     ['O']              []
# 279       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    rt @user1836 : @user1373 @user182 at a minimum...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    !!!!! " @user505 : #yoursexisweak if i fall as...
# 3    :'-d face that grinds rt @user1122 : ladies - ...
# 4    @user42 he stay drinkin it . he be burpin nshi...
# ..                                                 ...
# 275  rt @user1430 : happy #supersoulsunday tweet 💜 ...
# 276  rt @user2438 : it was an incredible concert gu...
# 277                        @user1695 i miss you sm wtf
# 278  rt @user61 : in the capital ! in 2016 ! tueh ....
# 279                 @user76 or the who . * runs away *
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    rt @user1836 : <[@user1373]> @user182 at a min...              B-PER
# 1    rt @user1836 : @user1373 <[@user182]> at a min...              B-PER
# 2    !!!!! " <[@user505]> : #yoursexisweak if i fal...              B-PER
# 3    :'-d face that grinds rt @user1122 : ladies - ...              B-PER
# 4    <[@user42]> he stay drinkin it . he be burpin ...              B-PER
# ..                                                 ...                ...
# 275  rt @user1430 : happy #supersoulsunday tweet 💜 ...              B-PER
# 276  rt @user2438 : it was an incredible concert gu...              B-PER
# 277                    <[@user1695]> i miss you sm wtf              B-PER
# 278  rt @user61 : in the capital ! in 2016 ! <[tueh...                  O
# 279             <[@user76]> or the who . * runs away *              B-PER
#
#     LW NER Label Alec NER Label LW Additional Notes
# 0          B-PER          B-PER                 NaN
# 1          B-PER          B-PER                 NaN
# 2          B-PER          B-PER                 NaN
# 3          B-PER          B-PER                 NaN
# 4          B-PER          B-PER                 NaN
# ..           ...            ...                 ...
# 275        B-PER          B-PER                 NaN
# 276        B-PER          B-PER                 NaN
# 277        B-PER          B-PER                 NaN
# 278            O              O                 NaN
# 279        B-PER          B-PER                 NaN
#
# [280 rows x 15 columns]

# %%
val_disagree = pd.read_csv('../../JPM_Twitter_Relabelling/Twitter Relabelled Files/Combined Val Files/combined_val_disagree_filtered.tsv', sep='\t')
val_disagree
# Out:
#      Unnamed: 0       Word  Start Word Index  End Word Index  POS Label  \
# 0           317  @user1661                20              20  ['PROPN']
# 1           128  @user2640                 3               3  ['PROPN']
# 2           132   @user532                13              13  ['PROPN']
# 3           356  @user2444                16              16  ['PROPN']
# 4           149   @user617                 4               4  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 98          276        #빅스                 1               1  ['PROPN']
# 99          286  associate                 0               0  ['PROPN']
# 100         294        mvp                 5               5  ['PROPN']
# 101         173  teachcode                21              21  ['PROPN']
# 102         410      light                11              11  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0          ['NOUN']        ['NOUN']     ['O']              []
# 1             ['X']           ['X']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4         ['PROPN']       ['PROPN']     ['O']              []
# ..              ...             ...       ...             ...
# 98        ['PUNCT']       ['PUNCT']     ['O']              []
# 99         ['NOUN']        ['NOUN']     ['O']              []
# 100        ['NOUN']        ['NOUN']     ['O']              []
# 101        ['NOUN']        ['NOUN']     ['O']              []
# 102        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    rt @user2001 : congratulations ! you won the c...
# 1    rt @user2399 : @user2640 hi . pls help us rt @...
# 2    rt @user2537 : also : buy tix for my good budd...
# 3    rt @user99 : did a little shopping today . ( ....
# 4    reached a milestone on @user617 : 20 consecuti...
# ..                                                 ...
# 98   retweet #빅스 ( #vixx ) and make on url605 to sh...
# 99   associate rick reid serenading us at the tax p...
# 100            rt @user35 : the real mvp url483 url310
# 101  rt @user1301 : what could be better than chick...
# 102  2500 lumen led flashlight cree xml t6 torch re...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    rt @user2001 : congratulations ! you won the c...              B-PER
# 1    rt @user2399 : <[@user2640]> hi . pls help us ...              B-PER
# 2    rt @user2537 : also : buy tix for my good budd...              B-PER
# 3    rt @user99 : did a little shopping today . ( ....              B-PER
# 4    reached a milestone on <[@user617]> : 20 conse...              B-PER
# ..                                                 ...                ...
# 98   retweet <[#빅스]> ( #vixx ) and make on url605 t...                  O
# 99   <[associate]> rick reid serenading us at the t...                  O
# 100        rt @user35 : the real <[mvp]> url483 url310                  O
# 101  rt @user1301 : what could be better than chick...                  O
# 102  2500 lumen led flashlight cree xml t6 torch re...                  O
#
#     LW NER Label Alec NER Label LW Additional Notes
# 0          B-ORG          B-PER                 NaN
# 1              O          B-PER                 NaN
# 2         B-MISC          B-PER                 NaN
# 3         B-MISC          B-PER             product
# 4          B-ORG          B-PER                 NaN
# ..           ...            ...                 ...
# 98         B-ORG              O                 NaN
# 99             O         B-MISC                 NaN
# 100            O         B-MISC                 NaN
# 101       B-MISC              O                   ?
# 102            O         B-MISC                 NaN
#
# [103 rows x 15 columns]

# %%
val_disagree = val_disagree.rename(columns={'Unnamed: 0': 'Orig Index'})
val_disagree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0           317  @user1661                20              20  ['PROPN']
# 1           128  @user2640                 3               3  ['PROPN']
# 2           132   @user532                13              13  ['PROPN']
# 3           356  @user2444                16              16  ['PROPN']
# 4           149   @user617                 4               4  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 98          276        #빅스                 1               1  ['PROPN']
# 99          286  associate                 0               0  ['PROPN']
# 100         294        mvp                 5               5  ['PROPN']
# 101         173  teachcode                21              21  ['PROPN']
# 102         410      light                11              11  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0          ['NOUN']        ['NOUN']     ['O']              []
# 1             ['X']           ['X']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4         ['PROPN']       ['PROPN']     ['O']              []
# ..              ...             ...       ...             ...
# 98        ['PUNCT']       ['PUNCT']     ['O']              []
# 99         ['NOUN']        ['NOUN']     ['O']              []
# 100        ['NOUN']        ['NOUN']     ['O']              []
# 101        ['NOUN']        ['NOUN']     ['O']              []
# 102        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    rt @user2001 : congratulations ! you won the c...
# 1    rt @user2399 : @user2640 hi . pls help us rt @...
# 2    rt @user2537 : also : buy tix for my good budd...
# 3    rt @user99 : did a little shopping today . ( ....
# 4    reached a milestone on @user617 : 20 consecuti...
# ..                                                 ...
# 98   retweet #빅스 ( #vixx ) and make on url605 to sh...
# 99   associate rick reid serenading us at the tax p...
# 100            rt @user35 : the real mvp url483 url310
# 101  rt @user1301 : what could be better than chick...
# 102  2500 lumen led flashlight cree xml t6 torch re...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    rt @user2001 : congratulations ! you won the c...              B-PER
# 1    rt @user2399 : <[@user2640]> hi . pls help us ...              B-PER
# 2    rt @user2537 : also : buy tix for my good budd...              B-PER
# 3    rt @user99 : did a little shopping today . ( ....              B-PER
# 4    reached a milestone on <[@user617]> : 20 conse...              B-PER
# ..                                                 ...                ...
# 98   retweet <[#빅스]> ( #vixx ) and make on url605 t...                  O
# 99   <[associate]> rick reid serenading us at the t...                  O
# 100        rt @user35 : the real <[mvp]> url483 url310                  O
# 101  rt @user1301 : what could be better than chick...                  O
# 102  2500 lumen led flashlight cree xml t6 torch re...                  O
#
#     LW NER Label Alec NER Label LW Additional Notes
# 0          B-ORG          B-PER                 NaN
# 1              O          B-PER                 NaN
# 2         B-MISC          B-PER                 NaN
# 3         B-MISC          B-PER             product
# 4          B-ORG          B-PER                 NaN
# ..           ...            ...                 ...
# 98         B-ORG              O                 NaN
# 99             O         B-MISC                 NaN
# 100            O         B-MISC                 NaN
# 101       B-MISC              O                   ?
# 102            O         B-MISC                 NaN
#
# [103 rows x 15 columns]

# %%
val_relabelled_frames = [val_agree, val_disagree]
val_relabelled = pd.concat(val_relabelled_frames)
val_relabelled
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1373                 3               3  ['PROPN']
# 1             2   @user182                 4               4  ['PROPN']
# 2             4   @user505                 2               2  ['PROPN']
# 3            10  @user2586                 9               9  ['PROPN']
# 4            11    @user42                 0               0  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 98          276        #빅스                 1               1  ['PROPN']
# 99          286  associate                 0               0  ['PROPN']
# 100         294        mvp                 5               5  ['PROPN']
# 101         173  teachcode                21              21  ['PROPN']
# 102         410      light                11              11  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1             ['X']           ['X']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3         ['PROPN']       ['PROPN']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 98        ['PUNCT']       ['PUNCT']     ['O']              []
# 99         ['NOUN']        ['NOUN']     ['O']              []
# 100        ['NOUN']        ['NOUN']     ['O']              []
# 101        ['NOUN']        ['NOUN']     ['O']              []
# 102        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    rt @user1836 : @user1373 @user182 at a minimum...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    !!!!! " @user505 : #yoursexisweak if i fall as...
# 3    :'-d face that grinds rt @user1122 : ladies - ...
# 4    @user42 he stay drinkin it . he be burpin nshi...
# ..                                                 ...
# 98   retweet #빅스 ( #vixx ) and make on url605 to sh...
# 99   associate rick reid serenading us at the tax p...
# 100            rt @user35 : the real mvp url483 url310
# 101  rt @user1301 : what could be better than chick...
# 102  2500 lumen led flashlight cree xml t6 torch re...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    rt @user1836 : <[@user1373]> @user182 at a min...              B-PER
# 1    rt @user1836 : @user1373 <[@user182]> at a min...              B-PER
# 2    !!!!! " <[@user505]> : #yoursexisweak if i fal...              B-PER
# 3    :'-d face that grinds rt @user1122 : ladies - ...              B-PER
# 4    <[@user42]> he stay drinkin it . he be burpin ...              B-PER
# ..                                                 ...                ...
# 98   retweet <[#빅스]> ( #vixx ) and make on url605 t...                  O
# 99   <[associate]> rick reid serenading us at the t...                  O
# 100        rt @user35 : the real <[mvp]> url483 url310                  O
# 101  rt @user1301 : what could be better than chick...                  O
# 102  2500 lumen led flashlight cree xml t6 torch re...                  O
#
#     LW NER Label Alec NER Label LW Additional Notes
# 0          B-PER          B-PER                 NaN
# 1          B-PER          B-PER                 NaN
# 2          B-PER          B-PER                 NaN
# 3          B-PER          B-PER                 NaN
# 4          B-PER          B-PER                 NaN
# ..           ...            ...                 ...
# 98         B-ORG              O                 NaN
# 99             O         B-MISC                 NaN
# 100            O         B-MISC                 NaN
# 101       B-MISC              O                   ?
# 102            O         B-MISC                 NaN
#
# [383 rows x 15 columns]

# %%
original_dataset_merged = pd.merge(original_dataset, val_relabelled[['Orig Index', 'LW NER Label']], on='Orig Index', how='left')
original_dataset_merged
# Out:
#      Orig Index  Sentence Index       Word  Start Word Index  End Word Index  \
# 0             0              10         tc                 0               0
# 1             1              11  @user1373                 3               3
# 2             2              11   @user182                 4               4
# 3             3              12  @user2559                 5               5
# 4             4              16   @user505                 2               2
# ..          ...             ...        ...               ...             ...
# 430         430             697      light                11              11
# 431         431             704  @user1695                 0               0
# 432         432             706       tueh                10              10
# 433         433             708  touch ups                 4               5
# 434         434               6    @user76                 0               0
#
#               POS Label   NER Label  \
# 0             ['PROPN']       ['O']
# 1             ['PROPN']       ['O']
# 2             ['PROPN']       ['O']
# 3             ['PROPN']       ['O']
# 4             ['PROPN']       ['O']
# ..                  ...         ...
# 430           ['PROPN']       ['O']
# 431           ['PROPN']       ['O']
# 432           ['PROPN']       ['O']
# 433  ['PROPN', 'PROPN']  ['O', 'O']
# 434           ['PROPN']       ['O']
#
#                                                  Tweet  \
# 0    tc : facebook ’s timeline is changing again , ...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    rt @user1836 : @user1373 @user182 at a minimum...
# 3    1 week to go ! @user2559 full weekend tickets ...
# 4    !!!!! " @user505 : #yoursexisweak if i fall as...
# ..                                                 ...
# 430  2500 lumen led flashlight cree xml t6 torch re...
# 431                        @user1695 i miss you sm wtf
# 432  rt @user61 : in the capital ! in 2016 ! tueh ....
# 433  i 've just unlocked touch ups achievement in p...
# 434                 @user76 or the who . * runs away *
#
#                                       Tweet POS Labels  \
# 0    ['PROPN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'A...
# 1    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 2    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 3    ['NUM', 'NOUN', 'PART', 'VERB', 'PUNCT', 'PROP...
# 4    ['PUNCT', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'S...
# ..                                                 ...
# 430  ['NUM', 'PROPN', 'PROPN', 'NOUN', 'PROPN', 'PR...
# 431   ['PROPN', 'PRON', 'VERB', 'PRON', 'ADV', 'INTJ']
# 432  ['X', 'X', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PUN...
# 433  ['PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'PROPN...
# 434  ['PROPN', 'CCONJ', 'DET', 'NOUN', 'PUNCT', 'PU...
#
#                                       Tweet NER Labels LW NER Label
# 0    ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', '...        B-ORG
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        B-PER
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        B-PER
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...       B-MISC
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        B-PER
# ..                                                 ...          ...
# 430  ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', '...          NaN
# 431                     ['O', 'O', 'O', 'O', 'O', 'O']          NaN
# 432  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...          NaN
# 433  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MI...          NaN
# 434  ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O...          NaN
#
# [435 rows x 11 columns]

# %%
original_dataset_merged = original_dataset_merged.rename(columns={'LW NER Label' : 'FINAL NER Label'})
original_dataset_merged
# Out:
#      Orig Index  Sentence Index       Word  Start Word Index  End Word Index  \
# 0             0              10         tc                 0               0
# 1             1              11  @user1373                 3               3
# 2             2              11   @user182                 4               4
# 3             3              12  @user2559                 5               5
# 4             4              16   @user505                 2               2
# ..          ...             ...        ...               ...             ...
# 430         430             697      light                11              11
# 431         431             704  @user1695                 0               0
# 432         432             706       tueh                10              10
# 433         433             708  touch ups                 4               5
# 434         434               6    @user76                 0               0
#
#               POS Label   NER Label  \
# 0             ['PROPN']       ['O']
# 1             ['PROPN']       ['O']
# 2             ['PROPN']       ['O']
# 3             ['PROPN']       ['O']
# 4             ['PROPN']       ['O']
# ..                  ...         ...
# 430           ['PROPN']       ['O']
# 431           ['PROPN']       ['O']
# 432           ['PROPN']       ['O']
# 433  ['PROPN', 'PROPN']  ['O', 'O']
# 434           ['PROPN']       ['O']
#
#                                                  Tweet  \
# 0    tc : facebook ’s timeline is changing again , ...
# 1    rt @user1836 : @user1373 @user182 at a minimum...
# 2    rt @user1836 : @user1373 @user182 at a minimum...
# 3    1 week to go ! @user2559 full weekend tickets ...
# 4    !!!!! " @user505 : #yoursexisweak if i fall as...
# ..                                                 ...
# 430  2500 lumen led flashlight cree xml t6 torch re...
# 431                        @user1695 i miss you sm wtf
# 432  rt @user61 : in the capital ! in 2016 ! tueh ....
# 433  i 've just unlocked touch ups achievement in p...
# 434                 @user76 or the who . * runs away *
#
#                                       Tweet POS Labels  \
# 0    ['PROPN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'A...
# 1    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 2    ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'ADP', '...
# 3    ['NUM', 'NOUN', 'PART', 'VERB', 'PUNCT', 'PROP...
# 4    ['PUNCT', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'S...
# ..                                                 ...
# 430  ['NUM', 'PROPN', 'PROPN', 'NOUN', 'PROPN', 'PR...
# 431   ['PROPN', 'PRON', 'VERB', 'PRON', 'ADV', 'INTJ']
# 432  ['X', 'X', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PUN...
# 433  ['PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'PROPN...
# 434  ['PROPN', 'CCONJ', 'DET', 'NOUN', 'PUNCT', 'PU...
#
#                                       Tweet NER Labels FINAL NER Label
# 0    ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', '...           B-ORG
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...           B-PER
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...           B-PER
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...          B-MISC
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...           B-PER
# ..                                                 ...             ...
# 430  ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', '...             NaN
# 431                     ['O', 'O', 'O', 'O', 'O', 'O']             NaN
# 432  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             NaN
# 433  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MI...             NaN
# 434  ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O...             NaN
#
# [435 rows x 11 columns]

# %%
original_dataset_merged.to_csv('logs/original_dataset_merged_with_results.tsv', sep='\t')

# %%
# WRITING BACK TO ORIGINAL FILE
filename = '../Datasets/NER/Tweebank/' + 'dev copy.bio'

how_much_changed = 0
replacement = ''
with open(filename, 'r') as file:
    original_data = file.readlines()

with open(filename, 'r') as file:
    sentence_count = 0
    word_in_sentence_count = 0
    
    for i, line in enumerate(file):
        line = line[:-1]

        if len(line):
            check_df = original_dataset_merged[original_dataset_merged['Sentence Index'] == sentence_count]
            
            if len(check_df) != 0: 
                check_df_row = check_df[check_df['Start Word Index'] == word_in_sentence_count]
                
                if len(check_df_row) != 0:
                    check_df_row_value = check_df_row['FINAL NER Label']
                    check_df_row_value_empty = check_df_row_value.any()

                    if check_df_row_value_empty != False:
                        token, _, _, label = line.split('\t')
                        
                        print("-" * 50)
                        print("ORIGINAL LINE")
                        print(line)
                        print("WORD IN TOKEN")
                        print(check_df_row.iloc[0]['Word'])
                        line_to_replace = [token, '-', '-', check_df_row.iloc[0]['FINAL NER Label']]
                        line_to_replace_string = '\t'.join(line_to_replace)
                        print("Line to replace")
                        print(line_to_replace_string) 

                        original_data[i] = line_to_replace_string + '\n'
                        how_much_changed += 1
        
            word_in_sentence_count += 1
        else:
            sentence_count += 1
            word_in_sentence_count = 0



to_write_file = open('dev_test.bio', 'w')
to_write_file.writelines(original_data)
to_write_file.close()

print("HOW MUCH CHANGED:")
print(how_much_changed)
# Out:
# --------------------------------------------------
# ORIGINAL LINE
# TC	-	-	O
# WORD IN TOKEN
# tc
# Line to replace
# TC	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1373	-	-	O
# WORD IN TOKEN
# @user1373
# Line to replace
# @USER1373	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER182	-	-	O
# WORD IN TOKEN
# @user182
# Line to replace
# @USER182	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2559	-	-	O
# WORD IN TOKEN
# @user2559
# Line to replace
# @USER2559	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER505	-	-	O
# WORD IN TOKEN
# @user505
# Line to replace
# @USER505	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Fiction	-	-	O
# WORD IN TOKEN
# fiction
# Line to replace
# Fiction	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# NonFiction	-	-	O
# WORD IN TOKEN
# nonfiction stories collection
# Line to replace
# NonFiction	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Rp	-	-	O
# WORD IN TOKEN
# rp
# Line to replace
# Rp	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1597	-	-	O
# WORD IN TOKEN
# @user1597
# Line to replace
# @USER1597	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER347	-	-	O
# WORD IN TOKEN
# @user347
# Line to replace
# @USER347	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2586	-	-	O
# WORD IN TOKEN
# @user2586
# Line to replace
# @USER2586	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER42	-	-	O
# WORD IN TOKEN
# @user42
# Line to replace
# @USER42	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER145	-	-	O
# WORD IN TOKEN
# @user145
# Line to replace
# @USER145	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER163	-	-	O
# WORD IN TOKEN
# @user163
# Line to replace
# @USER163	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Feb.	-	-	O
# WORD IN TOKEN
# feb.
# Line to replace
# Feb.	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER310	-	-	O
# WORD IN TOKEN
# @user310
# Line to replace
# @USER310	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER235	-	-	O
# WORD IN TOKEN
# @user235
# Line to replace
# @USER235	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER236	-	-	O
# WORD IN TOKEN
# @user236
# Line to replace
# @USER236	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER331	-	-	O
# WORD IN TOKEN
# @user331
# Line to replace
# @USER331	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER553	-	-	O
# WORD IN TOKEN
# @user553
# Line to replace
# @USER553	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER603	-	-	O
# WORD IN TOKEN
# @user603
# Line to replace
# @USER603	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER625	-	-	O
# WORD IN TOKEN
# @user625
# Line to replace
# @USER625	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER632	-	-	O
# WORD IN TOKEN
# @user632
# Line to replace
# @USER632	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER711	-	-	O
# WORD IN TOKEN
# @user711
# Line to replace
# @USER711	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# May	-	-	O
# WORD IN TOKEN
# may
# Line to replace
# May	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER772	-	-	O
# WORD IN TOKEN
# @user772
# Line to replace
# @USER772	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER841	-	-	O
# WORD IN TOKEN
# @user841
# Line to replace
# @USER841	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER870	-	-	O
# WORD IN TOKEN
# @user870
# Line to replace
# @USER870	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER953	-	-	O
# WORD IN TOKEN
# @user953
# Line to replace
# @USER953	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1070	-	-	O
# WORD IN TOKEN
# @user1070
# Line to replace
# @USER1070	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1095	-	-	O
# WORD IN TOKEN
# @user1095
# Line to replace
# @USER1095	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1097	-	-	O
# WORD IN TOKEN
# @user1097
# Line to replace
# @USER1097	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1133	-	-	O
# WORD IN TOKEN
# @user1133
# Line to replace
# @USER1133	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# rena	-	-	O
# WORD IN TOKEN
# rena
# Line to replace
# rena	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1174	-	-	O
# WORD IN TOKEN
# @user1174
# Line to replace
# @USER1174	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Ace	-	-	O
# WORD IN TOKEN
# ace
# Line to replace
# Ace	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2157	-	-	O
# WORD IN TOKEN
# @user2157
# Line to replace
# @USER2157	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1190	-	-	O
# WORD IN TOKEN
# @user1190
# Line to replace
# @USER1190	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER900	-	-	O
# WORD IN TOKEN
# @user900
# Line to replace
# @USER900	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1194	-	-	O
# WORD IN TOKEN
# @user1194
# Line to replace
# @USER1194	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1203	-	-	O
# WORD IN TOKEN
# @user1203
# Line to replace
# @USER1203	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1216	-	-	O
# WORD IN TOKEN
# @user1216
# Line to replace
# @USER1216	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1303	-	-	O
# WORD IN TOKEN
# @user1303
# Line to replace
# @USER1303	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1333	-	-	O
# WORD IN TOKEN
# @user1333
# Line to replace
# @USER1333	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1334	-	-	O
# WORD IN TOKEN
# @user1334
# Line to replace
# @USER1334	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1380	-	-	O
# WORD IN TOKEN
# @user1380
# Line to replace
# @USER1380	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1405	-	-	O
# WORD IN TOKEN
# @user1405
# Line to replace
# @USER1405	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1417	-	-	O
# WORD IN TOKEN
# @user1417
# Line to replace
# @USER1417	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1454	-	-	O
# WORD IN TOKEN
# @user1454
# Line to replace
# @USER1454	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1481	-	-	O
# WORD IN TOKEN
# @user1481
# Line to replace
# @USER1481	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1922	-	-	O
# WORD IN TOKEN
# @user1922
# Line to replace
# @USER1922	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER971	-	-	O
# WORD IN TOKEN
# @user971
# Line to replace
# @USER971	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1251	-	-	O
# WORD IN TOKEN
# @user1251
# Line to replace
# @USER1251	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER460	-	-	O
# WORD IN TOKEN
# @user460
# Line to replace
# @USER460	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1507	-	-	O
# WORD IN TOKEN
# @user1507
# Line to replace
# @USER1507	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1590	-	-	O
# WORD IN TOKEN
# @user1590
# Line to replace
# @USER1590	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1592	-	-	O
# WORD IN TOKEN
# @user1592
# Line to replace
# @USER1592	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1641	-	-	O
# WORD IN TOKEN
# @user1641
# Line to replace
# @USER1641	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1772	-	-	O
# WORD IN TOKEN
# @user1772
# Line to replace
# @USER1772	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1660	-	-	O
# WORD IN TOKEN
# @user1660
# Line to replace
# @USER1660	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1673	-	-	O
# WORD IN TOKEN
# @user1673
# Line to replace
# @USER1673	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1725	-	-	O
# WORD IN TOKEN
# @user1725
# Line to replace
# @USER1725	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1881	-	-	O
# WORD IN TOKEN
# @user1881
# Line to replace
# @USER1881	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1887	-	-	O
# WORD IN TOKEN
# @user1887
# Line to replace
# @USER1887	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1940	-	-	O
# WORD IN TOKEN
# @user1940
# Line to replace
# @USER1940	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1997	-	-	O
# WORD IN TOKEN
# @user1997
# Line to replace
# @USER1997	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2063	-	-	O
# WORD IN TOKEN
# @user2063
# Line to replace
# @USER2063	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2071	-	-	O
# WORD IN TOKEN
# @user2071
# Line to replace
# @USER2071	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2082	-	-	O
# WORD IN TOKEN
# @user2082
# Line to replace
# @USER2082	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Sat	-	-	O
# WORD IN TOKEN
# sat
# Line to replace
# Sat	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2149	-	-	O
# WORD IN TOKEN
# @user2149
# Line to replace
# @USER2149	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2345	-	-	O
# WORD IN TOKEN
# @user2345
# Line to replace
# @USER2345	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2389	-	-	O
# WORD IN TOKEN
# @user2389
# Line to replace
# @USER2389	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2396	-	-	O
# WORD IN TOKEN
# @user2396
# Line to replace
# @USER2396	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# jan	-	-	O
# WORD IN TOKEN
# jan
# Line to replace
# jan	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2525	-	-	O
# WORD IN TOKEN
# @user2525
# Line to replace
# @USER2525	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1269	-	-	O
# WORD IN TOKEN
# @user1269
# Line to replace
# @USER1269	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Pedestals	-	-	O
# WORD IN TOKEN
# pedestals
# Line to replace
# Pedestals	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Roger	-	-	O
# WORD IN TOKEN
# roger smith hotel
# Line to replace
# Roger	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2040	-	-	O
# WORD IN TOKEN
# @user2040
# Line to replace
# @USER2040	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1709	-	-	O
# WORD IN TOKEN
# @user1709
# Line to replace
# @USER1709	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1857	-	-	O
# WORD IN TOKEN
# @user1857
# Line to replace
# @USER1857	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2099	-	-	O
# WORD IN TOKEN
# @user2099
# Line to replace
# @USER2099	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1798	-	-	O
# WORD IN TOKEN
# @user1798
# Line to replace
# @USER1798	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# CFA	-	-	O
# WORD IN TOKEN
# cfa risk mgmt
# Line to replace
# CFA	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Yearbook	-	-	O
# WORD IN TOKEN
# yearbook
# Line to replace
# Yearbook	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Decades	-	-	O
# WORD IN TOKEN
# decades
# Line to replace
# Decades	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Live	-	-	O
# WORD IN TOKEN
# live
# Line to replace
# Live	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1890	-	-	O
# WORD IN TOKEN
# @user1890
# Line to replace
# @USER1890	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2462	-	-	O
# WORD IN TOKEN
# @user2462
# Line to replace
# @USER2462	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER495	-	-	O
# WORD IN TOKEN
# @user495
# Line to replace
# @USER495	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER558	-	-	O
# WORD IN TOKEN
# @user558
# Line to replace
# @USER558	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Worshiper	-	-	O
# WORD IN TOKEN
# worshiper
# Line to replace
# Worshiper	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Lapierre	-	-	O
# WORD IN TOKEN
# lapierre btg
# Line to replace
# Lapierre	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1572	-	-	O
# WORD IN TOKEN
# @user1572
# Line to replace
# @USER1572	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1961	-	-	O
# WORD IN TOKEN
# @user1961
# Line to replace
# @USER1961	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# P̶o̶c̶a̶h̶o̶n̶t̶a̶s̶	-	-	O
# WORD IN TOKEN
# p̶o̶c̶a̶h̶o̶n̶t̶a̶s̶
# Line to replace
# P̶o̶c̶a̶h̶o̶n̶t̶a̶s̶	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# December	-	-	O
# WORD IN TOKEN
# december
# Line to replace
# December	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Jax	-	-	O
# WORD IN TOKEN
# jax
# Line to replace
# Jax	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Pad	-	-	O
# WORD IN TOKEN
# pad
# Line to replace
# Pad	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2245	-	-	O
# WORD IN TOKEN
# @user2245
# Line to replace
# @USER2245	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER780	-	-	O
# WORD IN TOKEN
# @user780
# Line to replace
# @USER780	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# May	-	-	O
# WORD IN TOKEN
# may
# Line to replace
# May	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Goober	-	-	O
# WORD IN TOKEN
# goober
# Line to replace
# Goober	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# god	-	-	O
# WORD IN TOKEN
# god
# Line to replace
# god	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Bacon	-	-	O
# WORD IN TOKEN
# bacon cheeseburger perogies
# Line to replace
# Bacon	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Pumpkin	-	-	O
# WORD IN TOKEN
# pumpkin perogies
# Line to replace
# Pumpkin	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2555	-	-	O
# WORD IN TOKEN
# @user2555
# Line to replace
# @USER2555	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1004	-	-	O
# WORD IN TOKEN
# @user1004
# Line to replace
# @USER1004	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1924	-	-	O
# WORD IN TOKEN
# @user1924
# Line to replace
# @USER1924	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2534	-	-	O
# WORD IN TOKEN
# @user2534
# Line to replace
# @USER2534	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# CHU	-	-	O
# WORD IN TOKEN
# chu
# Line to replace
# CHU	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Ro	-	-	O
# WORD IN TOKEN
# ro
# Line to replace
# Ro	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1686	-	-	O
# WORD IN TOKEN
# @user1686
# Line to replace
# @USER1686	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# RDJ	-	-	O
# WORD IN TOKEN
# rdj
# Line to replace
# RDJ	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Fever	-	-	O
# WORD IN TOKEN
# fever
# Line to replace
# Fever	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER303	-	-	O
# WORD IN TOKEN
# @user303
# Line to replace
# @USER303	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ATLANTA	-	-	O
# WORD IN TOKEN
# #atlanta
# Line to replace
# #ATLANTA	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #AIDS	-	-	O
# WORD IN TOKEN
# #aids
# Line to replace
# #AIDS	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER162	-	-	O
# WORD IN TOKEN
# @user162
# Line to replace
# @USER162	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER796	-	-	O
# WORD IN TOKEN
# @user796
# Line to replace
# @USER796	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Wednesday	-	-	O
# WORD IN TOKEN
# wednesday
# Line to replace
# Wednesday	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# FREE	-	-	O
# WORD IN TOKEN
# free
# Line to replace
# FREE	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2640	-	-	O
# WORD IN TOKEN
# @user2640
# Line to replace
# @USER2640	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER36	-	-	O
# WORD IN TOKEN
# @user36
# Line to replace
# @USER36	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2552	-	-	O
# WORD IN TOKEN
# @user2552
# Line to replace
# @USER2552	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER345	-	-	O
# WORD IN TOKEN
# @user345
# Line to replace
# @USER345	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER532	-	-	O
# WORD IN TOKEN
# @user532
# Line to replace
# @USER532	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #CoonShit	-	-	O
# WORD IN TOKEN
# #coonshit
# Line to replace
# #CoonShit	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Socacize	-	-	O
# WORD IN TOKEN
# socacize
# Line to replace
# Socacize	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# @USER662	-	-	O
# WORD IN TOKEN
# @user662
# Line to replace
# @USER662	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER898	-	-	O
# WORD IN TOKEN
# @user898
# Line to replace
# @USER898	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# October	-	-	O
# WORD IN TOKEN
# october
# Line to replace
# October	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #ICONLOUNGE	-	-	O
# WORD IN TOKEN
# #iconlounge
# Line to replace
# #ICONLOUNGE	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Trinity	-	-	O
# WORD IN TOKEN
# trinity ave
# Line to replace
# Trinity	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Atlanta	-	-	O
# WORD IN TOKEN
# atlanta
# Line to replace
# Atlanta	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Wednesday	-	-	O
# WORD IN TOKEN
# wednesday
# Line to replace
# Wednesday	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1513	-	-	O
# WORD IN TOKEN
# @user1513
# Line to replace
# @USER1513	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1447	-	-	O
# WORD IN TOKEN
# @user1447
# Line to replace
# @USER1447	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1957	-	-	O
# WORD IN TOKEN
# @user1957
# Line to replace
# @USER1957	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1646	-	-	O
# WORD IN TOKEN
# @user1646
# Line to replace
# @USER1646	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# News	-	-	O
# WORD IN TOKEN
# news
# Line to replace
# News	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER617	-	-	O
# WORD IN TOKEN
# @user617
# Line to replace
# @USER617	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# tweet17	-	-	O
# WORD IN TOKEN
# tweet17
# Line to replace
# tweet17	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Datpiff	-	-	O
# WORD IN TOKEN
# #datpiff
# Line to replace
# #Datpiff	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER590	-	-	O
# WORD IN TOKEN
# @user590
# Line to replace
# @USER590	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #AmjadSabari	-	-	O
# WORD IN TOKEN
# #amjadsabari
# Line to replace
# #AmjadSabari	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #PartyWithPatti	-	-	O
# WORD IN TOKEN
# #partywithpatti
# Line to replace
# #PartyWithPatti	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2268	-	-	O
# WORD IN TOKEN
# @user2268
# Line to replace
# @USER2268	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER784	-	-	O
# WORD IN TOKEN
# @user784
# Line to replace
# @USER784	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #hananeelkhader	-	-	O
# WORD IN TOKEN
# #hananeelkhader
# Line to replace
# #hananeelkhader	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER318	-	-	O
# WORD IN TOKEN
# @user318
# Line to replace
# @USER318	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1931	-	-	O
# WORD IN TOKEN
# @user1931
# Line to replace
# @USER1931	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #4thOfJulySales	-	-	O
# WORD IN TOKEN
# #4thofjulysales
# Line to replace
# #4thOfJulySales	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2130	-	-	O
# WORD IN TOKEN
# @user2130
# Line to replace
# @USER2130	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2190	-	-	O
# WORD IN TOKEN
# @user2190
# Line to replace
# @USER2190	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER746	-	-	O
# WORD IN TOKEN
# @user746
# Line to replace
# @USER746	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Jesus	-	-	O
# WORD IN TOKEN
# #jesus
# Line to replace
# #Jesus	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER535	-	-	O
# WORD IN TOKEN
# @user535
# Line to replace
# @USER535	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER540	-	-	O
# WORD IN TOKEN
# @user540
# Line to replace
# @USER540	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1579	-	-	O
# WORD IN TOKEN
# @user1579
# Line to replace
# @USER1579	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2109	-	-	O
# WORD IN TOKEN
# @user2109
# Line to replace
# @USER2109	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #July	-	-	O
# WORD IN TOKEN
# #july
# Line to replace
# #July	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# T/Y	-	-	O
# WORD IN TOKEN
# t/y usher
# Line to replace
# T/Y	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1902	-	-	O
# WORD IN TOKEN
# @user1902
# Line to replace
# @USER1902	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# TeachCode	-	-	O
# WORD IN TOKEN
# teachcode
# Line to replace
# TeachCode	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER256	-	-	O
# WORD IN TOKEN
# @user256
# Line to replace
# @USER256	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2601	-	-	O
# WORD IN TOKEN
# @user2601
# Line to replace
# @USER2601	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Pluto	-	-	O
# WORD IN TOKEN
# pluto
# Line to replace
# Pluto	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER41	-	-	O
# WORD IN TOKEN
# @user41
# Line to replace
# @USER41	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# DUI	-	-	O
# WORD IN TOKEN
# dui
# Line to replace
# DUI	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #TeenChoice	-	-	O
# WORD IN TOKEN
# #teenchoice
# Line to replace
# #TeenChoice	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #ChoiceNextBigThing	-	-	O
# WORD IN TOKEN
# #choicenextbigthing
# Line to replace
# #ChoiceNextBigThing	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# a	-	-	O
# WORD IN TOKEN
# a
# Line to replace
# a	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1230	-	-	O
# WORD IN TOKEN
# @user1230
# Line to replace
# @USER1230	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER624	-	-	O
# WORD IN TOKEN
# @user624
# Line to replace
# @USER624	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1117	-	-	O
# WORD IN TOKEN
# @user1117
# Line to replace
# @USER1117	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# LDR	-	-	O
# WORD IN TOKEN
# ldr
# Line to replace
# LDR	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# CTTO	-	-	O
# WORD IN TOKEN
# ctto
# Line to replace
# CTTO	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #PaloAlto	-	-	O
# WORD IN TOKEN
# #paloalto
# Line to replace
# #PaloAlto	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Prime	-	-	O
# WORD IN TOKEN
# prime minister
# Line to replace
# Prime	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# mf	-	-	O
# WORD IN TOKEN
# mf
# Line to replace
# mf	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1490	-	-	O
# WORD IN TOKEN
# @user1490
# Line to replace
# @USER1490	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1099	-	-	O
# WORD IN TOKEN
# @user1099
# Line to replace
# @USER1099	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2492	-	-	O
# WORD IN TOKEN
# @user2492
# Line to replace
# @USER2492	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1944	-	-	O
# WORD IN TOKEN
# @user1944
# Line to replace
# @USER1944	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1965	-	-	O
# WORD IN TOKEN
# @user1965
# Line to replace
# @USER1965	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER967	-	-	O
# WORD IN TOKEN
# @user967
# Line to replace
# @USER967	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER220	-	-	O
# WORD IN TOKEN
# @user220
# Line to replace
# @USER220	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1640	-	-	O
# WORD IN TOKEN
# @user1640
# Line to replace
# @USER1640	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER106	-	-	O
# WORD IN TOKEN
# @user106
# Line to replace
# @USER106	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# PST	-	-	O
# WORD IN TOKEN
# pst
# Line to replace
# PST	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER837	-	-	O
# WORD IN TOKEN
# @user837
# Line to replace
# @USER837	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Fan	-	-	O
# WORD IN TOKEN
# fan up
# Line to replace
# Fan	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #GregBiffle	-	-	O
# WORD IN TOKEN
# #gregbiffle
# Line to replace
# #GregBiffle	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER81	-	-	O
# WORD IN TOKEN
# @user81
# Line to replace
# @USER81	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER264	-	-	O
# WORD IN TOKEN
# @user264
# Line to replace
# @USER264	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# KIB	-	-	O
# WORD IN TOKEN
# kib
# Line to replace
# KIB	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Q4	-	-	O
# WORD IN TOKEN
# q4
# Line to replace
# Q4	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Rs	-	-	O
# WORD IN TOKEN
# rs
# Line to replace
# Rs	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# IP	-	-	O
# WORD IN TOKEN
# ip
# Line to replace
# IP	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER783	-	-	O
# WORD IN TOKEN
# @user783
# Line to replace
# @USER783	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Tuesday	-	-	O
# WORD IN TOKEN
# tuesday
# Line to replace
# Tuesday	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Oct.	-	-	O
# WORD IN TOKEN
# oct.
# Line to replace
# Oct.	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Brewers	-	-	O
# WORD IN TOKEN
# #brewers minor league
# Line to replace
# #Brewers	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Thurs	-	-	O
# WORD IN TOKEN
# thurs
# Line to replace
# Thurs	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# News	-	-	O
# WORD IN TOKEN
# news
# Line to replace
# News	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Roma	-	-	O
# WORD IN TOKEN
# roma
# Line to replace
# Roma	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER2648	-	-	O
# WORD IN TOKEN
# @user2648
# Line to replace
# @USER2648	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1057	-	-	O
# WORD IN TOKEN
# @user1057
# Line to replace
# @USER1057	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2365	-	-	O
# WORD IN TOKEN
# @user2365
# Line to replace
# @USER2365	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Bloody	-	-	O
# WORD IN TOKEN
# bloody mary
# Line to replace
# Bloody	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2572	-	-	O
# WORD IN TOKEN
# @user2572
# Line to replace
# @USER2572	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER647	-	-	O
# WORD IN TOKEN
# @user647
# Line to replace
# @USER647	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# AP	-	-	O
# WORD IN TOKEN
# ap
# Line to replace
# AP	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER613	-	-	O
# WORD IN TOKEN
# @user613
# Line to replace
# @USER613	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER468	-	-	O
# WORD IN TOKEN
# @user468
# Line to replace
# @USER468	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2515	-	-	O
# WORD IN TOKEN
# @user2515
# Line to replace
# @USER2515	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #LvGIn	-	-	O
# WORD IN TOKEN
# #lvgin
# Line to replace
# #LvGIn	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# todayng	-	-	O
# WORD IN TOKEN
# todayng
# Line to replace
# todayng	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #CaliBernication	-	-	O
# WORD IN TOKEN
# #calibernication
# Line to replace
# #CaliBernication	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #BernieLoveWave	-	-	O
# WORD IN TOKEN
# #bernielovewave
# Line to replace
# #BernieLoveWave	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER328	-	-	O
# WORD IN TOKEN
# @user328
# Line to replace
# @USER328	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Caucus	-	-	O
# WORD IN TOKEN
# caucus
# Line to replace
# Caucus	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# KUNC	-	-	O
# WORD IN TOKEN
# kunc
# Line to replace
# KUNC	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #CherryBay	-	-	O
# WORD IN TOKEN
# #cherrybay party
# Line to replace
# #CherryBay	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER228	-	-	O
# WORD IN TOKEN
# @user228
# Line to replace
# @USER228	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER343	-	-	O
# WORD IN TOKEN
# @user343
# Line to replace
# @USER343	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER529	-	-	O
# WORD IN TOKEN
# @user529
# Line to replace
# @USER529	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1636	-	-	O
# WORD IN TOKEN
# @user1636
# Line to replace
# @USER1636	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1588	-	-	O
# WORD IN TOKEN
# @user1588
# Line to replace
# @USER1588	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER196	-	-	O
# WORD IN TOKEN
# @user196
# Line to replace
# @USER196	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER537	-	-	O
# WORD IN TOKEN
# @user537
# Line to replace
# @USER537	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER280	-	-	O
# WORD IN TOKEN
# @user280
# Line to replace
# @USER280	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER384	-	-	O
# WORD IN TOKEN
# @user384
# Line to replace
# @USER384	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2475	-	-	O
# WORD IN TOKEN
# @user2475
# Line to replace
# @USER2475	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1668	-	-	O
# WORD IN TOKEN
# @user1668
# Line to replace
# @USER1668	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1490	-	-	O
# WORD IN TOKEN
# @user1490
# Line to replace
# @USER1490	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1490	-	-	O
# WORD IN TOKEN
# @user1490
# Line to replace
# @USER1490	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER962	-	-	O
# WORD IN TOKEN
# @user962
# Line to replace
# @USER962	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# AI	-	-	O
# WORD IN TOKEN
# ai
# Line to replace
# AI	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# LIT	-	-	O
# WORD IN TOKEN
# lit
# Line to replace
# LIT	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1840	-	-	O
# WORD IN TOKEN
# @user1840
# Line to replace
# @USER1840	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1510	-	-	O
# WORD IN TOKEN
# @user1510
# Line to replace
# @USER1510	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1092	-	-	O
# WORD IN TOKEN
# @user1092
# Line to replace
# @USER1092	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2369	-	-	O
# WORD IN TOKEN
# @user2369
# Line to replace
# @USER2369	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1147	-	-	O
# WORD IN TOKEN
# @user1147
# Line to replace
# @USER1147	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1091	-	-	O
# WORD IN TOKEN
# @user1091
# Line to replace
# @USER1091	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1207	-	-	O
# WORD IN TOKEN
# @user1207
# Line to replace
# @USER1207	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER63	-	-	O
# WORD IN TOKEN
# @user63
# Line to replace
# @USER63	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2402	-	-	O
# WORD IN TOKEN
# @user2402
# Line to replace
# @USER2402	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1604	-	-	O
# WORD IN TOKEN
# @user1604
# Line to replace
# @USER1604	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER701	-	-	O
# WORD IN TOKEN
# @user701
# Line to replace
# @USER701	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1999	-	-	O
# WORD IN TOKEN
# @user1999
# Line to replace
# @USER1999	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# God	-	-	O
# WORD IN TOKEN
# god
# Line to replace
# God	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1490	-	-	O
# WORD IN TOKEN
# @user1490
# Line to replace
# @USER1490	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# HDWILL	-	-	O
# WORD IN TOKEN
# hdwill ep.
# Line to replace
# HDWILL	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# M51157	-	-	O
# WORD IN TOKEN
# m51157
# Line to replace
# M51157	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1451	-	-	O
# WORD IN TOKEN
# @user1451
# Line to replace
# @USER1451	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1593	-	-	O
# WORD IN TOKEN
# @user1593
# Line to replace
# @USER1593	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Ian	-	-	O
# WORD IN TOKEN
# ian
# Line to replace
# Ian	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1506	-	-	O
# WORD IN TOKEN
# @user1506
# Line to replace
# @USER1506	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2189	-	-	O
# WORD IN TOKEN
# @user2189
# Line to replace
# @USER2189	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER731	-	-	O
# WORD IN TOKEN
# @user731
# Line to replace
# @USER731	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# North	-	-	O
# WORD IN TOKEN
# north
# Line to replace
# North	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# North	-	-	O
# WORD IN TOKEN
# north
# Line to replace
# North	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #LiveWireTV	-	-	O
# WORD IN TOKEN
# #livewiretv
# Line to replace
# #LiveWireTV	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #SLAPTV	-	-	O
# WORD IN TOKEN
# #slaptv
# Line to replace
# #SLAPTV	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1586	-	-	O
# WORD IN TOKEN
# @user1586
# Line to replace
# @USER1586	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1011	-	-	O
# WORD IN TOKEN
# @user1011
# Line to replace
# @USER1011	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #mPLUSPlaces	-	-	O
# WORD IN TOKEN
# #mplusplaces
# Line to replace
# #mPLUSPlaces	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #빅스	-	-	O
# WORD IN TOKEN
# #빅스
# Line to replace
# #빅스	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #vixx	-	-	O
# WORD IN TOKEN
# #vixx
# Line to replace
# #vixx	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2451	-	-	O
# WORD IN TOKEN
# @user2451
# Line to replace
# @USER2451	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2205	-	-	O
# WORD IN TOKEN
# @user2205
# Line to replace
# @USER2205	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2118	-	-	O
# WORD IN TOKEN
# @user2118
# Line to replace
# @USER2118	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1941	-	-	O
# WORD IN TOKEN
# @user1941
# Line to replace
# @USER1941	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1045	-	-	O
# WORD IN TOKEN
# @user1045
# Line to replace
# @USER1045	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER884	-	-	O
# WORD IN TOKEN
# @user884
# Line to replace
# @USER884	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# UN	-	-	O
# WORD IN TOKEN
# un
# Line to replace
# UN	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2311	-	-	O
# WORD IN TOKEN
# @user2311
# Line to replace
# @USER2311	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Associate	-	-	O
# WORD IN TOKEN
# associate
# Line to replace
# Associate	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER677	-	-	O
# WORD IN TOKEN
# @user677
# Line to replace
# @USER677	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER570	-	-	O
# WORD IN TOKEN
# @user570
# Line to replace
# @USER570	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #hocoBOE	-	-	O
# WORD IN TOKEN
# #hocoboe
# Line to replace
# #hocoBOE	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# RTP	-	-	O
# WORD IN TOKEN
# rtp
# Line to replace
# RTP	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Parsippany	-	-	O
# WORD IN TOKEN
# #parsippany
# Line to replace
# #Parsippany	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# lay	-	-	O
# WORD IN TOKEN
# lay
# Line to replace
# lay	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Drum	-	-	O
# WORD IN TOKEN
# drum island during ride
# Line to replace
# Drum	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# MVP	-	-	O
# WORD IN TOKEN
# mvp
# Line to replace
# MVP	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1831	-	-	O
# WORD IN TOKEN
# @user1831
# Line to replace
# @USER1831	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1633	-	-	O
# WORD IN TOKEN
# @user1633
# Line to replace
# @USER1633	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2404	-	-	O
# WORD IN TOKEN
# @user2404
# Line to replace
# @USER2404	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2441	-	-	O
# WORD IN TOKEN
# @user2441
# Line to replace
# @USER2441	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# smith	-	-	O
# WORD IN TOKEN
# smith
# Line to replace
# smith	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER1540	-	-	O
# WORD IN TOKEN
# @user1540
# Line to replace
# @USER1540	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER859	-	-	O
# WORD IN TOKEN
# @user859
# Line to replace
# @USER859	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #TaiChi	-	-	O
# WORD IN TOKEN
# #taichi
# Line to replace
# #TaiChi	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# June	-	-	O
# WORD IN TOKEN
# june
# Line to replace
# June	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Cheeri	-	-	O
# WORD IN TOKEN
# cheeri
# Line to replace
# Cheeri	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Owls	-	-	O
# WORD IN TOKEN
# owls
# Line to replace
# Owls	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1067	-	-	O
# WORD IN TOKEN
# @user1067
# Line to replace
# @USER1067	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Wednesday	-	-	O
# WORD IN TOKEN
# wednesday
# Line to replace
# Wednesday	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER975	-	-	O
# WORD IN TOKEN
# @user975
# Line to replace
# @USER975	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER699	-	-	O
# WORD IN TOKEN
# @user699
# Line to replace
# @USER699	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2318	-	-	O
# WORD IN TOKEN
# @user2318
# Line to replace
# @USER2318	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Tuesday	-	-	O
# WORD IN TOKEN
# tuesday
# Line to replace
# Tuesday	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1661	-	-	O
# WORD IN TOKEN
# @user1661
# Line to replace
# @USER1661	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Mega	-	-	O
# WORD IN TOKEN
# mega
# Line to replace
# Mega	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Topps	-	-	O
# WORD IN TOKEN
# #topps
# Line to replace
# #Topps	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Rookie	-	-	O
# WORD IN TOKEN
# #rookie autograph
# Line to replace
# #Rookie	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# kai	-	-	O
# WORD IN TOKEN
# kai
# Line to replace
# kai	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# kai	-	-	O
# WORD IN TOKEN
# kai
# Line to replace
# kai	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Fab	-	-	O
# WORD IN TOKEN
# fab
# Line to replace
# Fab	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER618	-	-	O
# WORD IN TOKEN
# @user618
# Line to replace
# @USER618	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# ＠Loli	-	-	O
# WORD IN TOKEN
# ＠loli
# Line to replace
# ＠Loli	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# June	-	-	O
# WORD IN TOKEN
# june
# Line to replace
# June	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1235	-	-	O
# WORD IN TOKEN
# @user1235
# Line to replace
# @USER1235	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Aldub	-	-	O
# WORD IN TOKEN
# aldub
# Line to replace
# Aldub	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1586	-	-	O
# WORD IN TOKEN
# @user1586
# Line to replace
# @USER1586	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# @USER1195	-	-	O
# WORD IN TOKEN
# @user1195
# Line to replace
# @USER1195	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Mamamiaaaaaa	-	-	O
# WORD IN TOKEN
# mamamiaaaaaa
# Line to replace
# Mamamiaaaaaa	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER895	-	-	O
# WORD IN TOKEN
# @user895
# Line to replace
# @USER895	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER546	-	-	O
# WORD IN TOKEN
# @user546
# Line to replace
# @USER546	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #HamburgerHelperMixtape	-	-	O
# WORD IN TOKEN
# #hamburgerhelpermixtape
# Line to replace
# #HamburgerHelperMixtape	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER96	-	-	O
# WORD IN TOKEN
# @user96
# Line to replace
# @USER96	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2463	-	-	O
# WORD IN TOKEN
# @user2463
# Line to replace
# @USER2463	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER684	-	-	O
# WORD IN TOKEN
# @user684
# Line to replace
# @USER684	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER389	-	-	O
# WORD IN TOKEN
# @user389
# Line to replace
# @USER389	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER456	-	-	O
# WORD IN TOKEN
# @user456
# Line to replace
# @USER456	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER471	-	-	O
# WORD IN TOKEN
# @user471
# Line to replace
# @USER471	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# GOOOAAAAL	-	-	O
# WORD IN TOKEN
# goooaaaal
# Line to replace
# GOOOAAAAL	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1225	-	-	O
# WORD IN TOKEN
# @user1225
# Line to replace
# @USER1225	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# mrr2	-	-	O
# WORD IN TOKEN
# mrr2
# Line to replace
# mrr2	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER620	-	-	O
# WORD IN TOKEN
# @user620
# Line to replace
# @USER620	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1231	-	-	O
# WORD IN TOKEN
# @user1231
# Line to replace
# @USER1231	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER2136	-	-	O
# WORD IN TOKEN
# @user2136
# Line to replace
# @USER2136	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER596	-	-	O
# WORD IN TOKEN
# @user596
# Line to replace
# @USER596	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# GSM	-	-	O
# WORD IN TOKEN
# gsm
# Line to replace
# GSM	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# KRUSTY	-	-	O
# WORD IN TOKEN
# krusty krayayeah
# Line to replace
# KRUSTY	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Heathway	-	-	O
# WORD IN TOKEN
# #heathway
# Line to replace
# #Heathway	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER109	-	-	O
# WORD IN TOKEN
# @user109
# Line to replace
# @USER109	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# EARTH	-	-	O
# WORD IN TOKEN
# earth
# Line to replace
# EARTH	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# FIRE	-	-	O
# WORD IN TOKEN
# fire
# Line to replace
# FIRE	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# DP1756	-	-	O
# WORD IN TOKEN
# dp1756 ep ws9625
# Line to replace
# DP1756	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER459	-	-	O
# WORD IN TOKEN
# @user459
# Line to replace
# @USER459	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2444	-	-	O
# WORD IN TOKEN
# @user2444
# Line to replace
# @USER2444	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Wednesday	-	-	O
# WORD IN TOKEN
# wednesday
# Line to replace
# Wednesday	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# June	-	-	O
# WORD IN TOKEN
# june
# Line to replace
# June	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2659	-	-	O
# WORD IN TOKEN
# @user2659
# Line to replace
# @USER2659	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1222	-	-	O
# WORD IN TOKEN
# @user1222
# Line to replace
# @USER1222	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER976	-	-	O
# WORD IN TOKEN
# @user976
# Line to replace
# @USER976	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Edo	-	-	O
# WORD IN TOKEN
# edo
# Line to replace
# Edo	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER774	-	-	O
# WORD IN TOKEN
# @user774
# Line to replace
# @USER774	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER2006	-	-	O
# WORD IN TOKEN
# @user2006
# Line to replace
# @USER2006	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER703	-	-	O
# WORD IN TOKEN
# @user703
# Line to replace
# @USER703	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #PokeGoBike	-	-	O
# WORD IN TOKEN
# #pokegobike
# Line to replace
# #PokeGoBike	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Skid	-	-	O
# WORD IN TOKEN
# skid
# Line to replace
# Skid	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1866	-	-	O
# WORD IN TOKEN
# @user1866
# Line to replace
# @USER1866	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1856	-	-	O
# WORD IN TOKEN
# @user1856
# Line to replace
# @USER1856	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER907	-	-	O
# WORD IN TOKEN
# @user907
# Line to replace
# @USER907	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1385	-	-	O
# WORD IN TOKEN
# @user1385
# Line to replace
# @USER1385	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1722	-	-	O
# WORD IN TOKEN
# @user1722
# Line to replace
# @USER1722	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# @USER987	-	-	O
# WORD IN TOKEN
# @user987
# Line to replace
# @USER987	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER50	-	-	O
# WORD IN TOKEN
# @user50
# Line to replace
# @USER50	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2176	-	-	O
# WORD IN TOKEN
# @user2176
# Line to replace
# @USER2176	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# June	-	-	O
# WORD IN TOKEN
# june
# Line to replace
# June	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER1395	-	-	O
# WORD IN TOKEN
# @user1395
# Line to replace
# @USER1395	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2341	-	-	O
# WORD IN TOKEN
# @user2341
# Line to replace
# @USER2341	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2431	-	-	O
# WORD IN TOKEN
# @user2431
# Line to replace
# @USER2431	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Republicans	-	-	O
# WORD IN TOKEN
# #republicans
# Line to replace
# #Republicans	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #StarWars	-	-	O
# WORD IN TOKEN
# #starwars
# Line to replace
# #StarWars	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# PST	-	-	O
# WORD IN TOKEN
# pst
# Line to replace
# PST	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# @USER801	-	-	O
# WORD IN TOKEN
# @user801
# Line to replace
# @USER801	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Goose	-	-	O
# WORD IN TOKEN
# goose
# Line to replace
# Goose	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# sbc9	-	-	O
# WORD IN TOKEN
# sbc9
# Line to replace
# sbc9	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #GauriKhan	-	-	O
# WORD IN TOKEN
# #gaurikhan
# Line to replace
# #GauriKhan	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# @USER2594	-	-	O
# WORD IN TOKEN
# @user2594
# Line to replace
# @USER2594	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER2655	-	-	O
# WORD IN TOKEN
# @user2655
# Line to replace
# @USER2655	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1762	-	-	O
# WORD IN TOKEN
# @user1762
# Line to replace
# @USER1762	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# MT	-	-	O
# WORD IN TOKEN
# mt
# Line to replace
# MT	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# @USER1113	-	-	O
# WORD IN TOKEN
# @user1113
# Line to replace
# @USER1113	-	-	B-PER
# HOW MUCH CHANGED:
# 382
