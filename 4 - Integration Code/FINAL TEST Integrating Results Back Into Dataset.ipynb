# %% [markdown]
# Leung Wai Liu <br>
# JPMorgan AI Research <br>
# August 21, 2022 <br>
# FINAL VERSION - Integrated Results Back Into Dataset TEST

# %%
import pandas as pd
import numpy as np

# %%
original_dataset = pd.read_csv('logs/combined_test_labels_FINAL_NUMBERS.tsv', sep='\t')
original_dataset
# Out:
#      Sentence Index       Word  Start Word Index  End Word Index  POS Label  \
# 0                 1   @user415                11              11  ['PROPN']
# 1                 7  @user1136                11              11  ['PROPN']
# 2                 7        xb1                13              13  ['PROPN']
# 3                 7  @user1071                15              15  ['PROPN']
# 4                 7   @user718                18              18  ['PROPN']
# ..              ...        ...               ...             ...        ...
# 702            1193    ireland                 5               5  ['PROPN']
# 703            1196  @user1311                 0               0  ['PROPN']
# 704            1197  @user1132                 0               0  ['PROPN']
# 705            1197          t                 9               9  ['PROPN']
# 706               0  @user1812                 0               0  ['PROPN']
#
#     NER Label                                              Tweet  \
# 0       ['O']  new unique backpack ! combines vintage with mo...
# 1       ['O']  i 've entered for a chance to win a copy of @u...
# 2       ['O']  i 've entered for a chance to win a copy of @u...
# 3       ['O']  i 've entered for a chance to win a copy of @u...
# 4       ['O']  i 've entered for a chance to win a copy of @u...
# ..        ...                                                ...
# 702     ['O']  rt @user1391 : now northern ireland and polish...
# 703     ['O']  @user1311 if i had one of these i would go bac...
# 704     ['O']  @user1132 gon na have to buy a rico riders t s...
# 705     ['O']  @user1132 gon na have to buy a rico riders t s...
# 706     ['O']  @user1812 no , i 'm not . it 's definitely not...
#
#                                       Tweet POS Labels  \
# 0    ['ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'NOUN'...
# 1    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 2    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 3    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 4    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# ..                                                 ...
# 702  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'PROPN', 'CC...
# 703  ['PROPN', 'SCONJ', 'PRON', 'VERB', 'NUM', 'ADP...
# 704  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
# 705  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
# 706  ['PROPN', 'INTJ', 'PUNCT', 'PRON', 'AUX', 'PAR...
#
#                                       Tweet NER Labels
# 0    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ..                                                 ...
# 702  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...
# 703  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 704  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
# 705  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
# 706  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
# [707 rows x 9 columns]

# %%
original_dataset_users_only = original_dataset[original_dataset['Word'].str.contains("@user")]
original_dataset_users_only
# Out:
#      Sentence Index       Word  Start Word Index  End Word Index  POS Label  \
# 0                 1   @user415                11              11  ['PROPN']
# 1                 7  @user1136                11              11  ['PROPN']
# 3                 7  @user1071                15              15  ['PROPN']
# 4                 7   @user718                18              18  ['PROPN']
# 6                13   @user265                 3               3  ['PROPN']
# ..              ...        ...               ...             ...        ...
# 700            1192   @user450                 6               6  ['PROPN']
# 701            1192  @user1886                 8               8  ['PROPN']
# 703            1196  @user1311                 0               0  ['PROPN']
# 704            1197  @user1132                 0               0  ['PROPN']
# 706               0  @user1812                 0               0  ['PROPN']
#
#     NER Label                                              Tweet  \
# 0       ['O']  new unique backpack ! combines vintage with mo...
# 1       ['O']  i 've entered for a chance to win a copy of @u...
# 3       ['O']  i 've entered for a chance to win a copy of @u...
# 4       ['O']  i 've entered for a chance to win a copy of @u...
# 6       ['O']           rt @user1218 : @user265 blessed sunday 😊
# ..        ...                                                ...
# 700     ['O']  rt @user501 : beach party with @user450 and @u...
# 701     ['O']  rt @user501 : beach party with @user450 and @u...
# 703     ['O']  @user1311 if i had one of these i would go bac...
# 704     ['O']  @user1132 gon na have to buy a rico riders t s...
# 706     ['O']  @user1812 no , i 'm not . it 's definitely not...
#
#                                       Tweet POS Labels  \
# 0    ['ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'NOUN'...
# 1    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 3    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 4    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 6    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# ..                                                 ...
# 700  ['X', 'X', 'PUNCT', 'NOUN', 'NOUN', 'ADP', 'PR...
# 701  ['X', 'X', 'PUNCT', 'NOUN', 'NOUN', 'ADP', 'PR...
# 703  ['PROPN', 'SCONJ', 'PRON', 'VERB', 'NUM', 'ADP...
# 704  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
# 706  ['PROPN', 'INTJ', 'PUNCT', 'PRON', 'AUX', 'PAR...
#
#                                       Tweet NER Labels
# 0    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 6                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ..                                                 ...
# 700  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 701  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 703  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 704  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
# 706  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
# [429 rows x 9 columns]

# %%
original_dataset = original_dataset[~original_dataset['Word'].str.contains("@user")]
original_dataset
# Out:
#      Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                 7       xb1                13              13  ['PROPN']
# 5                12       cod                14              14  ['PROPN']
# 7                13    sunday                 5               5  ['PROPN']
# 9                16    denial                 3               3  ['PROPN']
# 36               50  benadryl                 1               1  ['PROPN']
# ..              ...       ...               ...             ...        ...
# 697            1187        ii                 0               0  ['PROPN']
# 698            1187        ii                 2               2  ['PROPN']
# 699            1187        ii                 8               8  ['PROPN']
# 702            1193   ireland                 5               5  ['PROPN']
# 705            1197         t                 9               9  ['PROPN']
#
#     NER Label                                              Tweet  \
# 2       ['O']  i 've entered for a chance to win a copy of @u...
# 5       ['O']  rt @user2437 : if you have short memory let me...
# 7       ['O']           rt @user1218 : @user265 blessed sunday 😊
# 9       ['O']  " @user1771 : denial has become such a comfort...
# 36      ['O']              @user1039 benadryl is your friend lol
# ..        ...                                                ...
# 697     ['O']  ii guess ii wo n't be getting what ii want ton...
# 698     ['O']  ii guess ii wo n't be getting what ii want ton...
# 699     ['O']  ii guess ii wo n't be getting what ii want ton...
# 702     ['O']  rt @user1391 : now northern ireland and polish...
# 705     ['O']  @user1132 gon na have to buy a rico riders t s...
#
#                                       Tweet POS Labels  \
# 2    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5    ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 9    ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
# 36   ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# ..                                                 ...
# 697  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 698  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 699  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 702  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'PROPN', 'CC...
# 705  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
#
#                                       Tweet NER Labels
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 5    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# 9    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 36                      ['O', 'O', 'O', 'O', 'O', 'O']
# ..                                                 ...
# 697  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 698  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 699  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 702  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...
# 705  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
#
# [278 rows x 9 columns]

# %%
test_agree = pd.read_csv('../FINAL NER Labels/combined_test_agree - combined_test_agree.tsv.tsv', sep='\t')
test_agree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             0   @user415                11              11  ['PROPN']
# 1             4   @user718                18              18  ['PROPN']
# 2             5        cod                14              14  ['PROPN']
# 3             6   @user265                 3               3  ['PROPN']
# 4             8  @user1771                 1               1  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 473         672    ireland                 5               5  ['PROPN']
# 474         673  @user1311                 0               0  ['PROPN']
# 475         674  @user1132                 0               0  ['PROPN']
# 476         675          t                 9               9  ['PROPN']
# 477         676  @user1812                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1         ['PROPN']       ['PROPN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 473       ['PROPN']       ['PROPN']     ['O']              []
# 474       ['PROPN']       ['PROPN']     ['O']              []
# 475       ['PROPN']       ['PROPN']     ['O']              []
# 476        ['NOUN']        ['NOUN']     ['O']              []
# 477       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 2    rt @user2437 : if you have short memory let me...
# 3             rt @user1218 : @user265 blessed sunday 😊
# 4    @user1771 : denial has become such a comfort f...
# ..                                                 ...
# 473  rt @user1391 : now northern ireland and polish...
# 474  @user1311 if i had one of these i would go bac...
# 475  @user1132 gon na have to buy a rico riders t s...
# 476  @user1132 gon na have to buy a rico riders t s...
# 477  @user1812 no , i 'm not . it 's definitely not...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    new unique backpack ! combines vintage with mo...              B-PER
# 1    i 've entered for a chance to win a copy of @u...              B-PER
# 2    rt @user2437 : if you have short memory let me...             B-MISC
# 3         rt @user1218 : <[@user265]> blessed sunday 😊              B-PER
# 4    <[@user1771]> : denial has become such a comfo...              B-PER
# ..                                                 ...                ...
# 473  rt @user1391 : now northern <[ireland]> and po...             B-MISC
# 474  <[@user1311]> if i had one of these i would go...              B-PER
# 475  <[@user1132]> gon na have to buy a rico riders...              B-PER
# 476  @user1132 gon na have to buy a rico riders <[t...                  O
# 477  <[@user1812]> no , i 'm not . it 's definitely...              B-PER
#
#     LW NER LABEL Alec NER LABEL LW Additional Notes
# 0          B-PER          B-PER                 NaN
# 1          B-PER          B-PER                 NaN
# 2         B-MISC         B-MISC                 NaN
# 3          B-PER          B-PER                 NaN
# 4          B-PER          B-PER                 NaN
# ..           ...            ...                 ...
# 473        B-LOC          B-LOC  (fans in context?)
# 474        B-PER          B-PER                 NaN
# 475        B-PER          B-PER                 NaN
# 476            O              O                 NaN
# 477        B-PER          B-PER                 NaN
#
# [478 rows x 15 columns]

# %%
test_agree = test_agree.rename(columns={'LW NER LABEL': 'FINAL NER Label'})
test_agree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             0   @user415                11              11  ['PROPN']
# 1             4   @user718                18              18  ['PROPN']
# 2             5        cod                14              14  ['PROPN']
# 3             6   @user265                 3               3  ['PROPN']
# 4             8  @user1771                 1               1  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 473         672    ireland                 5               5  ['PROPN']
# 474         673  @user1311                 0               0  ['PROPN']
# 475         674  @user1132                 0               0  ['PROPN']
# 476         675          t                 9               9  ['PROPN']
# 477         676  @user1812                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1         ['PROPN']       ['PROPN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 473       ['PROPN']       ['PROPN']     ['O']              []
# 474       ['PROPN']       ['PROPN']     ['O']              []
# 475       ['PROPN']       ['PROPN']     ['O']              []
# 476        ['NOUN']        ['NOUN']     ['O']              []
# 477       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 2    rt @user2437 : if you have short memory let me...
# 3             rt @user1218 : @user265 blessed sunday 😊
# 4    @user1771 : denial has become such a comfort f...
# ..                                                 ...
# 473  rt @user1391 : now northern ireland and polish...
# 474  @user1311 if i had one of these i would go bac...
# 475  @user1132 gon na have to buy a rico riders t s...
# 476  @user1132 gon na have to buy a rico riders t s...
# 477  @user1812 no , i 'm not . it 's definitely not...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    new unique backpack ! combines vintage with mo...              B-PER
# 1    i 've entered for a chance to win a copy of @u...              B-PER
# 2    rt @user2437 : if you have short memory let me...             B-MISC
# 3         rt @user1218 : <[@user265]> blessed sunday 😊              B-PER
# 4    <[@user1771]> : denial has become such a comfo...              B-PER
# ..                                                 ...                ...
# 473  rt @user1391 : now northern <[ireland]> and po...             B-MISC
# 474  <[@user1311]> if i had one of these i would go...              B-PER
# 475  <[@user1132]> gon na have to buy a rico riders...              B-PER
# 476  @user1132 gon na have to buy a rico riders <[t...                  O
# 477  <[@user1812]> no , i 'm not . it 's definitely...              B-PER
#
#     FINAL NER Label Alec NER LABEL LW Additional Notes
# 0             B-PER          B-PER                 NaN
# 1             B-PER          B-PER                 NaN
# 2            B-MISC         B-MISC                 NaN
# 3             B-PER          B-PER                 NaN
# 4             B-PER          B-PER                 NaN
# ..              ...            ...                 ...
# 473           B-LOC          B-LOC  (fans in context?)
# 474           B-PER          B-PER                 NaN
# 475           B-PER          B-PER                 NaN
# 476               O              O                 NaN
# 477           B-PER          B-PER                 NaN
#
# [478 rows x 15 columns]

# %%
test_agree = test_agree.drop('Alec NER LABEL', axis=1)
test_agree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             0   @user415                11              11  ['PROPN']
# 1             4   @user718                18              18  ['PROPN']
# 2             5        cod                14              14  ['PROPN']
# 3             6   @user265                 3               3  ['PROPN']
# 4             8  @user1771                 1               1  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 473         672    ireland                 5               5  ['PROPN']
# 474         673  @user1311                 0               0  ['PROPN']
# 475         674  @user1132                 0               0  ['PROPN']
# 476         675          t                 9               9  ['PROPN']
# 477         676  @user1812                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1         ['PROPN']       ['PROPN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# ..              ...             ...       ...             ...
# 473       ['PROPN']       ['PROPN']     ['O']              []
# 474       ['PROPN']       ['PROPN']     ['O']              []
# 475       ['PROPN']       ['PROPN']     ['O']              []
# 476        ['NOUN']        ['NOUN']     ['O']              []
# 477       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 2    rt @user2437 : if you have short memory let me...
# 3             rt @user1218 : @user265 blessed sunday 😊
# 4    @user1771 : denial has become such a comfort f...
# ..                                                 ...
# 473  rt @user1391 : now northern ireland and polish...
# 474  @user1311 if i had one of these i would go bac...
# 475  @user1132 gon na have to buy a rico riders t s...
# 476  @user1132 gon na have to buy a rico riders t s...
# 477  @user1812 no , i 'm not . it 's definitely not...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    new unique backpack ! combines vintage with mo...              B-PER
# 1    i 've entered for a chance to win a copy of @u...              B-PER
# 2    rt @user2437 : if you have short memory let me...             B-MISC
# 3         rt @user1218 : <[@user265]> blessed sunday 😊              B-PER
# 4    <[@user1771]> : denial has become such a comfo...              B-PER
# ..                                                 ...                ...
# 473  rt @user1391 : now northern <[ireland]> and po...             B-MISC
# 474  <[@user1311]> if i had one of these i would go...              B-PER
# 475  <[@user1132]> gon na have to buy a rico riders...              B-PER
# 476  @user1132 gon na have to buy a rico riders <[t...                  O
# 477  <[@user1812]> no , i 'm not . it 's definitely...              B-PER
#
#     FINAL NER Label LW Additional Notes
# 0             B-PER                 NaN
# 1             B-PER                 NaN
# 2            B-MISC                 NaN
# 3             B-PER                 NaN
# 4             B-PER                 NaN
# ..              ...                 ...
# 473           B-LOC  (fans in context?)
# 474           B-PER                 NaN
# 475           B-PER                 NaN
# 476               O                 NaN
# 477           B-PER                 NaN
#
# [478 rows x 14 columns]

# %%
test_agree_users_only = test_agree[test_agree['Word'].str.contains("@user")]
test_agree_users_only
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             0   @user415                11              11  ['PROPN']
# 1             4   @user718                18              18  ['PROPN']
# 3             6   @user265                 3               3  ['PROPN']
# 4             8  @user1771                 1               1  ['PROPN']
# 5            10  @user1659                 5               5  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 471         670   @user450                 6               6  ['PROPN']
# 472         671  @user1886                 8               8  ['PROPN']
# 474         673  @user1311                 0               0  ['PROPN']
# 475         674  @user1132                 0               0  ['PROPN']
# 477         676  @user1812                 0               0  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0             ['X']           ['X']     ['O']              []
# 1         ['PROPN']       ['PROPN']     ['O']              []
# 3             ['X']           ['X']     ['O']              []
# 4             ['X']           ['X']     ['O']              []
# 5         ['PROPN']       ['PROPN']     ['O']              []
# ..              ...             ...       ...             ...
# 471           ['X']           ['X']     ['O']              []
# 472           ['X']           ['X']     ['O']              []
# 474       ['PROPN']       ['PROPN']     ['O']              []
# 475       ['PROPN']       ['PROPN']     ['O']              []
# 477       ['PROPN']       ['PROPN']     ['O']              []
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 3             rt @user1218 : @user265 blessed sunday 😊
# 4    @user1771 : denial has become such a comfort f...
# 5       #nowplaying get another boyfriend of @user1659
# ..                                                 ...
# 471  rt @user501 : beach party with @user450 and @u...
# 472  rt @user501 : beach party with @user450 and @u...
# 474  @user1311 if i had one of these i would go bac...
# 475  @user1132 gon na have to buy a rico riders t s...
# 477  @user1812 no , i 'm not . it 's definitely not...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    new unique backpack ! combines vintage with mo...              B-PER
# 1    i 've entered for a chance to win a copy of @u...              B-PER
# 3         rt @user1218 : <[@user265]> blessed sunday 😊              B-PER
# 4    <[@user1771]> : denial has become such a comfo...              B-PER
# 5    #nowplaying get another boyfriend of <[@user16...              B-PER
# ..                                                 ...                ...
# 471  rt @user501 : beach party with <[@user450]> an...              B-PER
# 472  rt @user501 : beach party with @user450 and <[...              B-PER
# 474  <[@user1311]> if i had one of these i would go...              B-PER
# 475  <[@user1132]> gon na have to buy a rico riders...              B-PER
# 477  <[@user1812]> no , i 'm not . it 's definitely...              B-PER
#
#     FINAL NER Label LW Additional Notes
# 0             B-PER                 NaN
# 1             B-PER                 NaN
# 3             B-PER                 NaN
# 4             B-PER                 NaN
# 5             B-PER                 NaN
# ..              ...                 ...
# 471           B-PER                 NaN
# 472           B-PER                 NaN
# 474           B-PER                 NaN
# 475           B-PER                 NaN
# 477           B-PER                 NaN
#
# [391 rows x 14 columns]

# %%
test_agree = test_agree[~test_agree['Word'].str.contains("@user")]
test_agree
# Out:
#      Orig Index     Word  Start Word Index  End Word Index  POS Label  \
# 2             5      cod                14              14  ['PROPN']
# 55           61      ww1                12              12  ['PROPN']
# 78           92       hr                14              14  ['PROPN']
# 79           93       pr                17              17  ['PROPN']
# 80           94       lp                 3               3  ['PROPN']
# ..          ...      ...               ...             ...        ...
# 468         667       ii                 0               0  ['PROPN']
# 469         668       ii                 2               2  ['PROPN']
# 470         669       ii                 8               8  ['PROPN']
# 473         672  ireland                 5               5  ['PROPN']
# 476         675        t                 9               9  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 55        ['PROPN']       ['PROPN']     ['O']              []
# 78        ['PROPN']       ['PROPN']     ['O']              []
# 79         ['NOUN']        ['NOUN']     ['O']              []
# 80        ['PROPN']       ['PROPN']     ['O']              []
# ..              ...             ...       ...             ...
# 468           ['X']           ['X']     ['O']              []
# 469        ['PRON']        ['PRON']     ['O']              []
# 470        ['PRON']        ['PRON']     ['O']              []
# 473       ['PROPN']       ['PROPN']     ['O']              []
# 476        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 2    rt @user2437 : if you have short memory let me...
# 55   @user1651 with there boycotts and the way they...
# 78   have #pr pros noticed this like #hr pros have ...
# 79   have #pr pros noticed this like #hr pros have ...
# 80   having lunch at lp with 2 great & funny people...
# ..                                                 ...
# 468  ii guess ii wo n't be getting what ii want ton...
# 469  ii guess ii wo n't be getting what ii want ton...
# 470  ii guess ii wo n't be getting what ii want ton...
# 473  rt @user1391 : now northern ireland and polish...
# 476  @user1132 gon na have to buy a rico riders t s...
#
#                                        Candidate Label PROPOSED NER Label  \
# 2    rt @user2437 : if you have short memory let me...             B-MISC
# 55   @user1651 with there boycotts and the way they...             B-MISC
# 78   have #pr pros noticed this like #hr pros have ...             B-MISC
# 79   have #pr pros noticed this like #hr pros have ...                  O
# 80   having lunch at <[lp]> with 2 great & funny pe...             B-MISC
# ..                                                 ...                ...
# 468  <[ii]> guess ii wo n't be getting what ii want...                  O
# 469  ii guess <[ii]> wo n't be getting what ii want...                  O
# 470  ii guess ii wo n't be getting what <[ii]> want...                  O
# 473  rt @user1391 : now northern <[ireland]> and po...             B-MISC
# 476  @user1132 gon na have to buy a rico riders <[t...                  O
#
#     FINAL NER Label LW Additional Notes
# 2            B-MISC                 NaN
# 55           B-MISC                 NaN
# 78           B-MISC                 NaN
# 79           B-MISC                 NaN
# 80            B-LOC                 NaN
# ..              ...                 ...
# 468               O                 NaN
# 469               O                 NaN
# 470               O                 NaN
# 473           B-LOC  (fans in context?)
# 476               O                 NaN
#
# [87 rows x 14 columns]

# %%
test_disagree = pd.read_csv('../FINAL NER Labels/combined_test_disagree_sorted - combined_test_disagree_filtered.tsv.tsv', sep='\t')
test_disagree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1136                11              11  ['PROPN']
# 1           431   @user285                 8               8  ['PROPN']
# 2           592  @user1942                16              16  ['PROPN']
# 3           169  @user1141                11              11  ['PROPN']
# 4           415  @user1845                24              24  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 148         373   election                10              10  ['PROPN']
# 149         372     stakes                 2               2  ['PROPN']
# 150         345     r30000                21              21  ['PROPN']
# 151         319        ont                18              18  ['PROPN']
# 152         645     qianxi                 7               7  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0         ['PROPN']       ['PROPN']     ['O']              []
# 1          ['NOUN']        ['NOUN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3          ['NOUN']        ['NOUN']     ['O']              []
# 4          ['NOUN']        ['NOUN']     ['O']              []
# ..              ...             ...       ...             ...
# 148        ['NOUN']        ['NOUN']     ['O']              []
# 149        ['NOUN']        ['NOUN']     ['O']              []
# 150        ['NOUN']        ['NOUN']     ['O']              []
# 151           ['X']           ['X']     ['O']              []
# 152        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    i 've entered for a chance to win a copy of @u...
# 1    @user14 follow & rt to #win this stunning @use...
# 2    great thanks to @user2580 for allowing me to a...
# 3    want to stay current on an event or trend ? le...
# 4    looking for a new epilator ? philips satin sof...
# ..                                                 ...
# 148  why the stakes are so high in today ’s rivers ...
# 149  why the stakes are so high in today ’s rivers ...
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...
# 151  @user1547 we ca n't guarantee you 'll get a ne...
# 152  rt @user1283 : { preview } 160404 qianxi @ opp...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    i 've entered for a chance to win a copy of <[...              B-PER
# 1    @user14 follow & rt to #win this stunning <[@u...              B-PER
# 2    great thanks to @user2580 for allowing me to a...              B-PER
# 3    want to stay current on an event or trend ? le...              B-PER
# 4    looking for a new epilator ? philips satin sof...              B-PER
# ..                                                 ...                ...
# 148  why the stakes are so high in today ’s rivers ...                  O
# 149  why the <[stakes]> are so high in today ’s riv...                  O
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...                  O
# 151  @user1547 we ca n't guarantee you 'll get a ne...                  O
# 152  rt @user1283 : { preview } 160404 <[qianxi]> @...                  O
#
#     LW NER LABEL Alec NER LABEL Akshat NER Label  \
# 0         B-MISC          B-PER              NaN
# 1         B-MISC          B-PER              NaN
# 2          B-LOC          B-PER              NaN
# 3          B-ORG          B-PER              NaN
# 4          B-ORG          B-PER              NaN
# ..           ...            ...              ...
# 148            O         B-MISC                O
# 149            O         B-MISC                O
# 150       B-MISC              O           B-MISC
# 151            O         B-MISC                O
# 152        B-LOC              O            B-LOC
#
#                                LW Additional Notes
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 148                                            NaN
# 149                                            NaN
# 150                                            NaN
# 151                                            NaN
# 152  ???NOT SURE LW: Qianxi County, Guizhou, China
#
# [153 rows x 16 columns]

# %%
test_disagree = test_disagree.rename(columns={'Akshat NER Label': 'FINAL NER Label'})
test_disagree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1136                11              11  ['PROPN']
# 1           431   @user285                 8               8  ['PROPN']
# 2           592  @user1942                16              16  ['PROPN']
# 3           169  @user1141                11              11  ['PROPN']
# 4           415  @user1845                24              24  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 148         373   election                10              10  ['PROPN']
# 149         372     stakes                 2               2  ['PROPN']
# 150         345     r30000                21              21  ['PROPN']
# 151         319        ont                18              18  ['PROPN']
# 152         645     qianxi                 7               7  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0         ['PROPN']       ['PROPN']     ['O']              []
# 1          ['NOUN']        ['NOUN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3          ['NOUN']        ['NOUN']     ['O']              []
# 4          ['NOUN']        ['NOUN']     ['O']              []
# ..              ...             ...       ...             ...
# 148        ['NOUN']        ['NOUN']     ['O']              []
# 149        ['NOUN']        ['NOUN']     ['O']              []
# 150        ['NOUN']        ['NOUN']     ['O']              []
# 151           ['X']           ['X']     ['O']              []
# 152        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    i 've entered for a chance to win a copy of @u...
# 1    @user14 follow & rt to #win this stunning @use...
# 2    great thanks to @user2580 for allowing me to a...
# 3    want to stay current on an event or trend ? le...
# 4    looking for a new epilator ? philips satin sof...
# ..                                                 ...
# 148  why the stakes are so high in today ’s rivers ...
# 149  why the stakes are so high in today ’s rivers ...
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...
# 151  @user1547 we ca n't guarantee you 'll get a ne...
# 152  rt @user1283 : { preview } 160404 qianxi @ opp...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    i 've entered for a chance to win a copy of <[...              B-PER
# 1    @user14 follow & rt to #win this stunning <[@u...              B-PER
# 2    great thanks to @user2580 for allowing me to a...              B-PER
# 3    want to stay current on an event or trend ? le...              B-PER
# 4    looking for a new epilator ? philips satin sof...              B-PER
# ..                                                 ...                ...
# 148  why the stakes are so high in today ’s rivers ...                  O
# 149  why the <[stakes]> are so high in today ’s riv...                  O
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...                  O
# 151  @user1547 we ca n't guarantee you 'll get a ne...                  O
# 152  rt @user1283 : { preview } 160404 <[qianxi]> @...                  O
#
#     LW NER LABEL Alec NER LABEL FINAL NER Label  \
# 0         B-MISC          B-PER             NaN
# 1         B-MISC          B-PER             NaN
# 2          B-LOC          B-PER             NaN
# 3          B-ORG          B-PER             NaN
# 4          B-ORG          B-PER             NaN
# ..           ...            ...             ...
# 148            O         B-MISC               O
# 149            O         B-MISC               O
# 150       B-MISC              O          B-MISC
# 151            O         B-MISC               O
# 152        B-LOC              O           B-LOC
#
#                                LW Additional Notes
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 148                                            NaN
# 149                                            NaN
# 150                                            NaN
# 151                                            NaN
# 152  ???NOT SURE LW: Qianxi County, Guizhou, China
#
# [153 rows x 16 columns]

# %%
test_disagree = test_disagree.drop(['LW NER LABEL', 'Alec NER LABEL'], axis=1)
test_disagree
# Out:
#      Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0             1  @user1136                11              11  ['PROPN']
# 1           431   @user285                 8               8  ['PROPN']
# 2           592  @user1942                16              16  ['PROPN']
# 3           169  @user1141                11              11  ['PROPN']
# 4           415  @user1845                24              24  ['PROPN']
# ..          ...        ...               ...             ...        ...
# 148         373   election                10              10  ['PROPN']
# 149         372     stakes                 2               2  ['PROPN']
# 150         345     r30000                21              21  ['PROPN']
# 151         319        ont                18              18  ['PROPN']
# 152         645     qianxi                 7               7  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 0         ['PROPN']       ['PROPN']     ['O']              []
# 1          ['NOUN']        ['NOUN']     ['O']              []
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 3          ['NOUN']        ['NOUN']     ['O']              []
# 4          ['NOUN']        ['NOUN']     ['O']              []
# ..              ...             ...       ...             ...
# 148        ['NOUN']        ['NOUN']     ['O']              []
# 149        ['NOUN']        ['NOUN']     ['O']              []
# 150        ['NOUN']        ['NOUN']     ['O']              []
# 151           ['X']           ['X']     ['O']              []
# 152        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 0    i 've entered for a chance to win a copy of @u...
# 1    @user14 follow & rt to #win this stunning @use...
# 2    great thanks to @user2580 for allowing me to a...
# 3    want to stay current on an event or trend ? le...
# 4    looking for a new epilator ? philips satin sof...
# ..                                                 ...
# 148  why the stakes are so high in today ’s rivers ...
# 149  why the stakes are so high in today ’s rivers ...
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...
# 151  @user1547 we ca n't guarantee you 'll get a ne...
# 152  rt @user1283 : { preview } 160404 qianxi @ opp...
#
#                                        Candidate Label PROPOSED NER Label  \
# 0    i 've entered for a chance to win a copy of <[...              B-PER
# 1    @user14 follow & rt to #win this stunning <[@u...              B-PER
# 2    great thanks to @user2580 for allowing me to a...              B-PER
# 3    want to stay current on an event or trend ? le...              B-PER
# 4    looking for a new epilator ? philips satin sof...              B-PER
# ..                                                 ...                ...
# 148  why the stakes are so high in today ’s rivers ...                  O
# 149  why the <[stakes]> are so high in today ’s riv...                  O
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...                  O
# 151  @user1547 we ca n't guarantee you 'll get a ne...                  O
# 152  rt @user1283 : { preview } 160404 <[qianxi]> @...                  O
#
#     FINAL NER Label                            LW Additional Notes
# 0               NaN                                            NaN
# 1               NaN                                            NaN
# 2               NaN                                            NaN
# 3               NaN                                            NaN
# 4               NaN                                            NaN
# ..              ...                                            ...
# 148               O                                            NaN
# 149               O                                            NaN
# 150          B-MISC                                            NaN
# 151               O                                            NaN
# 152           B-LOC  ???NOT SURE LW: Qianxi County, Guizhou, China
#
# [153 rows x 14 columns]

# %%
test_disagree_users_only = test_disagree[test_disagree['Word'].str.contains("@user")]
test_disagree_users_only
# Out:
#     Orig Index       Word  Start Word Index  End Word Index  POS Label  \
# 0            1  @user1136                11              11  ['PROPN']
# 1          431   @user285                 8               8  ['PROPN']
# 2          592  @user1942                16              16  ['PROPN']
# 3          169  @user1141                11              11  ['PROPN']
# 4          415  @user1845                24              24  ['PROPN']
# 5          410  @user1892                12              12  ['PROPN']
# 6          406   @user584                 6               6  ['PROPN']
# 7          396  @user1490                15              15  ['PROPN']
# 8          214  @user2379                12              12  ['PROPN']
# 9          220  @user1250                16              16  ['PROPN']
# 10         221  @user1950                17              17  ['PROPN']
# 11         222  @user1704                15              15  ['PROPN']
# 12         223   @user760                 9               9  ['PROPN']
# 13         386  @user1123                15              15  ['PROPN']
# 14         559  @user1025                12              12  ['PROPN']
# 15         243  @user1783                 5               5  ['PROPN']
# 16         564  @user2161                 0               0  ['PROPN']
# 17         360   @user174                 1               1  ['PROPN']
# 18         581   @user199                10              10  ['PROPN']
# 19         518   @user194                 0               0  ['PROPN']
# 20         582  @user1711                16              16  ['PROPN']
# 21         283    @user83                17              17  ['PROPN']
# 22         336  @user1061                 4               4  ['PROPN']
# 23         333   @user392                21              21  ['PROPN']
# 25         432     @user7                20              20  ['PROPN']
# 26         423   @user424                 3               3  ['PROPN']
# 27         473  @user1861                 4               4  ['PROPN']
# 28         475   @user960                10              10  ['PROPN']
# 29         531  @user1200                 5               5  ['PROPN']
# 30         490   @user486                20              20  ['PROPN']
# 31         623  @user1049                 8               8  ['PROPN']
# 32          81  @user2503                 0               0  ['PROPN']
# 34         121   @user146                23              23  ['PROPN']
# 35         541   @user421                18              18  ['PROPN']
# 37         448  @user1100                16              16  ['PROPN']
# 38         136  @user1488                 0               0  ['PROPN']
# 39           3  @user1071                15              15  ['PROPN']
# 79          86  @user2147                 6               6  ['PROPN']
#
#    Spacy POS Label Final POS Label NER Label  Spacy NER Label  \
# 0        ['PROPN']       ['PROPN']     ['O']               []
# 1         ['NOUN']        ['NOUN']     ['O']               []
# 2        ['PROPN']       ['PROPN']     ['O']               []
# 3         ['NOUN']        ['NOUN']     ['O']               []
# 4         ['NOUN']        ['NOUN']     ['O']               []
# 5        ['PROPN']       ['PROPN']     ['O']               []
# 6         ['NOUN']        ['NOUN']     ['O']               []
# 7            ['X']           ['X']     ['O']               []
# 8            ['X']           ['X']     ['O']               []
# 9            ['X']           ['X']     ['O']               []
# 10           ['X']           ['X']     ['O']               []
# 11           ['X']           ['X']     ['O']               []
# 12        ['NOUN']        ['NOUN']     ['O']               []
# 13        ['NOUN']        ['NOUN']     ['O']               []
# 14           ['X']           ['X']     ['O']               []
# 15       ['PROPN']       ['PROPN']     ['O']               []
# 16           ['X']           ['X']     ['O']               []
# 17       ['PROPN']       ['PROPN']     ['O']       ['PERSON']
# 18        ['NOUN']        ['NOUN']     ['O']               []
# 19           ['X']           ['X']     ['O']               []
# 20           ['X']           ['X']     ['O']               []
# 21        ['NOUN']        ['NOUN']     ['O']               []
# 22           ['X']           ['X']     ['O']               []
# 23           ['X']           ['X']     ['O']               []
# 25        ['NOUN']        ['NOUN']     ['O']               []
# 26       ['PROPN']       ['PROPN']     ['O']               []
# 27           ['X']           ['X']     ['O']               []
# 28           ['X']           ['X']     ['O']               []
# 29       ['PROPN']       ['PROPN']     ['O']               []
# 30       ['PROPN']       ['PROPN']     ['O']               []
# 31        ['NOUN']        ['NOUN']     ['O']               []
# 32        ['NOUN']        ['NOUN']     ['O']               []
# 34         ['NUM']         ['NUM']     ['O']               []
# 35           ['X']           ['X']     ['O']               []
# 37        ['NOUN']        ['NOUN']     ['O']               []
# 38       ['PROPN']       ['PROPN']     ['O']               []
# 39        ['NOUN']        ['NOUN']     ['O']               []
# 79       ['PROPN']       ['PROPN']     ['O']  ['WORK_OF_ART']
#
#                                                 Tweet  \
# 0   i 've entered for a chance to win a copy of @u...
# 1   @user14 follow & rt to #win this stunning @use...
# 2   great thanks to @user2580 for allowing me to a...
# 3   want to stay current on an event or trend ? le...
# 4   looking for a new epilator ? philips satin sof...
# 5   hey , @user2366 , let 's go on a #datenight to...
# 6   rt @user988 : video : the @user584 staged a li...
# 7   donald trump reads the snake lyric at campaign...
# 8   rt @user2284 : #housing shortages stifle sales...
# 9   rt @user1634 : we want a #newsarunshow with @u...
# 10  rt @user1634 : we want a #newsarunshow with @u...
# 11  rt @user1755 : beer director greg engert getti...
# 12  rt @user916 : found some cool fans at the @use...
# 13  turkey 's erdogan pours cold water on hopes of...
# 14  rt @user1805 : check out my article about darr...
# 15  oh , and regex by @user1783 . do check out the...
# 16  @user2161 but she been a little distant lately...
# 17  hello @user174 , thank you for partnering with...
# 18  rt @user260 : the greatest boyfriend ever prop...
# 19  @user194 #firesidebricky meal . chicken noodle...
# 20  rt @user260 : the greatest boyfriend ever prop...
# 21  iorange -e 10 ft strongest kevlar fiber lightn...
# 22  rt @user2506 : powerful @user1061 piece by tim...
# 23  rt @user211 : first look : virginia madsen ( @...
# 25  @user14 follow & rt to #win this stunning @use...
# 26  rt @user756 : @user424 very proud to be in top...
# 27  rt @user1137 : british @user1861 astronaut #ti...
# 28  rt @user1137 : british @user1861 astronaut #ti...
# 29  rt @user1199 : tonight the @user1200 world tou...
# 30  url844 cadet world team training at harwich , ...
# 31  try this easy chicken cordon bleu #recipe usin...
# 32  @user2503 reportedly testing all - dorito taco...
# 34  rt @user1818 : home opener is 2 days away . ne...
# 35  iron man , the hulk and frozen 's anna arreste...
# 37  rt @user961 : before they tip the #ecf tomorro...
# 38  @user1488 how can my parcel go missing at your...
# 39  i 've entered for a chance to win a copy of @u...
# 79  excited for rough cut screening of @user2147 t...
#
#                                       Candidate Label PROPOSED NER Label  \
# 0   i 've entered for a chance to win a copy of <[...              B-PER
# 1   @user14 follow & rt to #win this stunning <[@u...              B-PER
# 2   great thanks to @user2580 for allowing me to a...              B-PER
# 3   want to stay current on an event or trend ? le...              B-PER
# 4   looking for a new epilator ? philips satin sof...              B-PER
# 5   hey , @user2366 , let 's go on a #datenight to...              B-PER
# 6   rt @user988 : video : the <[@user584]> staged ...              B-PER
# 7   donald trump reads the snake lyric at campaign...              B-PER
# 8   rt @user2284 : #housing shortages stifle sales...              B-PER
# 9   rt @user1634 : we want a #newsarunshow with @u...              B-PER
# 10  rt @user1634 : we want a #newsarunshow with @u...              B-PER
# 11  rt @user1755 : beer director greg engert getti...              B-PER
# 12  rt @user916 : found some cool fans at the <[@u...              B-PER
# 13  turkey 's erdogan pours cold water on hopes of...              B-PER
# 14  rt @user1805 : check out my article about darr...              B-PER
# 15  oh , and regex by <[@user1783]> . do check out...              B-PER
# 16  <[@user2161]> but she been a little distant la...              B-PER
# 17  hello <[@user174]> , thank you for partnering ...              B-PER
# 18  rt @user260 : the greatest boyfriend ever prop...              B-PER
# 19  <[@user194]> #firesidebricky meal . chicken no...              B-PER
# 20  rt @user260 : the greatest boyfriend ever prop...              B-PER
# 21  iorange -e 10 ft strongest kevlar fiber lightn...              B-PER
# 22  rt @user2506 : powerful <[@user1061]> piece by...              B-PER
# 23  rt @user211 : first look : virginia madsen ( @...              B-PER
# 25  @user14 follow & rt to #win this stunning @use...              B-PER
# 26  rt @user756 : <[@user424]> very proud to be in...              B-PER
# 27  rt @user1137 : british <[@user1861]> astronaut...              B-PER
# 28  rt @user1137 : british @user1861 astronaut #ti...              B-PER
# 29  rt @user1199 : tonight the <[@user1200]> world...              B-PER
# 30  url844 cadet world team training at harwich , ...              B-PER
# 31  try this easy chicken cordon bleu #recipe usin...              B-PER
# 32  <[@user2503]> reportedly testing all - dorito ...              B-PER
# 34  rt @user1818 : home opener is 2 days away . ne...              B-PER
# 35  iron man , the hulk and frozen 's anna arreste...              B-PER
# 37  rt @user961 : before they tip the #ecf tomorro...              B-PER
# 38  <[@user1488]> how can my parcel go missing at ...              B-PER
# 39  i 've entered for a chance to win a copy of @u...              B-PER
# 79  excited for rough cut screening of <[@user2147...             B-MISC
#
#    FINAL NER Label LW Additional Notes
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              NaN                 NaN
# 4              NaN                 NaN
# 5              NaN                 NaN
# 6              NaN                 NaN
# 7              NaN                 NaN
# 8              NaN                 NaN
# 9              NaN                 NaN
# 10             NaN                 NaN
# 11             NaN                  TV
# 12             NaN                 NaN
# 13             NaN                 NaN
# 14             NaN                 NaN
# 15             NaN                 NaN
# 16             NaN                 NaN
# 17             NaN                 NaN
# 18             NaN                 NaN
# 19             NaN                 NaN
# 20             NaN                 NaN
# 21             NaN                 NaN
# 22             NaN                 NaN
# 23             NaN                 NaN
# 25             NaN                 NaN
# 26             NaN                 NaN
# 27             NaN                 NaN
# 28             NaN                 NaN
# 29             NaN                 NaN
# 30             NaN                 NaN
# 31             NaN                 NaN
# 32             NaN                 NaN
# 34             NaN                 NaN
# 35             NaN                 NaN
# 37             NaN                 NaN
# 38             NaN                 NaN
# 39             NaN                 NaN
# 79             NaN                 NaN

# %%
print(len(test_disagree_users_only))
# Out:
# 38

# %%
test_disagree = test_disagree[~test_disagree['Word'].str.contains("@user")]
test_disagree
# Out:
#      Orig Index        Word  Start Word Index  End Word Index  POS Label  \
# 24          600    #murdoch                18              18  ['PROPN']
# 33           80    #robford                 4               4  ['PROPN']
# 36          496    #eleague                 1               1  ['PROPN']
# 40          253  #vozempire                 0               0  ['PROPN']
# 41          142         cpa                 7               7  ['PROPN']
# ..          ...         ...               ...             ...        ...
# 148         373    election                10              10  ['PROPN']
# 149         372      stakes                 2               2  ['PROPN']
# 150         345      r30000                21              21  ['PROPN']
# 151         319         ont                18              18  ['PROPN']
# 152         645      qianxi                 7               7  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 24        ['PROPN']       ['PROPN']     ['O']      ['PERSON']
# 33        ['PROPN']       ['PROPN']     ['O']      ['PERSON']
# 36        ['PROPN']       ['PROPN']     ['O']      ['PERSON']
# 40        ['PROPN']       ['PROPN']     ['O']         ['ORG']
# 41        ['PROPN']       ['PROPN']     ['O']         ['ORG']
# ..              ...             ...       ...             ...
# 148        ['NOUN']        ['NOUN']     ['O']              []
# 149        ['NOUN']        ['NOUN']     ['O']              []
# 150        ['NOUN']        ['NOUN']     ['O']              []
# 151           ['X']           ['X']     ['O']              []
# 152        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 24   no emergency budget , no activating article 50...
# 33   @user2337 talking points ? #robford has a new ...
# 36          csgo #eleague live on #tbs !!!!!!! url1571
# 40   #vozempire : ready to divorce ? david beckham ...
# 41   14221 started on 08/05/2016 reached its destin...
# ..                                                 ...
# 148  why the stakes are so high in today ’s rivers ...
# 149  why the stakes are so high in today ’s rivers ...
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...
# 151  @user1547 we ca n't guarantee you 'll get a ne...
# 152  rt @user1283 : { preview } 160404 qianxi @ opp...
#
#                                        Candidate Label PROPOSED NER Label  \
# 24   no emergency budget , no activating article 50...              B-PER
# 33   @user2337 talking points ? <[#robford]> has a ...              B-PER
# 36      csgo <[#eleague]> live on #tbs !!!!!!! url1571              B-PER
# 40   <[#vozempire]> : ready to divorce ? david beck...              B-ORG
# 41   14221 started on 08/05/2016 reached its destin...              B-ORG
# ..                                                 ...                ...
# 148  why the stakes are so high in today ’s rivers ...                  O
# 149  why the <[stakes]> are so high in today ’s riv...                  O
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...                  O
# 151  @user1547 we ca n't guarantee you 'll get a ne...                  O
# 152  rt @user1283 : { preview } 160404 <[qianxi]> @...                  O
#
#     FINAL NER Label                                LW Additional Notes
# 24            B-PER  ??? - LW: Rupert Murdoch - head of the FOX Med...
# 33            B-PER                                                NaN
# 36           B-MISC                                                NaN
# 40            B-ORG                                                NaN
# 41            B-ORG  ??? - LW: based on context, might be Cathay Pa...
# ..              ...                                                ...
# 148               O                                                NaN
# 149               O                                                NaN
# 150          B-MISC                                                NaN
# 151               O                                                NaN
# 152           B-LOC      ???NOT SURE LW: Qianxi County, Guizhou, China
#
# [115 rows x 14 columns]

# %%
test_relabelled_frames = [test_agree, test_disagree]
test_relabelled = pd.concat(test_relabelled_frames)
test_relabelled
# Out:
#      Orig Index      Word  Start Word Index  End Word Index  POS Label  \
# 2             5       cod                14              14  ['PROPN']
# 55           61       ww1                12              12  ['PROPN']
# 78           92        hr                14              14  ['PROPN']
# 79           93        pr                17              17  ['PROPN']
# 80           94        lp                 3               3  ['PROPN']
# ..          ...       ...               ...             ...        ...
# 148         373  election                10              10  ['PROPN']
# 149         372    stakes                 2               2  ['PROPN']
# 150         345    r30000                21              21  ['PROPN']
# 151         319       ont                18              18  ['PROPN']
# 152         645    qianxi                 7               7  ['PROPN']
#
#     Spacy POS Label Final POS Label NER Label Spacy NER Label  \
# 2         ['PROPN']       ['PROPN']     ['O']              []
# 55        ['PROPN']       ['PROPN']     ['O']              []
# 78        ['PROPN']       ['PROPN']     ['O']              []
# 79         ['NOUN']        ['NOUN']     ['O']              []
# 80        ['PROPN']       ['PROPN']     ['O']              []
# ..              ...             ...       ...             ...
# 148        ['NOUN']        ['NOUN']     ['O']              []
# 149        ['NOUN']        ['NOUN']     ['O']              []
# 150        ['NOUN']        ['NOUN']     ['O']              []
# 151           ['X']           ['X']     ['O']              []
# 152        ['NOUN']        ['NOUN']     ['O']              []
#
#                                                  Tweet  \
# 2    rt @user2437 : if you have short memory let me...
# 55   @user1651 with there boycotts and the way they...
# 78   have #pr pros noticed this like #hr pros have ...
# 79   have #pr pros noticed this like #hr pros have ...
# 80   having lunch at lp with 2 great & funny people...
# ..                                                 ...
# 148  why the stakes are so high in today ’s rivers ...
# 149  why the stakes are so high in today ’s rivers ...
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...
# 151  @user1547 we ca n't guarantee you 'll get a ne...
# 152  rt @user1283 : { preview } 160404 qianxi @ opp...
#
#                                        Candidate Label PROPOSED NER Label  \
# 2    rt @user2437 : if you have short memory let me...             B-MISC
# 55   @user1651 with there boycotts and the way they...             B-MISC
# 78   have #pr pros noticed this like #hr pros have ...             B-MISC
# 79   have #pr pros noticed this like #hr pros have ...                  O
# 80   having lunch at <[lp]> with 2 great & funny pe...             B-MISC
# ..                                                 ...                ...
# 148  why the stakes are so high in today ’s rivers ...                  O
# 149  why the <[stakes]> are so high in today ’s riv...                  O
# 150  rt @user33 : 5000 #thenextgalaxy retweets in 3...                  O
# 151  @user1547 we ca n't guarantee you 'll get a ne...                  O
# 152  rt @user1283 : { preview } 160404 <[qianxi]> @...                  O
#
#     FINAL NER Label                            LW Additional Notes
# 2            B-MISC                                            NaN
# 55           B-MISC                                            NaN
# 78           B-MISC                                            NaN
# 79           B-MISC                                            NaN
# 80            B-LOC                                            NaN
# ..              ...                                            ...
# 148               O                                            NaN
# 149               O                                            NaN
# 150          B-MISC                                            NaN
# 151               O                                            NaN
# 152           B-LOC  ???NOT SURE LW: Qianxi County, Guizhou, China
#
# [202 rows x 14 columns]

# %%
original_dataset_merged = original_dataset.copy()
original_dataset_merged['PROPOSED NER Label'] = np.nan
original_dataset_merged['FINAL NER Label'] = np.nan
original_dataset_merged
# Out:
#      Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                 7       xb1                13              13  ['PROPN']
# 5                12       cod                14              14  ['PROPN']
# 7                13    sunday                 5               5  ['PROPN']
# 9                16    denial                 3               3  ['PROPN']
# 36               50  benadryl                 1               1  ['PROPN']
# ..              ...       ...               ...             ...        ...
# 697            1187        ii                 0               0  ['PROPN']
# 698            1187        ii                 2               2  ['PROPN']
# 699            1187        ii                 8               8  ['PROPN']
# 702            1193   ireland                 5               5  ['PROPN']
# 705            1197         t                 9               9  ['PROPN']
#
#     NER Label                                              Tweet  \
# 2       ['O']  i 've entered for a chance to win a copy of @u...
# 5       ['O']  rt @user2437 : if you have short memory let me...
# 7       ['O']           rt @user1218 : @user265 blessed sunday 😊
# 9       ['O']  " @user1771 : denial has become such a comfort...
# 36      ['O']              @user1039 benadryl is your friend lol
# ..        ...                                                ...
# 697     ['O']  ii guess ii wo n't be getting what ii want ton...
# 698     ['O']  ii guess ii wo n't be getting what ii want ton...
# 699     ['O']  ii guess ii wo n't be getting what ii want ton...
# 702     ['O']  rt @user1391 : now northern ireland and polish...
# 705     ['O']  @user1132 gon na have to buy a rico riders t s...
#
#                                       Tweet POS Labels  \
# 2    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5    ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 9    ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
# 36   ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# ..                                                 ...
# 697  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 698  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 699  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 702  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'PROPN', 'CC...
# 705  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
#
#                                       Tweet NER Labels  PROPOSED NER Label  \
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 5    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']                 NaN
# 9    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 36                      ['O', 'O', 'O', 'O', 'O', 'O']                 NaN
# ..                                                 ...                 ...
# 697  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 698  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 699  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 NaN
# 702  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...                 NaN
# 705  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                 NaN
#
#      FINAL NER Label
# 2                NaN
# 5                NaN
# 7                NaN
# 9                NaN
# 36               NaN
# ..               ...
# 697              NaN
# 698              NaN
# 699              NaN
# 702              NaN
# 705              NaN
#
# [278 rows x 11 columns]

# %%
how_many_merged = 0
how_many_not_merged = 0
for index, row in original_dataset_merged.iterrows():

    search_row = test_relabelled.loc[(test_relabelled['Word'] == row['Word']) & (test_relabelled['Start Word Index'] == row['Start Word Index']) & (test_relabelled['End Word Index'] == row['End Word Index']) & (test_relabelled['Tweet'] == row['Tweet'])]
    if len(search_row) != 0:
        original_dataset_merged.loc[index, 'PROPOSED NER Label'] = search_row.iloc[0]['PROPOSED NER Label']
        original_dataset_merged.loc[index, 'FINAL NER Label'] = search_row.iloc[0]['FINAL NER Label']
        how_many_merged += 1
    else:
        how_many_not_merged += 1

print("HOW MANY MERGED:", how_many_merged)
print("HOW MANY NOT MERGED:", how_many_not_merged)
# Out:
# HOW MANY MERGED: 201
# HOW MANY NOT MERGED: 77

# %%
how_many_actually_merged = 0
how_many_actually_not_merged = 0
for index, row in test_relabelled.iterrows():

    search_row = original_dataset_merged.loc[(original_dataset_merged['Word'] == row['Word']) & (original_dataset_merged['Start Word Index'] == row['Start Word Index']) & (original_dataset_merged['End Word Index'] == row['End Word Index']) & (original_dataset_merged['Tweet'] == row['Tweet'])]
    if len(search_row) != 0:
        if (~search_row['FINAL NER Label'].any()):
            how_many_actually_not_merged += 1
            print(row)
        else:
            how_many_actually_merged += 1
    else:
        how_many_actually_not_merged += 1
        print(row)

print("HOW MANY MERGED:", how_many_actually_merged)
print("HOW MANY NOT MERGED:", how_many_actually_not_merged)
# Out:
# Orig Index                                                             9
# Word                                                              denial
# Start Word Index                                                       3
# End Word Index                                                         3
# POS Label                                                      ['PROPN']
# Spacy POS Label                                                 ['NOUN']
# Final POS Label                                                 ['NOUN']
# NER Label                                                          ['O']
# Spacy NER Label                                                       []
# Tweet                  @user1771 : denial has become such a comfort f...
# Candidate Label        @user1771 : <[denial]> has become such a comfo...
# PROPOSED NER Label                                                     O
# FINAL NER Label                                                        O
# LW Additional Notes                                                  NaN
# Name: 129, dtype: object
# HOW MANY MERGED: 201
# HOW MANY NOT MERGED: 1

# %%
search_missing_row = original_dataset_merged.loc[original_dataset_merged['Word'] == 'denial']
search_missing_row
# Out:
#    Sentence Index    Word  Start Word Index  End Word Index  POS Label  \
# 9              16  denial                 3               3  ['PROPN']
#
#   NER Label                                              Tweet  \
# 9     ['O']  " @user1771 : denial has become such a comfort...
#
#                                     Tweet POS Labels  \
# 9  ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
#
#                                     Tweet NER Labels PROPOSED NER Label  \
# 9  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
#
#   FINAL NER Label
# 9             NaN

# %%
original_dataset_merged.loc[9, 'PROPOSED NER Label'] = 'O'
original_dataset_merged.loc[9, 'FINAL NER Label'] = 'O'

# %% [markdown]
# # search_missing_row = original_dataset_merged.loc[original_dataset_merged['Word'] == 'denial']
# search_missing_row

# %%
original_dataset_merged
# Out:
#      Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                 7       xb1                13              13  ['PROPN']
# 5                12       cod                14              14  ['PROPN']
# 7                13    sunday                 5               5  ['PROPN']
# 9                16    denial                 3               3  ['PROPN']
# 36               50  benadryl                 1               1  ['PROPN']
# ..              ...       ...               ...             ...        ...
# 697            1187        ii                 0               0  ['PROPN']
# 698            1187        ii                 2               2  ['PROPN']
# 699            1187        ii                 8               8  ['PROPN']
# 702            1193   ireland                 5               5  ['PROPN']
# 705            1197         t                 9               9  ['PROPN']
#
#     NER Label                                              Tweet  \
# 2       ['O']  i 've entered for a chance to win a copy of @u...
# 5       ['O']  rt @user2437 : if you have short memory let me...
# 7       ['O']           rt @user1218 : @user265 blessed sunday 😊
# 9       ['O']  " @user1771 : denial has become such a comfort...
# 36      ['O']              @user1039 benadryl is your friend lol
# ..        ...                                                ...
# 697     ['O']  ii guess ii wo n't be getting what ii want ton...
# 698     ['O']  ii guess ii wo n't be getting what ii want ton...
# 699     ['O']  ii guess ii wo n't be getting what ii want ton...
# 702     ['O']  rt @user1391 : now northern ireland and polish...
# 705     ['O']  @user1132 gon na have to buy a rico riders t s...
#
#                                       Tweet POS Labels  \
# 2    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5    ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 9    ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
# 36   ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# ..                                                 ...
# 697  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 698  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 699  ['PROPN', 'VERB', 'PROPN', 'AUX', 'PART', 'AUX...
# 702  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'PROPN', 'CC...
# 705  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
#
#                                       Tweet NER Labels PROPOSED NER Label  \
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 5    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 9    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 36                      ['O', 'O', 'O', 'O', 'O', 'O']             B-MISC
# ..                                                 ...                ...
# 697  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 698  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 699  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 702  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...             B-MISC
# 705  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                  O
#
#     FINAL NER Label
# 2             B-ORG
# 5            B-MISC
# 7               NaN
# 9                 O
# 36           B-MISC
# ..              ...
# 697               O
# 698               O
# 699               O
# 702           B-LOC
# 705               O
#
# [278 rows x 11 columns]

# %%
#sanity check
original_dataset_merged_empty_single = original_dataset_merged[(~original_dataset_merged['FINAL NER Label'].notnull()) & (original_dataset_merged['Start Word Index'] == original_dataset_merged['End Word Index'])]
original_dataset_merged_empty_single
# Out:
#      Sentence Index                     Word  Start Word Index  \
# 7                13                   sunday                 5
# 87               94                   frisco                 8
# 89              105                gothtober                 0
# 101             128                  october                10
# 130             186                  january                 7
# 157             260                 february                 9
# 158             260                    march                12
# 164             264                      est                 2
# 184             291                      feb                 4
# 185             291                      feb                12
# 195             301                 #grammys                 4
# 217             343                september                15
# 248             415           #kanhaiyakumar                 3
# 249             415                     feb.                 8
# 260             450                    sames                 0
# 274             481                     july                 7
# 301             528                 saturday                 7
# 302             528                   sunday                 9
# 342             602                      est                22
# 343             602                      pst                25
# 368             633                    april                11
# 369             633                    april                22
# 378             653                    april                24
# 380             656                  #arctic                17
# 392             669                  october                 4
# 394             671                     july                 6
# 420             731                   friday                 9
# 421             733                       pm                15
# 442             782                 thursday                21
# 483             838               #indiegame                23
# 514             904                 thursday                 8
# 515             904                      may                10
# 554             961                  america                12
# 556             966                   #av/it                 9
# 557             966                      aug                13
# 559             967             #july4canada                 6
# 588            1021                     july                 7
# 590            1022                       pm                 2
# 595            1031                september                13
# 642            1100                     july                19
# 661            1131                     #sja                 5
# 662            1131  #medicalfirstresponders                 6
# 663            1131                 #ontario                 7
# 664            1131            #championship                 8
# 678            1150           #hellomynameis                13
# 694            1179                      feb                10
#
#      End Word Index  POS Label NER Label  \
# 7                 5  ['PROPN']     ['O']
# 87                8  ['PROPN']     ['O']
# 89                0  ['PROPN']     ['O']
# 101              10  ['PROPN']     ['O']
# 130               7  ['PROPN']     ['O']
# 157               9  ['PROPN']     ['O']
# 158              12  ['PROPN']     ['O']
# 164               2  ['PROPN']     ['O']
# 184               4  ['PROPN']     ['O']
# 185              12  ['PROPN']     ['O']
# 195               4  ['PROPN']     ['O']
# 217              15  ['PROPN']     ['O']
# 248               3  ['PROPN']     ['O']
# 249               8  ['PROPN']     ['O']
# 260               0  ['PROPN']     ['O']
# 274               7  ['PROPN']     ['O']
# 301               7  ['PROPN']     ['O']
# 302               9  ['PROPN']     ['O']
# 342              22  ['PROPN']     ['O']
# 343              25  ['PROPN']     ['O']
# 368              11  ['PROPN']     ['O']
# 369              22  ['PROPN']     ['O']
# 378              24  ['PROPN']     ['O']
# 380              17  ['PROPN']     ['O']
# 392               4  ['PROPN']     ['O']
# 394               6  ['PROPN']     ['O']
# 420               9  ['PROPN']     ['O']
# 421              15  ['PROPN']     ['O']
# 442              21  ['PROPN']     ['O']
# 483              23  ['PROPN']     ['O']
# 514               8  ['PROPN']     ['O']
# 515              10  ['PROPN']     ['O']
# 554              12  ['PROPN']     ['O']
# 556               9  ['PROPN']     ['O']
# 557              13  ['PROPN']     ['O']
# 559               6  ['PROPN']     ['O']
# 588               7  ['PROPN']     ['O']
# 590               2  ['PROPN']     ['O']
# 595              13  ['PROPN']     ['O']
# 642              19  ['PROPN']     ['O']
# 661               5  ['PROPN']     ['O']
# 662               6  ['PROPN']     ['O']
# 663               7  ['PROPN']     ['O']
# 664               8  ['PROPN']     ['O']
# 678              13  ['PROPN']     ['O']
# 694              10  ['PROPN']     ['O']
#
#                                                  Tweet  \
# 7             rt @user1218 : @user265 blessed sunday 😊
# 87   check out cooking how - to : homemade frisco m...
# 89                               gothtober #blanktober
# 101  i posted 11 photos on facebook in the album " ...
# 130  the heat wo n't be ready itil january but we will
# 157  { ghyr rewind } new release round - up februar...
# 158  { ghyr rewind } new release round - up februar...
# 164  7 pm est / 1 am cest - #glitch label takeover ...
# 184  rt @user201 : 14th feb 2015 : world cup first ...
# 185  rt @user201 : 14th feb 2015 : world cup first ...
# 195  rt @user98 : the #grammys red carpet will last...
# 217  rt @user326 : gucci mane is going on tour afte...
# 248  rt @user2409 : #kanhaiyakumar bail plea #adjou...
# 249  rt @user2409 : #kanhaiyakumar bail plea #adjou...
# 260                                      sames url1428
# 274  " sorry i ca n't work on july 9th because ever...
# 301  rt @user2477 : things that happened last satur...
# 302  rt @user2477 : things that happened last satur...
# 342  rt @user1131 : hey ! new music video tomorrow ...
# 343  rt @user1131 : hey ! new music video tomorrow ...
# 368  rt @user630 : the first picture is chicago at ...
# 369  rt @user630 : the first picture is chicago at ...
# 378  #cinobservatory #ohwx : temp : -0.28 °c , hum ...
# 380  rt @user522 : “ it ’s a red flag ” — polar bea...
# 392  rt @user28 : on october 7 • fifth harmony will...
# 394  @user879 last time i checked . july 22nd is in...
# 420  @user54 thanks for sharing ---==adamcsmith==--...
# 421  rt @user95 : dear leaders of the opposition ! ...
# 442  rt @user756 : @user424 very proud to be in top...
# 483  rt @user852 : new patch will be live tomorrow ...
# 514  exclusive first look at cross border vat on th...
# 515  exclusive first look at cross border vat on th...
# 554  rt @user1275 : @user737 @user1807 i like that ...
# 556  rt @user1150 : qualify for a place at the #av/...
# 557  rt @user1150 : qualify for a place at the #av/...
# 559  @user203 waiting for buses to celebrate #july4...
# 588  rt @user1879 : need extra cash for july 4 week...
# 590  @user1112 : pm @user351 struggles to secure eu...
# 595  rt @user524 : grey 's anatomy season 13 is exp...
# 642  @user1420 was n't sure if you posted about thi...
# 661  congratulations to @user1154 for winning #sja ...
# 662  congratulations to @user1154 for winning #sja ...
# 663  congratulations to @user1154 for winning #sja ...
# 664  congratulations to @user1154 for winning #sja ...
# 678  rt @user518 : so proud of how hard @user770 ha...
# 694  ddo woman living with mould / collapsed ceilin...
#
#                                       Tweet POS Labels  \
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 87   ['VERB', 'ADP', 'NOUN', 'NOUN', 'PUNCT', 'NOUN...
# 89                                      ['PROPN', 'X']
# 101  ['PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'PROPN'...
# 130  ['DET', 'NOUN', 'AUX', 'PART', 'AUX', 'ADJ', '...
# 157  ['PUNCT', 'PROPN', 'VERB', 'PUNCT', 'ADJ', 'NO...
# 158  ['PUNCT', 'PROPN', 'VERB', 'PUNCT', 'ADJ', 'NO...
# 164  ['NUM', 'NOUN', 'PROPN', 'PUNCT', 'NUM', 'NOUN...
# 184  ['X', 'X', 'PUNCT', 'NOUN', 'PROPN', 'NUM', 'P...
# 185  ['X', 'X', 'PUNCT', 'NOUN', 'PROPN', 'NUM', 'P...
# 195  ['X', 'X', 'PUNCT', 'DET', 'PROPN', 'ADJ', 'NO...
# 217  ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'AUX', '...
# 248  ['X', 'X', 'PUNCT', 'PROPN', 'NOUN', 'NOUN', '...
# 249  ['X', 'X', 'PUNCT', 'PROPN', 'NOUN', 'NOUN', '...
# 260                                     ['PROPN', 'X']
# 274  ['PUNCT', 'INTJ', 'PRON', 'AUX', 'PART', 'VERB...
# 301  ['X', 'X', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'A...
# 302  ['X', 'X', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'A...
# 342  ['X', 'X', 'PUNCT', 'INTJ', 'PUNCT', 'ADJ', 'N...
# 343  ['X', 'X', 'PUNCT', 'INTJ', 'PUNCT', 'ADJ', 'N...
# 368  ['X', 'X', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX...
# 369  ['X', 'X', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX...
# 378  ['X', 'X', 'PUNCT', 'NOUN', 'PUNCT', 'NUM', 'S...
# 380  ['X', 'X', 'PUNCT', 'PUNCT', 'PRON', 'AUX', 'D...
# 392  ['X', 'X', 'PUNCT', 'ADP', 'PROPN', 'NUM', 'PU...
# 394  ['PROPN', 'ADJ', 'NOUN', 'PRON', 'VERB', 'PUNC...
# 420  ['PROPN', 'NOUN', 'SCONJ', 'VERB', 'PROPN', 'P...
# 421  ['X', 'X', 'PUNCT', 'ADJ', 'NOUN', 'ADP', 'DET...
# 442  ['X', 'X', 'PUNCT', 'PROPN', 'ADV', 'ADJ', 'PA...
# 483  ['X', 'X', 'PUNCT', 'ADJ', 'NOUN', 'AUX', 'AUX...
# 514  ['ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', ...
# 515  ['ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', ...
# 554  ['X', 'X', 'PUNCT', 'X', 'X', 'PRON', 'VERB', ...
# 556  ['X', 'X', 'PUNCT', 'VERB', 'ADP', 'DET', 'NOU...
# 557  ['X', 'X', 'PUNCT', 'VERB', 'ADP', 'DET', 'NOU...
# 559  ['PROPN', 'VERB', 'ADP', 'NOUN', 'PART', 'VERB...
# 588  ['X', 'X', 'PUNCT', 'VERB', 'ADJ', 'NOUN', 'AD...
# 590  ['PROPN', 'PUNCT', 'PROPN', 'PROPN', 'VERB', '...
# 595  ['X', 'X', 'PUNCT', 'PROPN', 'PART', 'PROPN', ...
# 642  ['PROPN', 'AUX', 'PART', 'ADJ', 'SCONJ', 'PRON...
# 661  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 662  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 663  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 664  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 678  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'SCONJ', 'AD...
# 694  ['PROPN', 'NOUN', 'VERB', 'ADP', 'NOUN', 'PUNC...
#
#                                       Tweet NER Labels PROPOSED NER Label  \
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 87   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 89                                          ['O', 'O']                NaN
# 101  ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', '...                NaN
# 130  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 157  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 158  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 164  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 184  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...                NaN
# 185  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...                NaN
# 195  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 217  ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O...                NaN
# 248  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 249  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 260                                         ['O', 'O']                NaN
# 274  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 301  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 302  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 342  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 343  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 368  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', '...                NaN
# 369  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', '...                NaN
# 378  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 380  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 392  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                NaN
# 394  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 420  ['O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', '...                NaN
# 421  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 442  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 483  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 514  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MI...                NaN
# 515  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MI...                NaN
# 554  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 556  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 557  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 559           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 588  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 590  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                NaN
# 595  ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', ...                NaN
# 642  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 661  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 662  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 663  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 664  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 678  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 694  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
#
#     FINAL NER Label
# 7               NaN
# 87              NaN
# 89              NaN
# 101             NaN
# 130             NaN
# 157             NaN
# 158             NaN
# 164             NaN
# 184             NaN
# 185             NaN
# 195             NaN
# 217             NaN
# 248             NaN
# 249             NaN
# 260             NaN
# 274             NaN
# 301             NaN
# 302             NaN
# 342             NaN
# 343             NaN
# 368             NaN
# 369             NaN
# 378             NaN
# 380             NaN
# 392             NaN
# 394             NaN
# 420             NaN
# 421             NaN
# 442             NaN
# 483             NaN
# 514             NaN
# 515             NaN
# 554             NaN
# 556             NaN
# 557             NaN
# 559             NaN
# 588             NaN
# 590             NaN
# 595             NaN
# 642             NaN
# 661             NaN
# 662             NaN
# 663             NaN
# 664             NaN
# 678             NaN
# 694             NaN

# %%
original_dataset_merged.loc[87, 'PROPOSED NER Label'] = 'B-MISC'
original_dataset_merged.loc[87, 'FINAL NER Label'] = 'B-MISC'

original_dataset_merged.loc[89, 'PROPOSED NER Label'] = 'B-MISC'
original_dataset_merged.loc[89, 'FINAL NER Label'] = 'B-MISC'

original_dataset_merged.loc[195, 'PROPOSED NER Label'] = 'B-MISC'
original_dataset_merged.loc[195, 'FINAL NER Label'] = 'B-MISC'

original_dataset_merged.loc[248, 'PROPOSED NER Label'] = 'B-PER'
original_dataset_merged.loc[248, 'FINAL NER Label'] = 'B-PER'

# %%
#sanity check
original_dataset_merged_empty_single = original_dataset_merged[(~original_dataset_merged['FINAL NER Label'].notnull()) & (original_dataset_merged['Start Word Index'] == original_dataset_merged['End Word Index'])]
original_dataset_merged_empty_single
# Out:
#      Sentence Index                     Word  Start Word Index  \
# 7                13                   sunday                 5
# 101             128                  october                10
# 130             186                  january                 7
# 157             260                 february                 9
# 158             260                    march                12
# 164             264                      est                 2
# 184             291                      feb                 4
# 185             291                      feb                12
# 217             343                september                15
# 249             415                     feb.                 8
# 260             450                    sames                 0
# 274             481                     july                 7
# 301             528                 saturday                 7
# 302             528                   sunday                 9
# 342             602                      est                22
# 343             602                      pst                25
# 368             633                    april                11
# 369             633                    april                22
# 378             653                    april                24
# 380             656                  #arctic                17
# 392             669                  october                 4
# 394             671                     july                 6
# 420             731                   friday                 9
# 421             733                       pm                15
# 442             782                 thursday                21
# 483             838               #indiegame                23
# 514             904                 thursday                 8
# 515             904                      may                10
# 554             961                  america                12
# 556             966                   #av/it                 9
# 557             966                      aug                13
# 559             967             #july4canada                 6
# 588            1021                     july                 7
# 590            1022                       pm                 2
# 595            1031                september                13
# 642            1100                     july                19
# 661            1131                     #sja                 5
# 662            1131  #medicalfirstresponders                 6
# 663            1131                 #ontario                 7
# 664            1131            #championship                 8
# 678            1150           #hellomynameis                13
# 694            1179                      feb                10
#
#      End Word Index  POS Label NER Label  \
# 7                 5  ['PROPN']     ['O']
# 101              10  ['PROPN']     ['O']
# 130               7  ['PROPN']     ['O']
# 157               9  ['PROPN']     ['O']
# 158              12  ['PROPN']     ['O']
# 164               2  ['PROPN']     ['O']
# 184               4  ['PROPN']     ['O']
# 185              12  ['PROPN']     ['O']
# 217              15  ['PROPN']     ['O']
# 249               8  ['PROPN']     ['O']
# 260               0  ['PROPN']     ['O']
# 274               7  ['PROPN']     ['O']
# 301               7  ['PROPN']     ['O']
# 302               9  ['PROPN']     ['O']
# 342              22  ['PROPN']     ['O']
# 343              25  ['PROPN']     ['O']
# 368              11  ['PROPN']     ['O']
# 369              22  ['PROPN']     ['O']
# 378              24  ['PROPN']     ['O']
# 380              17  ['PROPN']     ['O']
# 392               4  ['PROPN']     ['O']
# 394               6  ['PROPN']     ['O']
# 420               9  ['PROPN']     ['O']
# 421              15  ['PROPN']     ['O']
# 442              21  ['PROPN']     ['O']
# 483              23  ['PROPN']     ['O']
# 514               8  ['PROPN']     ['O']
# 515              10  ['PROPN']     ['O']
# 554              12  ['PROPN']     ['O']
# 556               9  ['PROPN']     ['O']
# 557              13  ['PROPN']     ['O']
# 559               6  ['PROPN']     ['O']
# 588               7  ['PROPN']     ['O']
# 590               2  ['PROPN']     ['O']
# 595              13  ['PROPN']     ['O']
# 642              19  ['PROPN']     ['O']
# 661               5  ['PROPN']     ['O']
# 662               6  ['PROPN']     ['O']
# 663               7  ['PROPN']     ['O']
# 664               8  ['PROPN']     ['O']
# 678              13  ['PROPN']     ['O']
# 694              10  ['PROPN']     ['O']
#
#                                                  Tweet  \
# 7             rt @user1218 : @user265 blessed sunday 😊
# 101  i posted 11 photos on facebook in the album " ...
# 130  the heat wo n't be ready itil january but we will
# 157  { ghyr rewind } new release round - up februar...
# 158  { ghyr rewind } new release round - up februar...
# 164  7 pm est / 1 am cest - #glitch label takeover ...
# 184  rt @user201 : 14th feb 2015 : world cup first ...
# 185  rt @user201 : 14th feb 2015 : world cup first ...
# 217  rt @user326 : gucci mane is going on tour afte...
# 249  rt @user2409 : #kanhaiyakumar bail plea #adjou...
# 260                                      sames url1428
# 274  " sorry i ca n't work on july 9th because ever...
# 301  rt @user2477 : things that happened last satur...
# 302  rt @user2477 : things that happened last satur...
# 342  rt @user1131 : hey ! new music video tomorrow ...
# 343  rt @user1131 : hey ! new music video tomorrow ...
# 368  rt @user630 : the first picture is chicago at ...
# 369  rt @user630 : the first picture is chicago at ...
# 378  #cinobservatory #ohwx : temp : -0.28 °c , hum ...
# 380  rt @user522 : “ it ’s a red flag ” — polar bea...
# 392  rt @user28 : on october 7 • fifth harmony will...
# 394  @user879 last time i checked . july 22nd is in...
# 420  @user54 thanks for sharing ---==adamcsmith==--...
# 421  rt @user95 : dear leaders of the opposition ! ...
# 442  rt @user756 : @user424 very proud to be in top...
# 483  rt @user852 : new patch will be live tomorrow ...
# 514  exclusive first look at cross border vat on th...
# 515  exclusive first look at cross border vat on th...
# 554  rt @user1275 : @user737 @user1807 i like that ...
# 556  rt @user1150 : qualify for a place at the #av/...
# 557  rt @user1150 : qualify for a place at the #av/...
# 559  @user203 waiting for buses to celebrate #july4...
# 588  rt @user1879 : need extra cash for july 4 week...
# 590  @user1112 : pm @user351 struggles to secure eu...
# 595  rt @user524 : grey 's anatomy season 13 is exp...
# 642  @user1420 was n't sure if you posted about thi...
# 661  congratulations to @user1154 for winning #sja ...
# 662  congratulations to @user1154 for winning #sja ...
# 663  congratulations to @user1154 for winning #sja ...
# 664  congratulations to @user1154 for winning #sja ...
# 678  rt @user518 : so proud of how hard @user770 ha...
# 694  ddo woman living with mould / collapsed ceilin...
#
#                                       Tweet POS Labels  \
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 101  ['PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'PROPN'...
# 130  ['DET', 'NOUN', 'AUX', 'PART', 'AUX', 'ADJ', '...
# 157  ['PUNCT', 'PROPN', 'VERB', 'PUNCT', 'ADJ', 'NO...
# 158  ['PUNCT', 'PROPN', 'VERB', 'PUNCT', 'ADJ', 'NO...
# 164  ['NUM', 'NOUN', 'PROPN', 'PUNCT', 'NUM', 'NOUN...
# 184  ['X', 'X', 'PUNCT', 'NOUN', 'PROPN', 'NUM', 'P...
# 185  ['X', 'X', 'PUNCT', 'NOUN', 'PROPN', 'NUM', 'P...
# 217  ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'AUX', '...
# 249  ['X', 'X', 'PUNCT', 'PROPN', 'NOUN', 'NOUN', '...
# 260                                     ['PROPN', 'X']
# 274  ['PUNCT', 'INTJ', 'PRON', 'AUX', 'PART', 'VERB...
# 301  ['X', 'X', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'A...
# 302  ['X', 'X', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'A...
# 342  ['X', 'X', 'PUNCT', 'INTJ', 'PUNCT', 'ADJ', 'N...
# 343  ['X', 'X', 'PUNCT', 'INTJ', 'PUNCT', 'ADJ', 'N...
# 368  ['X', 'X', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX...
# 369  ['X', 'X', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX...
# 378  ['X', 'X', 'PUNCT', 'NOUN', 'PUNCT', 'NUM', 'S...
# 380  ['X', 'X', 'PUNCT', 'PUNCT', 'PRON', 'AUX', 'D...
# 392  ['X', 'X', 'PUNCT', 'ADP', 'PROPN', 'NUM', 'PU...
# 394  ['PROPN', 'ADJ', 'NOUN', 'PRON', 'VERB', 'PUNC...
# 420  ['PROPN', 'NOUN', 'SCONJ', 'VERB', 'PROPN', 'P...
# 421  ['X', 'X', 'PUNCT', 'ADJ', 'NOUN', 'ADP', 'DET...
# 442  ['X', 'X', 'PUNCT', 'PROPN', 'ADV', 'ADJ', 'PA...
# 483  ['X', 'X', 'PUNCT', 'ADJ', 'NOUN', 'AUX', 'AUX...
# 514  ['ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', ...
# 515  ['ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', ...
# 554  ['X', 'X', 'PUNCT', 'X', 'X', 'PRON', 'VERB', ...
# 556  ['X', 'X', 'PUNCT', 'VERB', 'ADP', 'DET', 'NOU...
# 557  ['X', 'X', 'PUNCT', 'VERB', 'ADP', 'DET', 'NOU...
# 559  ['PROPN', 'VERB', 'ADP', 'NOUN', 'PART', 'VERB...
# 588  ['X', 'X', 'PUNCT', 'VERB', 'ADJ', 'NOUN', 'AD...
# 590  ['PROPN', 'PUNCT', 'PROPN', 'PROPN', 'VERB', '...
# 595  ['X', 'X', 'PUNCT', 'PROPN', 'PART', 'PROPN', ...
# 642  ['PROPN', 'AUX', 'PART', 'ADJ', 'SCONJ', 'PRON...
# 661  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 662  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 663  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 664  ['NOUN', 'ADP', 'PROPN', 'SCONJ', 'VERB', 'PRO...
# 678  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'SCONJ', 'AD...
# 694  ['PROPN', 'NOUN', 'VERB', 'ADP', 'NOUN', 'PUNC...
#
#                                       Tweet NER Labels PROPOSED NER Label  \
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 101  ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', '...                NaN
# 130  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 157  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 158  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 164  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 184  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...                NaN
# 185  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...                NaN
# 217  ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O...                NaN
# 249  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 260                                         ['O', 'O']                NaN
# 274  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 301  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 302  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 342  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 343  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 368  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', '...                NaN
# 369  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', '...                NaN
# 378  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 380  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 392  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                NaN
# 394  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 420  ['O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', '...                NaN
# 421  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 442  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 483  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 514  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MI...                NaN
# 515  ['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MI...                NaN
# 554  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 556  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 557  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 559           ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 588  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 590  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...                NaN
# 595  ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', ...                NaN
# 642  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 661  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 662  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 663  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 664  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 678  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 694  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
#
#     FINAL NER Label
# 7               NaN
# 101             NaN
# 130             NaN
# 157             NaN
# 158             NaN
# 164             NaN
# 184             NaN
# 185             NaN
# 217             NaN
# 249             NaN
# 260             NaN
# 274             NaN
# 301             NaN
# 302             NaN
# 342             NaN
# 343             NaN
# 368             NaN
# 369             NaN
# 378             NaN
# 380             NaN
# 392             NaN
# 394             NaN
# 420             NaN
# 421             NaN
# 442             NaN
# 483             NaN
# 514             NaN
# 515             NaN
# 554             NaN
# 556             NaN
# 557             NaN
# 559             NaN
# 588             NaN
# 590             NaN
# 595             NaN
# 642             NaN
# 661             NaN
# 662             NaN
# 663             NaN
# 664             NaN
# 678             NaN
# 694             NaN

# %%
multiple_test = pd.read_csv('../FINAL NER Labels/TEST_MULTIPLE_twitter_label - TEST_MULTIPLE_twitter_label.tsv.tsv', sep='\t')
multiple_test = multiple_test.rename(columns={'Akshat NER Label' : 'FINAL NER Label'})
multiple_test
# Out:
#                                                  Word  Start Word Index  \
# 0                                          taco shell                 6
# 1                                       amateur radio                 0
# 2                                           mr. mikes                 3
# 3                                  dentist procedures                 9
# 4                                   wednesday special                 0
# 5                    x8w x8c x8g rc quadcopter banana                12
# 6                                          morse code                11
# 7                                        #marwat saeb                22
# 8                                scrubbing dish cloth                12
# 9                                         t20 cricket                18
# 10                                      one direction                19
# 11                                         early bird                 3
# 12                                        rajya sabha                18
# 13                                   #rhino sanctuary                 5
# 14                                eastern black rhino                 9
# 15                                   black wig brasil                 0
# 16                                        la provence                 5
# 17                                duterte grand rally                 7
# 18                                    meo cover house                14
# 19                                      united states                 9
# 20                                  bishop father god                 4
# 21                               erectile dysfunction                 2
# 22                                            eng sub                16
# 23                                       nak tanya ni                 9
# 24                            colouring page seahorse                 5
# 25                                      no.x hologram                 9
# 26                                         oppo r9 cf                 9
# 27                                          mi abuela                 3
# 28  #sja #medicalfirstresponders #ontario #champio...                 5
# 29                           #av/it leadership summit                 9
# 30                                        #arctic sea                17
# 31                           united states of america                 9
#
#     End Word Index                                          POS Label  \
# 0                7                                 ['PROPN', 'PROPN']
# 1                1                                 ['PROPN', 'PROPN']
# 2                4                                 ['PROPN', 'PROPN']
# 3               10                                 ['PROPN', 'PROPN']
# 4                1                                 ['PROPN', 'PROPN']
# 5               17  ['PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', ...
# 6               12                                 ['PROPN', 'PROPN']
# 7               23                                 ['PROPN', 'PROPN']
# 8               14                        ['PROPN', 'PROPN', 'PROPN']
# 9               19                                 ['PROPN', 'PROPN']
# 10              20                                 ['PROPN', 'PROPN']
# 11               4                                 ['PROPN', 'PROPN']
# 12              19                                 ['PROPN', 'PROPN']
# 13               6                                 ['PROPN', 'PROPN']
# 14              11                        ['PROPN', 'PROPN', 'PROPN']
# 15               2                        ['PROPN', 'PROPN', 'PROPN']
# 16               6                                 ['PROPN', 'PROPN']
# 17               9                                 ['PROPN', 'PROPN']
# 18              16                        ['PROPN', 'PROPN', 'PROPN']
# 19              10                                 ['PROPN', 'PROPN']
# 20               6                        ['PROPN', 'PROPN', 'PROPN']
# 21               3                                 ['PROPN', 'PROPN']
# 22              17                                 ['PROPN', 'PROPN']
# 23              11                        ['PROPN', 'PROPN', 'PROPN']
# 24               7                        ['PROPN', 'PROPN', 'PROPN']
# 25              10                                 ['PROPN', 'PROPN']
# 26              11                        ['PROPN', 'PROPN', 'PROPN']
# 27               4                                 ['PROPN', 'PROPN']
# 28               8                                          ['PROPN']
# 29              11                                          ['PROPN']
# 30              18                                          ['PROPN']
# 31              12                                          ['PROPN']
#
#                                       Spacy POS Label  \
# 0                                    ['NOUN', 'NOUN']
# 1                                     ['ADJ', 'NOUN']
# 2                         ['PROPN', 'PROPN', 'PROPN']
# 3                                    ['NOUN', 'NOUN']
# 4                                    ['PROPN', 'ADJ']
# 5   ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN...
# 6                                    ['NOUN', 'NOUN']
# 7                                  ['PROPN', 'PROPN']
# 8                            ['VERB', 'NOUN', 'NOUN']
# 9                                   ['PROPN', 'NOUN']
# 10                      ['SPACE', 'X', 'NUM', 'NOUN']
# 11                                    ['ADJ', 'NOUN']
# 12                                 ['PROPN', 'PROPN']
# 13                                  ['PROPN', 'NOUN']
# 14                             ['ADJ', 'ADJ', 'NOUN']
# 15                           ['ADJ', 'NOUN', 'PROPN']
# 16                                 ['PROPN', 'PROPN']
# 17                                    ['ADJ', 'NOUN']
# 18                           ['NOUN', 'NOUN', 'NOUN']
# 19                                 ['PROPN', 'PROPN']
# 20                        ['PROPN', 'PROPN', 'PROPN']
# 21                                    ['ADJ', 'NOUN']
# 22                                   ['NOUN', 'NOUN']
# 23                        ['PROPN', 'PROPN', 'PROPN']
# 24                          ['NOUN', 'NOUN', 'PROPN']
# 25                                   ['NOUN', 'NOUN']
# 26                           ['NOUN', 'NOUN', 'NOUN']
# 27                                 ['PROPN', 'PROPN']
# 28                                          ['PROPN']
# 29                            ['PROPN', 'X', 'PROPN']
# 30                                            ['ADJ']
# 31                                          ['PROPN']
#
#                                       Final POS Label  \
# 0                                    ['NOUN', 'NOUN']
# 1                                     ['ADJ', 'NOUN']
# 2                         ['PROPN', 'PROPN', 'PROPN']
# 3                                    ['NOUN', 'NOUN']
# 4                                    ['PROPN', 'ADJ']
# 5   ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN...
# 6                                    ['NOUN', 'NOUN']
# 7                                  ['PROPN', 'PROPN']
# 8                            ['VERB', 'NOUN', 'NOUN']
# 9                                   ['PROPN', 'NOUN']
# 10                      ['SPACE', 'X', 'NUM', 'NOUN']
# 11                                    ['ADJ', 'NOUN']
# 12                                 ['PROPN', 'PROPN']
# 13                                  ['PROPN', 'NOUN']
# 14                             ['ADJ', 'ADJ', 'NOUN']
# 15                           ['ADJ', 'NOUN', 'PROPN']
# 16                                 ['PROPN', 'PROPN']
# 17                                    ['ADJ', 'NOUN']
# 18                           ['NOUN', 'NOUN', 'NOUN']
# 19                                 ['PROPN', 'PROPN']
# 20                        ['PROPN', 'PROPN', 'PROPN']
# 21                                    ['ADJ', 'NOUN']
# 22                                   ['NOUN', 'NOUN']
# 23                        ['PROPN', 'PROPN', 'PROPN']
# 24                          ['NOUN', 'NOUN', 'PROPN']
# 25                                   ['NOUN', 'NOUN']
# 26                           ['NOUN', 'NOUN', 'NOUN']
# 27                                 ['PROPN', 'PROPN']
# 28                                          ['PROPN']
# 29                            ['PROPN', 'X', 'PROPN']
# 30                                            ['ADJ']
# 31                                          ['PROPN']
#
#                          NER Label Spacy NER Label  \
# 0                       ['O', 'O']              []
# 1                       ['O', 'O']              []
# 2                       ['O', 'O']              []
# 3                       ['O', 'O']              []
# 4                       ['O', 'O']        ['DATE']
# 5   ['O', 'O', 'O', 'O', 'O', 'O']              []
# 6                       ['O', 'O']              []
# 7                       ['O', 'O']              []
# 8                  ['O', 'O', 'O']              []
# 9                       ['O', 'O']              []
# 10                      ['O', 'O']              []
# 11                      ['O', 'O']              []
# 12                      ['O', 'O']              []
# 13                      ['O', 'O']              []
# 14                 ['O', 'O', 'O']              []
# 15                 ['O', 'O', 'O']              []
# 16                      ['O', 'O']              []
# 17                      ['O', 'O']              []
# 18                 ['O', 'O', 'O']              []
# 19                      ['O', 'O']              []
# 20                 ['O', 'O', 'O']              []
# 21                      ['O', 'O']              []
# 22                      ['O', 'O']              []
# 23                 ['O', 'O', 'O']              []
# 24                 ['O', 'O', 'O']              []
# 25                      ['O', 'O']              []
# 26                 ['O', 'O', 'O']              []
# 27                      ['O', 'O']              []
# 28                           ['O']         ['ORG']
# 29                           ['O']              []
# 30                           ['O']              []
# 31                           ['O']              []
#
#                                                 Tweet  \
# 0   @user2503 reportedly testing all - dorito taco...
# 1   amateur radio – hurricane katrina interview an...
# 2                            i 'm at mr. mikes . url8
# 3   know the professionals , information and facts...
# 4   wednesday special : roast beef with mash potat...
# 5   #deals #7994 3pcs 7.4 v 2000 mah battery + cha...
# 6   rt @user408 : scientist : we 've finally taugh...
# 7   rt @user1926 : who was removed aftr #ghq . #me...
# 8   rt @user1814 : discover how scrubbing dots mak...
# 9   rt @user201 : 14th feb 2015 : world cup first ...
# 10  rt @user2272 : most subscribed music artists o...
# 11  rt @user286 : early bird tickets are now sold ...
# 12  rt @user1377 : can we give respectability to t...
# 13  . @user1407 @user2135 sera community #rhino sa...
# 14  . @user1407 @user2135 sera community #rhino sa...
# 15                          black wig brasil : url914
# 16  just posted a photo @ la provence lake oswego ...
# 17  rt @user628 : mala tomorrow land 😂😂 duterte gr...
# 18  rt @user281 : cat scared of vacuum cleaner | f...
# 19  rt @user1275 : @user737 @user1807 i like that ...
# 20  rt @user1232 : amen bishop father god please h...
# 21           dealing with erectile dysfunction url892
# 22  rt @user2466 : quick subs of snsd cut on today...
# 23  rt @user64 : i hate when ppl says " nak tanya ...
# 24  rt @user290 : printable zentangle colouring pa...
# 25  rt @user2449 : limited pre-order : kim jae joo...
# 26  rt @user1283 : { preview } 160404 qianxi @ opp...
# 27  rt @user2593 : mi abuela maria so annoying smh...
# 28  congratulations to @user1154 for winning #sja ...
# 29  rt @user1150 : qualify for a place at the #av/...
# 30  rt @user522 : “ it ’s a red flag ” — polar bea...
# 31  rt @user1275 : @user737 @user1807 i like that ...
#
#                                       Candidate Label  \
# 0   @user2503 reportedly testing all - dorito <[ta...
# 1   <[amateur radio]> – hurricane katrina intervie...
# 2                        i 'm at <[mr. mikes]> . url8
# 3   know the professionals , information and facts...
# 4   <[wednesday special]> : roast beef with mash p...
# 5   #deals #7994 3pcs 7.4 v 2000 mah battery + cha...
# 6   rt @user408 : scientist : we 've finally taugh...
# 7   rt @user1926 : who was removed aftr #ghq . #me...
# 8   rt @user1814 : discover how scrubbing dots mak...
# 9   rt @user201 : 14th feb 2015 : world cup first ...
# 10  rt @user2272 : most subscribed music artists o...
# 11  rt @user286 : <[early bird]> tickets are now s...
# 12  rt @user1377 : can we give respectability to t...
# 13  . @user1407 @user2135 sera community <[#rhino ...
# 14  . @user1407 @user2135 sera community #rhino sa...
# 15                      <[black wig brasil]> : url914
# 16  just posted a photo @ <[la provence]> lake osw...
# 17  rt @user628 : mala tomorrow land 😂😂 duterte <[...
# 18  rt @user281 : cat scared of vacuum cleaner | f...
# 19  rt @user1275 : @user737 @user1807 i like that ...
# 20  rt @user1232 : amen <[bishop father god]> plea...
# 21       dealing with <[erectile dysfunction]> url892
# 22  rt @user2466 : quick subs of snsd cut on today...
# 23  rt @user64 : i hate when ppl says " <[nak tany...
# 24  rt @user290 : printable zentangle <[colouring ...
# 25  rt @user2449 : limited pre-order : kim jae joo...
# 26  rt @user1283 : { preview } 160404 qianxi @ <[o...
# 27  rt @user2593 : <[mi abuela]> maria so annoying...
# 28  congratulations to @user1154 for winning <[#sj...
# 29  rt @user1150 : qualify for a place at the <[#a...
# 30  rt @user522 : “ it ’s a red flag ” — polar bea...
# 31  rt @user1275 : @user737 @user1807 i like that ...
#
#                 PROPOSED NER Label  \
# 0                       ['O', 'O']
# 1                       ['O', 'O']
# 2             ['B-MISC', 'I-MISC']
# 3                       ['O', 'O']
# 4             ['B-MISC', 'I-MISC']
# 5   ['O', 'O', 'O', 'O', 'O', 'O']
# 6                       ['O', 'O']
# 7             ['B-MISC', 'I-MISC']
# 8                  ['O', 'O', 'O']
# 9             ['B-MISC', 'I-MISC']
# 10                      ['O', 'O']
# 11                      ['O', 'O']
# 12            ['B-MISC', 'I-MISC']
# 13            ['B-MISC', 'I-MISC']
# 14                 ['O', 'O', 'O']
# 15  ['B-MISC', 'I-MISC', 'I-MISC']
# 16            ['B-MISC', 'I-MISC']
# 17                      ['O', 'O']
# 18                 ['O', 'O', 'O']
# 19            ['B-MISC', 'I-MISC']
# 20  ['B-MISC', 'I-MISC', 'I-MISC']
# 21                      ['O', 'O']
# 22                      ['O', 'O']
# 23  ['B-MISC', 'I-MISC', 'I-MISC']
# 24  ['B-MISC', 'I-MISC', 'I-MISC']
# 25                      ['O', 'O']
# 26                 ['O', 'O', 'O']
# 27            ['B-MISC', 'I-MISC']
# 28                       ['B-ORG']
# 29                       ['B-ORG']
# 30                           ['O']
# 31                      ['B-MISC']
#
#                                        Your NER Label  \
# 0                                          ['O', 'O']
# 1                                          ['O', 'O']
# 2                                  ['B-LOC', 'I-LOC']
# 3                                          ['O', 'O']
# 4                                          ['O', 'O']
# 5   ['B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MI...
# 6                                          ['O', 'O']
# 7                                  ['B-PER', 'I-PER']
# 8                                     ['O', 'O', 'O']
# 9                                ['B-MISC', 'I-MISC']
# 10                                 ['B-ORG', 'I-ORG']
# 11                                         ['O', 'O']
# 12                                 ['B-ORG', 'I-ORG']
# 13                                         ['O', 'O']
# 14                                    ['O', 'O', 'O']
# 15                                    ['O', 'O', 'O']
# 16                                 ['B-ORG', 'I-ORG']
# 17                               ['I-MISC', 'I-MISC']
# 18                                    ['O', 'O', 'O']
# 19                                 ['B-LOC', 'I-LOC']
# 20                                    ['O', 'O', 'O']
# 21                                         ['O', 'O']
# 22                                         ['O', 'O']
# 23                                    ['O', 'O', 'O']
# 24                                    ['O', 'O', 'O']
# 25                                         ['O', 'O']
# 26                     ['B-MISC', 'I-MISC', 'I-MISC']
# 27                                         ['O', 'O']
# 28                                         ['B-MISC']
# 29                                         ['B-MISC']
# 30                                          ['B-LOC']
# 31                                            [B-LOC]
#
#                          FINAL NER Label                 LW Additional Notes
# 0                                    O O                                 NaN
# 1                                    O O                                 NaN
# 2                            B-LOC I-LOC                                 NaN
# 3                                    O O                                 NaN
# 4                                    O O                                 NaN
# 5   B-MISC I-MISC I-MISC I-MISC I-MISC O                                 NaN
# 6                                    O O                                 NaN
# 7                            B-PER I-PER                                 NaN
# 8                                  O O O                                 NaN
# 9                          B-MISC I-MISC                                 NaN
# 10                           B-ORG I-ORG                                 NaN
# 11                                   O O                                 NaN
# 12                           B-ORG I-ORG  Upper House of Parliament of India
# 13                                   O O                                 NaN
# 14                                 O O O                                 NaN
# 15                                 O O O                                 NaN
# 16                           B-ORG I-ORG                                 NaN
# 17                  B-MISC I-MISC I-MISC            continuation from duerte
# 18                                 O O O                                 NaN
# 19                           B-LOC I-LOC                                 NaN
# 20                  B-MISC I-MISC I-MISC                                 NaN
# 21                                   O O                                 NaN
# 22                                   O O                                 NaN
# 23                                 O O O                                 NaN
# 24                                 O O O                                 NaN
# 25                         B-MISC I-MISC                                 NaN
# 26                  B-MISC I-MISC I-MISC                        product name
# 27                                   O O                                 NaN
# 28           B-MISC I-MISC I-MISC I-MISC                                 NaN
# 29                  B-MISC I-MISC I-MISC    ---> join with leadership summit
# 30                           B-LOC I-LOC                ---> join with sea??
# 31               B-LOC I-LOC I-LOC I-LOC                                 NaN

# %%
for index, row in multiple_test.iterrows():
    words_in_row = row['Word'].split(' ')
    results_in_row = row['FINAL NER Label'].split(' ')
    start_index = row['Start Word Index']
    end_index = row['End Word Index']
    
    search_row = original_dataset_merged.loc[(original_dataset_merged['Tweet'] == row['Tweet'])]
    sentence_index = search_row.iloc[0]['Sentence Index']
    tweet = search_row.iloc[0]['Tweet']
    for i in range(len(words_in_row)):
        to_add = pd.DataFrame({'Sentence Index': [sentence_index], 'Word': [words_in_row[i]], 'Start Word Index': [start_index + i], 'End Word Index': [start_index + i], 'Tweet': [tweet], 'PROPOSED NER Label': [""], 'FINAL NER Label': [results_in_row[i]]})
        frames = [original_dataset_merged, to_add]
        
        original_dataset_merged = pd.concat(frames)

# %%
original_dataset_merged
# Out:
#     Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                7       xb1                13              13  ['PROPN']
# 5               12       cod                14              14  ['PROPN']
# 7               13    sunday                 5               5  ['PROPN']
# 9               16    denial                 3               3  ['PROPN']
# 36              50  benadryl                 1               1  ['PROPN']
# ..             ...       ...               ...             ...        ...
# 0              656       sea                18              18        NaN
# 0              961    united                 9               9        NaN
# 0              961    states                10              10        NaN
# 0              961        of                11              11        NaN
# 0              961   america                12              12        NaN
#
#    NER Label                                              Tweet  \
# 2      ['O']  i 've entered for a chance to win a copy of @u...
# 5      ['O']  rt @user2437 : if you have short memory let me...
# 7      ['O']           rt @user1218 : @user265 blessed sunday 😊
# 9      ['O']  " @user1771 : denial has become such a comfort...
# 36     ['O']              @user1039 benadryl is your friend lol
# ..       ...                                                ...
# 0        NaN  rt @user522 : “ it ’s a red flag ” — polar bea...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
#
#                                      Tweet POS Labels  \
# 2   ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5   ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 7   ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 9   ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
# 36  ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                      Tweet NER Labels PROPOSED NER Label  \
# 2   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 5   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# 7                 ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 9   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 36                     ['O', 'O', 'O', 'O', 'O', 'O']             B-MISC
# ..                                                ...                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#    FINAL NER Label
# 2            B-ORG
# 5           B-MISC
# 7              NaN
# 9                O
# 36          B-MISC
# ..             ...
# 0            I-LOC
# 0            B-LOC
# 0            I-LOC
# 0            I-LOC
# 0            I-LOC
#
# [360 rows x 11 columns]

# %%
#sanity check AGAIN
original_dataset_merged_empty_single = original_dataset_merged[(~original_dataset_merged['FINAL NER Label'].notnull())]
original_dataset_merged_empty_single
# Out:
#      Sentence Index            Word  Start Word Index  End Word Index  \
# 7                13          sunday                 5               5
# 82               85      taco shell                 6               7
# 86               90   amateur radio                 0               1
# 99              117       mr. mikes                 3               4
# 101             128         october                10              10
# ..              ...             ...               ...             ...
# 667            1133   no.x hologram                 9              10
# 674            1144      oppo r9 cf                 9              11
# 678            1150  #hellomynameis                13              13
# 689            1177       mi abuela                 3               4
# 694            1179             feb                10              10
#
#                        POS Label        NER Label  \
# 7                      ['PROPN']            ['O']
# 82            ['PROPN', 'PROPN']       ['O', 'O']
# 86            ['PROPN', 'PROPN']       ['O', 'O']
# 99            ['PROPN', 'PROPN']       ['O', 'O']
# 101                    ['PROPN']            ['O']
# ..                           ...              ...
# 667           ['PROPN', 'PROPN']       ['O', 'O']
# 674  ['PROPN', 'PROPN', 'PROPN']  ['O', 'O', 'O']
# 678                    ['PROPN']            ['O']
# 689           ['PROPN', 'PROPN']       ['O', 'O']
# 694                    ['PROPN']            ['O']
#
#                                                  Tweet  \
# 7             rt @user1218 : @user265 blessed sunday 😊
# 82   @user2503 reportedly testing all - dorito taco...
# 86   amateur radio – hurricane katrina interview an...
# 99                            i 'm at mr. mikes . url8
# 101  i posted 11 photos on facebook in the album " ...
# ..                                                 ...
# 667  rt @user2449 : limited pre-order : kim jae joo...
# 674  rt @user1283 : { preview } 160404 qianxi @ opp...
# 678  rt @user518 : so proud of how hard @user770 ha...
# 689  rt @user2593 : mi abuela maria so annoying smh...
# 694  ddo woman living with mould / collapsed ceilin...
#
#                                       Tweet POS Labels  \
# 7    ['X', 'X', 'PUNCT', 'PROPN', 'VERB', 'PROPN', ...
# 82   ['PROPN', 'ADV', 'VERB', 'ADJ', 'PUNCT', 'PROP...
# 86   ['PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', ...
# 99   ['PRON', 'AUX', 'ADP', 'PROPN', 'PROPN', 'PUNC...
# 101  ['PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'PROPN'...
# ..                                                 ...
# 667  ['X', 'X', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'P...
# 674  ['X', 'X', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', ...
# 678  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'SCONJ', 'AD...
# 689  ['X', 'X', 'PUNCT', 'PROPN', 'PROPN', 'PROPN',...
# 694  ['PROPN', 'NOUN', 'VERB', 'ADP', 'NOUN', 'PUNC...
#
#                                       Tweet NER Labels PROPOSED NER Label  \
# 7                  ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 82   ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O']                NaN
# 86   ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', ...                NaN
# 99                 ['O', 'O', 'O', 'O', 'O', 'O', 'O']                NaN
# 101  ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', '...                NaN
# ..                                                 ...                ...
# 667  ['O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER...                NaN
# 674  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 678  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 689  ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', '...                NaN
# 694  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
#
#     FINAL NER Label
# 7               NaN
# 82              NaN
# 86              NaN
# 99              NaN
# 101             NaN
# ..              ...
# 667             NaN
# 674             NaN
# 678             NaN
# 689             NaN
# 694             NaN
#
# [72 rows x 11 columns]

# %%
#sanity check VALUE
original_dataset_merged_check = original_dataset_merged[original_dataset_merged['Word'] == 'pst']
original_dataset_merged_check

original_dataset_merged.loc[668, 'PROPOSED NER Label'] = 'O'
original_dataset_merged.loc[668, 'FINAL NER Label'] = 'O'

# %%
#sanity check VALUE
original_dataset_merged_check = original_dataset_merged[original_dataset_merged['Word'] == 'pst']
original_dataset_merged_check
# Out:
#      Sentence Index Word  Start Word Index  End Word Index  POS Label  \
# 343             602  pst                25              25  ['PROPN']
# 668            1136  pst                18              18  ['PROPN']
#
#     NER Label                                              Tweet  \
# 343     ['O']  rt @user1131 : hey ! new music video tomorrow ...
# 668     ['O']  rt @user1206 : the * all new * url233 will be ...
#
#                                       Tweet POS Labels  \
# 343  ['X', 'X', 'PUNCT', 'INTJ', 'PUNCT', 'ADJ', 'N...
# 668  ['X', 'X', 'PUNCT', 'DET', 'PUNCT', 'DET', 'AD...
#
#                                       Tweet NER Labels PROPOSED NER Label  \
# 343  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                NaN
# 668  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
#
#     FINAL NER Label
# 343             NaN
# 668               O

# %%
#GETTING RID OF THE NaN values
original_dataset_merged = original_dataset_merged[(original_dataset_merged['FINAL NER Label'].notnull())]
original_dataset_merged
# Out:
#     Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                7       xb1                13              13  ['PROPN']
# 5               12       cod                14              14  ['PROPN']
# 9               16    denial                 3               3  ['PROPN']
# 36              50  benadryl                 1               1  ['PROPN']
# 61              68       ww1                12              12  ['PROPN']
# ..             ...       ...               ...             ...        ...
# 0              656       sea                18              18        NaN
# 0              961    united                 9               9        NaN
# 0              961    states                10              10        NaN
# 0              961        of                11              11        NaN
# 0              961   america                12              12        NaN
#
#    NER Label                                              Tweet  \
# 2      ['O']  i 've entered for a chance to win a copy of @u...
# 5      ['O']  rt @user2437 : if you have short memory let me...
# 9      ['O']  " @user1771 : denial has become such a comfort...
# 36     ['O']              @user1039 benadryl is your friend lol
# 61     ['O']  @user1651 with there boycotts and the way they...
# ..       ...                                                ...
# 0        NaN  rt @user522 : “ it ’s a red flag ” — polar bea...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
#
#                                      Tweet POS Labels  \
# 2   ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5   ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 9   ['PUNCT', 'PROPN', 'PUNCT', 'PROPN', 'AUX', 'V...
# 36  ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# 61  ['PROPN', 'ADP', 'PRON', 'NOUN', 'CCONJ', 'DET...
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                      Tweet NER Labels PROPOSED NER Label  \
# 2   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 5   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# 9   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 36                     ['O', 'O', 'O', 'O', 'O', 'O']             B-MISC
# 61  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# ..                                                ...                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#    FINAL NER Label
# 2            B-ORG
# 5           B-MISC
# 9                O
# 36          B-MISC
# 61          B-MISC
# ..             ...
# 0            I-LOC
# 0            B-LOC
# 0            I-LOC
# 0            I-LOC
# 0            I-LOC
#
# [288 rows x 11 columns]

# %%
original_dataset_merged.to_csv('logs/FINAL_ALL_test_original_dataset_merged_with_results.tsv', sep='\t')

# %%
# WRITING BACK TO ORIGINAL FILE
filename = '../Datasets/NER/Tweebank/' + 'test.bio'

how_much_changed = 0
replacement = ''
with open(filename, 'r') as file:
    original_data = file.readlines()

with open(filename, 'r') as file:
    sentence_count = 0
    word_in_sentence_count = 0
    
    for i, line in enumerate(file):
        line = line[:-1]

        if len(line):
            check_df = original_dataset_merged[original_dataset_merged['Sentence Index'] == sentence_count]
            
            if len(check_df) != 0: 
                check_df_row = check_df[check_df['Start Word Index'] == word_in_sentence_count]
                
                if len(check_df_row) != 0:
                    check_df_row_value = check_df_row['FINAL NER Label']
                    check_df_row_value_empty = check_df_row_value.any()

                    if check_df_row_value_empty != False:
                        token, _, _, label = line.split('\t')
                        
                        print("-" * 50)
                        print("ORIGINAL LINE")
                        print(line)
                        print("WORD IN TOKEN")
                        print(check_df_row.iloc[0]['Word'])
                        line_to_replace = [token, '-', '-', check_df_row.iloc[0]['FINAL NER Label']]
                        line_to_replace_string = '\t'.join(line_to_replace)
                        print("Line to replace")
                        print(line_to_replace_string) 

                        original_data[i] = line_to_replace_string + '\n'
                        how_much_changed += 1
        
            word_in_sentence_count += 1
        else:
            sentence_count += 1
            word_in_sentence_count = 0



to_write_file = open('FINAL_test.bio', 'w')
to_write_file.writelines(original_data)
to_write_file.close()

print("HOW MUCH CHANGED:")
print(how_much_changed)
# Out:
# --------------------------------------------------
# ORIGINAL LINE
# XB1	-	-	O
# WORD IN TOKEN
# xb1
# Line to replace
# XB1	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# COD	-	-	O
# WORD IN TOKEN
# cod
# Line to replace
# COD	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Denial	-	-	O
# WORD IN TOKEN
# denial
# Line to replace
# Denial	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# benadryl	-	-	O
# WORD IN TOKEN
# benadryl
# Line to replace
# benadryl	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# ww1	-	-	O
# WORD IN TOKEN
# ww1
# Line to replace
# ww1	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Sostar	-	-	O
# WORD IN TOKEN
# sostar
# Line to replace
# Sostar	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #RobFord	-	-	O
# WORD IN TOKEN
# #robford
# Line to replace
# #RobFord	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Taco	-	-	O
# WORD IN TOKEN
# taco
# Line to replace
# Taco	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Shell	-	-	O
# WORD IN TOKEN
# shell
# Line to replace
# Shell	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Amateur	-	-	O
# WORD IN TOKEN
# amateur
# Line to replace
# Amateur	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Radio	-	-	O
# WORD IN TOKEN
# radio
# Line to replace
# Radio	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Frisco	-	-	O
# WORD IN TOKEN
# frisco
# Line to replace
# Frisco	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Gothtober	-	-	O
# WORD IN TOKEN
# gothtober
# Line to replace
# Gothtober	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #PR	-	-	O
# WORD IN TOKEN
# #pr
# Line to replace
# #PR	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #HR	-	-	O
# WORD IN TOKEN
# #hr
# Line to replace
# #HR	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# HR	-	-	O
# WORD IN TOKEN
# hr
# Line to replace
# HR	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# PR	-	-	O
# WORD IN TOKEN
# pr
# Line to replace
# PR	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# lp	-	-	O
# WORD IN TOKEN
# lp
# Line to replace
# lp	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Mr.	-	-	O
# WORD IN TOKEN
# mr.
# Line to replace
# Mr.	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Mikes	-	-	O
# WORD IN TOKEN
# mikes
# Line to replace
# Mikes	-	-	I-LOC
# --------------------------------------------------
# ORIGINAL LINE
# jawn	-	-	O
# WORD IN TOKEN
# jawn
# Line to replace
# jawn	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Cheyney	-	-	O
# WORD IN TOKEN
# cheyney
# Line to replace
# Cheyney	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Dentist	-	-	O
# WORD IN TOKEN
# dentist
# Line to replace
# Dentist	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Procedures	-	-	O
# WORD IN TOKEN
# procedures
# Line to replace
# Procedures	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Treatments	-	-	O
# WORD IN TOKEN
# treatments
# Line to replace
# Treatments	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# LW2003	-	-	O
# WORD IN TOKEN
# lw2003
# Line to replace
# LW2003	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# LW2003	-	-	O
# WORD IN TOKEN
# lw2003
# Line to replace
# LW2003	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# AP	-	-	O
# WORD IN TOKEN
# ap
# Line to replace
# AP	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# AP	-	-	O
# WORD IN TOKEN
# ap
# Line to replace
# AP	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# DataContext	-	-	O
# WORD IN TOKEN
# datacontext
# Line to replace
# DataContext	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# ListBox	-	-	O
# WORD IN TOKEN
# listbox
# Line to replace
# ListBox	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Orgs	-	-	O
# WORD IN TOKEN
# orgs
# Line to replace
# Orgs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Gov't	-	-	O
# WORD IN TOKEN
# gov't
# Line to replace
# Gov't	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# VHS	-	-	O
# WORD IN TOKEN
# vhs
# Line to replace
# VHS	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# IEC	-	-	O
# WORD IN TOKEN
# iec
# Line to replace
# IEC	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# St	-	-	O
# WORD IN TOKEN
# st
# Line to replace
# St	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# warped	-	-	O
# WORD IN TOKEN
# warped
# Line to replace
# warped	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Glee	-	-	O
# WORD IN TOKEN
# #glee
# Line to replace
# #Glee	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Wednesday	-	-	O
# WORD IN TOKEN
# wednesday
# Line to replace
# Wednesday	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Special	-	-	O
# WORD IN TOKEN
# special
# Line to replace
# Special	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Migraine	-	-	O
# WORD IN TOKEN
# #migraine
# Line to replace
# #Migraine	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# X8W	-	-	O
# WORD IN TOKEN
# x8w
# Line to replace
# X8W	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# X8C	-	-	O
# WORD IN TOKEN
# x8c
# Line to replace
# X8C	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# X8G	-	-	O
# WORD IN TOKEN
# x8g
# Line to replace
# X8G	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# RC	-	-	O
# WORD IN TOKEN
# rc
# Line to replace
# RC	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Quadcopter	-	-	O
# WORD IN TOKEN
# quadcopter
# Line to replace
# Quadcopter	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Banana	-	-	O
# WORD IN TOKEN
# banana
# Line to replace
# Banana	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #eCommerce	-	-	O
# WORD IN TOKEN
# #ecommerce
# Line to replace
# #eCommerce	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #CRM	-	-	O
# WORD IN TOKEN
# #crm
# Line to replace
# #CRM	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# CPA	-	-	O
# WORD IN TOKEN
# cpa
# Line to replace
# CPA	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #BOHO	-	-	O
# WORD IN TOKEN
# #boho
# Line to replace
# #BOHO	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# YUNG	-	-	O
# WORD IN TOKEN
# yung
# Line to replace
# YUNG	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Morse	-	-	O
# WORD IN TOKEN
# morse
# Line to replace
# Morse	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Code	-	-	O
# WORD IN TOKEN
# code
# Line to replace
# Code	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #GHQ	-	-	O
# WORD IN TOKEN
# #ghq
# Line to replace
# #GHQ	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #BKU	-	-	O
# WORD IN TOKEN
# #bku
# Line to replace
# #BKU	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #Marwat	-	-	O
# WORD IN TOKEN
# #marwat
# Line to replace
# #Marwat	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Saeb	-	-	O
# WORD IN TOKEN
# saeb
# Line to replace
# Saeb	-	-	I-PER
# --------------------------------------------------
# ORIGINAL LINE
# GHYR	-	-	O
# WORD IN TOKEN
# ghyr
# Line to replace
# GHYR	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Blogopolis4D	-	-	O
# WORD IN TOKEN
# #blogopolis4d
# Line to replace
# #Blogopolis4D	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #BeautyBlog	-	-	O
# WORD IN TOKEN
# #beautyblog
# Line to replace
# #BeautyBlog	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# CEST	-	-	O
# WORD IN TOKEN
# cest
# Line to replace
# CEST	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# SEO	-	-	O
# WORD IN TOKEN
# seo
# Line to replace
# SEO	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Scrubbing	-	-	O
# WORD IN TOKEN
# scrubbing
# Line to replace
# Scrubbing	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Dish	-	-	O
# WORD IN TOKEN
# dish
# Line to replace
# Dish	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Cloth	-	-	O
# WORD IN TOKEN
# cloth
# Line to replace
# Cloth	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# PTs	-	-	O
# WORD IN TOKEN
# pts
# Line to replace
# PTs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #bd	-	-	O
# WORD IN TOKEN
# #bd
# Line to replace
# #bd	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# asmii	-	-	O
# WORD IN TOKEN
# asmii
# Line to replace
# asmii	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# hibha	-	-	O
# WORD IN TOKEN
# hibha
# Line to replace
# hibha	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# T	-	-	O
# WORD IN TOKEN
# t
# Line to replace
# T	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# T20	-	-	O
# WORD IN TOKEN
# t20
# Line to replace
# T20	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Cricket	-	-	O
# WORD IN TOKEN
# cricket
# Line to replace
# Cricket	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Valentine	-	-	O
# WORD IN TOKEN
# valentine
# Line to replace
# Valentine	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Kira	-	-	O
# WORD IN TOKEN
# kira
# Line to replace
# Kira	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# L	-	-	O
# WORD IN TOKEN
# l
# Line to replace
# L	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #GRAMMYs	-	-	O
# WORD IN TOKEN
# #grammys
# Line to replace
# #GRAMMYs	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #ISL	-	-	O
# WORD IN TOKEN
# #isl
# Line to replace
# #ISL	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #BIGOLIVE	-	-	O
# WORD IN TOKEN
# #bigolive
# Line to replace
# #BIGOLIVE	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Chainsmokers	-	-	O
# WORD IN TOKEN
# chainsmokers
# Line to replace
# Chainsmokers	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Hardwell	-	-	O
# WORD IN TOKEN
# hardwell
# Line to replace
# Hardwell	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# A3174	-	-	O
# WORD IN TOKEN
# a3174
# Line to replace
# A3174	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# LTB	-	-	O
# WORD IN TOKEN
# ltb
# Line to replace
# LTB	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# japan	-	-	O
# WORD IN TOKEN
# japan
# Line to replace
# japan	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# One	-	-	O
# WORD IN TOKEN
# one
# Line to replace
# One	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Direction	-	-	O
# WORD IN TOKEN
# direction
# Line to replace
# Direction	-	-	I-ORG
# --------------------------------------------------
# ORIGINAL LINE
# #BarunSobti	-	-	O
# WORD IN TOKEN
# #barunsobti
# Line to replace
# #BarunSobti	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #SanayaIrani	-	-	O
# WORD IN TOKEN
# #sanayairani
# Line to replace
# #SanayaIrani	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# JW	-	-	O
# WORD IN TOKEN
# jw
# Line to replace
# JW	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Globe	-	-	O
# WORD IN TOKEN
# globe
# Line to replace
# Globe	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #MomentsThatCount	-	-	O
# WORD IN TOKEN
# #momentsthatcount
# Line to replace
# #MomentsThatCount	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #NissanPavilion	-	-	O
# WORD IN TOKEN
# #nissanpavilion
# Line to replace
# #NissanPavilion	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# R&B	-	-	O
# WORD IN TOKEN
# r&b
# Line to replace
# R&B	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #KanhaiyaKumar	-	-	O
# WORD IN TOKEN
# #kanhaiyakumar
# Line to replace
# #KanhaiyaKumar	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #LetterCarrier	-	-	O
# WORD IN TOKEN
# #lettercarrier
# Line to replace
# #LetterCarrier	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Yemen	-	-	O
# WORD IN TOKEN
# #yemen
# Line to replace
# #Yemen	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #Europe	-	-	O
# WORD IN TOKEN
# #europe
# Line to replace
# #Europe	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# STANDEE	-	-	O
# WORD IN TOKEN
# standee
# Line to replace
# STANDEE	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# AG	-	-	O
# WORD IN TOKEN
# ag
# Line to replace
# AG	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #VOZEMPIRE	-	-	O
# WORD IN TOKEN
# #vozempire
# Line to replace
# #VOZEMPIRE	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Early	-	-	O
# WORD IN TOKEN
# early
# Line to replace
# Early	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Bird	-	-	O
# WORD IN TOKEN
# bird
# Line to replace
# Bird	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #CountryFlo	-	-	O
# WORD IN TOKEN
# #countryflo
# Line to replace
# #CountryFlo	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# VIP	-	-	O
# WORD IN TOKEN
# vip
# Line to replace
# VIP	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #quotes	-	-	O
# WORD IN TOKEN
# #quotes
# Line to replace
# #quotes	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Disastorus	-	-	O
# WORD IN TOKEN
# disastorus
# Line to replace
# Disastorus	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #SoundCloud	-	-	O
# WORD IN TOKEN
# #soundcloud
# Line to replace
# #SoundCloud	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Rajya	-	-	O
# WORD IN TOKEN
# rajya
# Line to replace
# Rajya	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Sabha	-	-	O
# WORD IN TOKEN
# sabha
# Line to replace
# Sabha	-	-	I-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Art	-	-	O
# WORD IN TOKEN
# art
# Line to replace
# Art	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# god	-	-	O
# WORD IN TOKEN
# god
# Line to replace
# god	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Zipperbag	-	-	O
# WORD IN TOKEN
# zipperbag
# Line to replace
# Zipperbag	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# -E	-	-	O
# WORD IN TOKEN
# -e
# Line to replace
# -E	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Kevlar	-	-	O
# WORD IN TOKEN
# kevlar
# Line to replace
# Kevlar	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# MCGI	-	-	O
# WORD IN TOKEN
# mcgi
# Line to replace
# MCGI	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Reunited	-	-	O
# WORD IN TOKEN
# reunited
# Line to replace
# Reunited	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #SEHUN	-	-	O
# WORD IN TOKEN
# #sehun
# Line to replace
# #SEHUN	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Ichimoku	-	-	O
# WORD IN TOKEN
# #ichimoku
# Line to replace
# #Ichimoku	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# tw	-	-	O
# WORD IN TOKEN
# tw
# Line to replace
# tw	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Rhino	-	-	O
# WORD IN TOKEN
# #rhino
# Line to replace
# #Rhino	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Sanctuary	-	-	O
# WORD IN TOKEN
# sanctuary
# Line to replace
# Sanctuary	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Eastern	-	-	O
# WORD IN TOKEN
# eastern
# Line to replace
# Eastern	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Black	-	-	O
# WORD IN TOKEN
# black
# Line to replace
# Black	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Rhino	-	-	O
# WORD IN TOKEN
# rhino
# Line to replace
# Rhino	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Black	-	-	O
# WORD IN TOKEN
# black
# Line to replace
# Black	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Wig	-	-	O
# WORD IN TOKEN
# wig
# Line to replace
# Wig	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Brasil	-	-	O
# WORD IN TOKEN
# brasil
# Line to replace
# Brasil	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Cheyenne	-	-	O
# WORD IN TOKEN
# #cheyenne
# Line to replace
# #Cheyenne	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# DrMSG	-	-	O
# WORD IN TOKEN
# drmsg
# Line to replace
# DrMSG	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# MSG	-	-	O
# WORD IN TOKEN
# msg
# Line to replace
# MSG	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Brand	-	-	O
# WORD IN TOKEN
# brand
# Line to replace
# Brand	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# ONT	-	-	O
# WORD IN TOKEN
# ont
# Line to replace
# ONT	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #roma	-	-	O
# WORD IN TOKEN
# #roma
# Line to replace
# #roma	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# GAWD	-	-	O
# WORD IN TOKEN
# gawd
# Line to replace
# GAWD	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Lawd	-	-	O
# WORD IN TOKEN
# lawd
# Line to replace
# Lawd	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Elementary	-	-	O
# WORD IN TOKEN
# #elementary
# Line to replace
# #Elementary	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# OG	-	-	O
# WORD IN TOKEN
# og
# Line to replace
# OG	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# GB	-	-	O
# WORD IN TOKEN
# gb
# Line to replace
# GB	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# GPs	-	-	O
# WORD IN TOKEN
# gps
# Line to replace
# GPs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #TheNextGalaxy	-	-	O
# WORD IN TOKEN
# #thenextgalaxy
# Line to replace
# #TheNextGalaxy	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# R30000	-	-	O
# WORD IN TOKEN
# r30000
# Line to replace
# R30000	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Arctic	-	-	O
# WORD IN TOKEN
# #arctic
# Line to replace
# #Arctic	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# sea	-	-	O
# WORD IN TOKEN
# sea
# Line to replace
# sea	-	-	I-LOC
# --------------------------------------------------
# ORIGINAL LINE
# OnlyPiolou	-	-	O
# WORD IN TOKEN
# onlypiolou
# Line to replace
# OnlyPiolou	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# thepeoplepick	-	-	O
# WORD IN TOKEN
# thepeoplepick
# Line to replace
# thepeoplepick	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# La	-	-	O
# WORD IN TOKEN
# la
# Line to replace
# La	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Provence	-	-	O
# WORD IN TOKEN
# provence
# Line to replace
# Provence	-	-	I-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Stakes	-	-	O
# WORD IN TOKEN
# stakes
# Line to replace
# Stakes	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Election	-	-	O
# WORD IN TOKEN
# election
# Line to replace
# Election	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #EURO2016	-	-	O
# WORD IN TOKEN
# #euro2016
# Line to replace
# #EURO2016	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# FT	-	-	O
# WORD IN TOKEN
# ft
# Line to replace
# FT	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #AUT	-	-	O
# WORD IN TOKEN
# #aut
# Line to replace
# #AUT	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #StrictlyBidness	-	-	O
# WORD IN TOKEN
# #strictlybidness
# Line to replace
# #StrictlyBidness	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ReverbNation	-	-	O
# WORD IN TOKEN
# #reverbnation
# Line to replace
# #ReverbNation	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #HitPlay	-	-	O
# WORD IN TOKEN
# #hitplay
# Line to replace
# #HitPlay	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Pharmacy	-	-	O
# WORD IN TOKEN
# #pharmacy
# Line to replace
# #Pharmacy	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Lyric	-	-	O
# WORD IN TOKEN
# lyric
# Line to replace
# Lyric	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# TABDEELi	-	-	O
# WORD IN TOKEN
# tabdeeli
# Line to replace
# TABDEELi	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Companion	-	-	O
# WORD IN TOKEN
# companion
# Line to replace
# Companion	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Tfry	-	-	O
# WORD IN TOKEN
# tfry
# Line to replace
# Tfry	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Eyenimal	-	-	O
# WORD IN TOKEN
# eyenimal
# Line to replace
# Eyenimal	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# nightvision	-	-	O
# WORD IN TOKEN
# nightvision
# Line to replace
# nightvision	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Trump	-	-	O
# WORD IN TOKEN
# #trump
# Line to replace
# #Trump	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #CareerArc	-	-	O
# WORD IN TOKEN
# #careerarc
# Line to replace
# #CareerArc	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Brimfield	-	-	O
# WORD IN TOKEN
# #brimfield
# Line to replace
# #Brimfield	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# elo	-	-	O
# WORD IN TOKEN
# elo
# Line to replace
# elo	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Wade	-	-	O
# WORD IN TOKEN
# #wade
# Line to replace
# #Wade	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# 3pt	-	-	O
# WORD IN TOKEN
# 3pt
# Line to replace
# 3pt	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #TeenChoice	-	-	O
# WORD IN TOKEN
# #teenchoice
# Line to replace
# #TeenChoice	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ChoiceModel	-	-	O
# WORD IN TOKEN
# #choicemodel
# Line to replace
# #ChoiceModel	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Earthquake	-	-	O
# WORD IN TOKEN
# #earthquake
# Line to replace
# #Earthquake	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Everett	-	-	O
# WORD IN TOKEN
# #everett
# Line to replace
# #Everett	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #ECF	-	-	O
# WORD IN TOKEN
# #ecf
# Line to replace
# #ECF	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #TheAssociation	-	-	O
# WORD IN TOKEN
# #theassociation
# Line to replace
# #TheAssociation	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# OC	-	-	O
# WORD IN TOKEN
# oc
# Line to replace
# OC	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Ukraine	-	-	O
# WORD IN TOKEN
# #ukraine
# Line to replace
# #Ukraine	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #Sentsov	-	-	O
# WORD IN TOKEN
# #sentsov
# Line to replace
# #Sentsov	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Afanasyev	-	-	O
# WORD IN TOKEN
# #afanasyev
# Line to replace
# #Afanasyev	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Kolchenko	-	-	O
# WORD IN TOKEN
# #kolchenko
# Line to replace
# #Kolchenko	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Soloshenko	-	-	O
# WORD IN TOKEN
# #soloshenko
# Line to replace
# #Soloshenko	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Russia	-	-	O
# WORD IN TOKEN
# #russia
# Line to replace
# #Russia	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Defense	-	-	O
# WORD IN TOKEN
# defense
# Line to replace
# Defense	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Discovery	-	-	O
# WORD IN TOKEN
# discovery
# Line to replace
# Discovery	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Mzbel	-	-	O
# WORD IN TOKEN
# mzbel
# Line to replace
# Mzbel	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Baywatch	-	-	O
# WORD IN TOKEN
# #baywatch
# Line to replace
# #Baywatch	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #TimPeake	-	-	O
# WORD IN TOKEN
# #timpeake
# Line to replace
# #TimPeake	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Mala	-	-	O
# WORD IN TOKEN
# mala
# Line to replace
# Mala	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# DUTERTE	-	-	B-PER
# WORD IN TOKEN
# duterte
# Line to replace
# DUTERTE	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# GRAND	-	-	O
# WORD IN TOKEN
# grand
# Line to replace
# GRAND	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# RALLY	-	-	O
# WORD IN TOKEN
# rally
# Line to replace
# RALLY	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #GOPDebate	-	-	O
# WORD IN TOKEN
# #gopdebate
# Line to replace
# #GOPDebate	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Cruz	-	-	O
# WORD IN TOKEN
# #cruz
# Line to replace
# #Cruz	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Trump	-	-	O
# WORD IN TOKEN
# #trump
# Line to replace
# #Trump	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #ThreatWire	-	-	O
# WORD IN TOKEN
# #threatwire
# Line to replace
# #ThreatWire	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# Meo	-	-	O
# WORD IN TOKEN
# meo
# Line to replace
# Meo	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Cover	-	-	O
# WORD IN TOKEN
# cover
# Line to replace
# Cover	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# House	-	-	O
# WORD IN TOKEN
# house
# Line to replace
# House	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ELEAGUE	-	-	O
# WORD IN TOKEN
# #eleague
# Line to replace
# #ELEAGUE	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #tbs	-	-	O
# WORD IN TOKEN
# #tbs
# Line to replace
# #tbs	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# sm	-	-	O
# WORD IN TOKEN
# sm
# Line to replace
# sm	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #USURY	-	-	O
# WORD IN TOKEN
# #usury
# Line to replace
# #USURY	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #PAEDOPHILA	-	-	O
# WORD IN TOKEN
# #paedophila
# Line to replace
# #PAEDOPHILA	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #EMBRYOLOGY	-	-	O
# WORD IN TOKEN
# #embryology
# Line to replace
# #EMBRYOLOGY	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Zola	-	-	O
# WORD IN TOKEN
# zola
# Line to replace
# Zola	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #GreenWall	-	-	O
# WORD IN TOKEN
# #greenwall
# Line to replace
# #GreenWall	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Fc	-	-	O
# WORD IN TOKEN
# fc
# Line to replace
# Fc	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# B	-	-	O
# WORD IN TOKEN
# b
# Line to replace
# B	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# In.Sight	-	-	O
# WORD IN TOKEN
# in.sight
# Line to replace
# In.Sight	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# k3	-	-	O
# WORD IN TOKEN
# k3
# Line to replace
# k3	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# KKC	-	-	O
# WORD IN TOKEN
# kkc
# Line to replace
# KKC	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #lacandelaviva	-	-	O
# WORD IN TOKEN
# #lacandelaviva
# Line to replace
# #lacandelaviva	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #FDIC2016	-	-	O
# WORD IN TOKEN
# #fdic2016
# Line to replace
# #FDIC2016	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ShawnWorldTourCologne	-	-	O
# WORD IN TOKEN
# #shawnworldtourcologne
# Line to replace
# #ShawnWorldTourCologne	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# United	-	-	O
# WORD IN TOKEN
# united
# Line to replace
# United	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# States	-	-	O
# WORD IN TOKEN
# states
# Line to replace
# States	-	-	I-LOC
# --------------------------------------------------
# ORIGINAL LINE
# of	-	-	O
# WORD IN TOKEN
# of
# Line to replace
# of	-	-	I-LOC
# --------------------------------------------------
# ORIGINAL LINE
# America	-	-	O
# WORD IN TOKEN
# america
# Line to replace
# America	-	-	I-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #AV/IT	-	-	O
# WORD IN TOKEN
# #av/it
# Line to replace
# #AV/IT	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Leadership	-	-	B-MISC
# WORD IN TOKEN
# leadership
# Line to replace
# Leadership	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Summit	-	-	I-MISC
# WORD IN TOKEN
# summit
# Line to replace
# Summit	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Rockstar	-	-	O
# WORD IN TOKEN
# rockstar
# Line to replace
# Rockstar	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #TeenChoice	-	-	O
# WORD IN TOKEN
# #teenchoice
# Line to replace
# #TeenChoice	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #ChoiceModel	-	-	O
# WORD IN TOKEN
# #choicemodel
# Line to replace
# #ChoiceModel	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Taurus	-	-	O
# WORD IN TOKEN
# #taurus
# Line to replace
# #Taurus	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# HC	-	-	O
# WORD IN TOKEN
# hc
# Line to replace
# HC	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# BB	-	-	O
# WORD IN TOKEN
# bb
# Line to replace
# BB	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# ASK	-	-	O
# WORD IN TOKEN
# ask
# Line to replace
# ASK	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Daraa	-	-	O
# WORD IN TOKEN
# #daraa
# Line to replace
# #Daraa	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Dildo	-	-	O
# WORD IN TOKEN
# dildo
# Line to replace
# Dildo	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# hilltop	-	-	O
# WORD IN TOKEN
# hilltop
# Line to replace
# hilltop	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Bishop	-	-	O
# WORD IN TOKEN
# bishop
# Line to replace
# Bishop	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Father	-	-	O
# WORD IN TOKEN
# father
# Line to replace
# Father	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# God	-	-	O
# WORD IN TOKEN
# god
# Line to replace
# God	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# MD	-	-	O
# WORD IN TOKEN
# md
# Line to replace
# MD	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# ZTD	-	-	O
# WORD IN TOKEN
# ztd
# Line to replace
# ZTD	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Sigma	-	-	O
# WORD IN TOKEN
# sigma
# Line to replace
# Sigma	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# AB	-	-	O
# WORD IN TOKEN
# ab
# Line to replace
# AB	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #Jesus	-	-	O
# WORD IN TOKEN
# #jesus
# Line to replace
# #Jesus	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #velingrad	-	-	O
# WORD IN TOKEN
# #velingrad
# Line to replace
# #velingrad	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# #JESUS	-	-	O
# WORD IN TOKEN
# #jesus
# Line to replace
# #JESUS	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# Pee	-	-	O
# WORD IN TOKEN
# pee
# Line to replace
# Pee	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Erectile	-	-	O
# WORD IN TOKEN
# erectile
# Line to replace
# Erectile	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Dysfunction	-	-	O
# WORD IN TOKEN
# dysfunction
# Line to replace
# Dysfunction	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Labour	-	-	O
# WORD IN TOKEN
# #labour
# Line to replace
# #Labour	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #Murdoch	-	-	O
# WORD IN TOKEN
# #murdoch
# Line to replace
# #Murdoch	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# God	-	-	O
# WORD IN TOKEN
# god
# Line to replace
# God	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #SouthBelfast	-	-	O
# WORD IN TOKEN
# #southbelfast
# Line to replace
# #SouthBelfast	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# Ecigs	-	-	O
# WORD IN TOKEN
# ecigs
# Line to replace
# Ecigs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# AR	-	-	O
# WORD IN TOKEN
# ar
# Line to replace
# AR	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Greendale	-	-	O
# WORD IN TOKEN
# #greendale
# Line to replace
# #Greendale	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# WI	-	-	O
# WORD IN TOKEN
# wi
# Line to replace
# WI	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# O.H	-	-	O
# WORD IN TOKEN
# o.h
# Line to replace
# O.H	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #PerdueCrew	-	-	O
# WORD IN TOKEN
# #perduecrew
# Line to replace
# #PerdueCrew	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# FM	-	-	O
# WORD IN TOKEN
# fm
# Line to replace
# FM	-	-	B-PER
# --------------------------------------------------
# ORIGINAL LINE
# #Iran	-	-	O
# WORD IN TOKEN
# #iran
# Line to replace
# #Iran	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# ENG	-	-	O
# WORD IN TOKEN
# eng
# Line to replace
# ENG	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# SUB	-	-	O
# WORD IN TOKEN
# sub
# Line to replace
# SUB	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# KBS	-	-	O
# WORD IN TOKEN
# kbs
# Line to replace
# KBS	-	-	B-ORG
# --------------------------------------------------
# ORIGINAL LINE
# nak	-	-	O
# WORD IN TOKEN
# nak
# Line to replace
# nak	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# tanya	-	-	O
# WORD IN TOKEN
# tanya
# Line to replace
# tanya	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# ni	-	-	O
# WORD IN TOKEN
# ni
# Line to replace
# ni	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Colouring	-	-	O
# WORD IN TOKEN
# colouring
# Line to replace
# Colouring	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Page	-	-	O
# WORD IN TOKEN
# page
# Line to replace
# Page	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Seahorse	-	-	O
# WORD IN TOKEN
# seahorse
# Line to replace
# Seahorse	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# #SJA	-	-	O
# WORD IN TOKEN
# #sja
# Line to replace
# #SJA	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #MedicalFirstResponders	-	-	O
# WORD IN TOKEN
# #medicalfirstresponders
# Line to replace
# #MedicalFirstResponders	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Ontario	-	-	O
# WORD IN TOKEN
# #ontario
# Line to replace
# #Ontario	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #Championship	-	-	O
# WORD IN TOKEN
# #championship
# Line to replace
# #Championship	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# ETFs	-	-	O
# WORD IN TOKEN
# etfs
# Line to replace
# ETFs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# ETFs	-	-	O
# WORD IN TOKEN
# etfs
# Line to replace
# ETFs	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# NO.X	-	-	O
# WORD IN TOKEN
# no.x
# Line to replace
# NO.X	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# Hologram	-	-	O
# WORD IN TOKEN
# hologram
# Line to replace
# Hologram	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# PST	-	-	O
# WORD IN TOKEN
# pst
# Line to replace
# PST	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Qianxi	-	-	O
# WORD IN TOKEN
# qianxi
# Line to replace
# Qianxi	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# OPPO	-	-	O
# WORD IN TOKEN
# oppo
# Line to replace
# OPPO	-	-	B-MISC
# --------------------------------------------------
# ORIGINAL LINE
# R9	-	-	O
# WORD IN TOKEN
# r9
# Line to replace
# R9	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# CF	-	-	O
# WORD IN TOKEN
# cf
# Line to replace
# CF	-	-	I-MISC
# --------------------------------------------------
# ORIGINAL LINE
# #prettyporn~	-	-	O
# WORD IN TOKEN
# #prettyporn~
# Line to replace
# #prettyporn~	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# mi	-	-	O
# WORD IN TOKEN
# mi
# Line to replace
# mi	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# abuela	-	-	O
# WORD IN TOKEN
# abuela
# Line to replace
# abuela	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# DDO	-	-	O
# WORD IN TOKEN
# ddo
# Line to replace
# DDO	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Ii	-	-	O
# WORD IN TOKEN
# ii
# Line to replace
# Ii	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Ii	-	-	O
# WORD IN TOKEN
# ii
# Line to replace
# Ii	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Ii	-	-	O
# WORD IN TOKEN
# ii
# Line to replace
# Ii	-	-	O
# --------------------------------------------------
# ORIGINAL LINE
# Ireland	-	-	O
# WORD IN TOKEN
# ireland
# Line to replace
# Ireland	-	-	B-LOC
# --------------------------------------------------
# ORIGINAL LINE
# t	-	-	O
# WORD IN TOKEN
# t
# Line to replace
# t	-	-	O
# HOW MUCH CHANGED:
# 286

# %%
## SANITY CHECK FINAL DATASET
filename = '../Datasets/NER/Tweebank/' + 'test.bio'

original_data_check = []
new_data_check = []

total_changed_additions = 0
total_new_additions = 0

total_old_entities = 0
total_new_entities = 0


with open(filename, 'r') as file:
    original_data_check = file.readlines()

with open('FINAL_test.bio', 'r') as file_two:
    new_data_check = file_two.readlines()

print(len(original_data_check))
print(len(new_data_check))

for i in range(len(original_data_check)):
    original_string = original_data_check[i]
    new_string = new_data_check[i]
    
    if original_string != '\n':
        old_token, _, _, old_label = original_string.split('\t')
        new_token, _, _, new_label = new_string.split('\t')
        
        if old_label != "O\n":
            total_old_entities += 1
        if new_label != "O\n":
            total_new_entities += 1

        if old_label != new_label:
            print("-" * 50)
            print("CHANGED ADDITION")
            print("OLD STRING")
            print(original_string)
            print("NEW STRING")
            print(new_string)
            print("OLD LABEL:", old_label)
            print("NEW LABEL:", new_label)
            total_changed_additions += 1
        if (old_label == "O\n") and (new_label != "O\n"):
            print("ALSO NEW ADDITION AS WELL")
            total_new_additions += 1
            
print("TOTAL OLD ENTITIES", total_old_entities)
print("TOTAL NEW ENTITIES", total_new_entities)
print("TOTAL CHANGED ADDITIONS", total_changed_additions)            
print("TOTAL NEW ADDITIONS", total_new_additions)
# Out:
# 20295
# 20295
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# XB1	-	-	O
#
# NEW STRING
# XB1	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# COD	-	-	O
#
# NEW STRING
# COD	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# benadryl	-	-	O
#
# NEW STRING
# benadryl	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# ww1	-	-	O
#
# NEW STRING
# ww1	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Sostar	-	-	O
#
# NEW STRING
# Sostar	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #RobFord	-	-	O
#
# NEW STRING
# #RobFord	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Frisco	-	-	O
#
# NEW STRING
# Frisco	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Gothtober	-	-	O
#
# NEW STRING
# Gothtober	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# HR	-	-	O
#
# NEW STRING
# HR	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# PR	-	-	O
#
# NEW STRING
# PR	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# lp	-	-	O
#
# NEW STRING
# lp	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Mr.	-	-	O
#
# NEW STRING
# Mr.	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Mikes	-	-	O
#
# NEW STRING
# Mikes	-	-	I-LOC
#
# OLD LABEL: O
#
# NEW LABEL: I-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# jawn	-	-	O
#
# NEW STRING
# jawn	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Cheyney	-	-	O
#
# NEW STRING
# Cheyney	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# LW2003	-	-	O
#
# NEW STRING
# LW2003	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# LW2003	-	-	O
#
# NEW STRING
# LW2003	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# AP	-	-	O
#
# NEW STRING
# AP	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# AP	-	-	O
#
# NEW STRING
# AP	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# VHS	-	-	O
#
# NEW STRING
# VHS	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# St	-	-	O
#
# NEW STRING
# St	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# warped	-	-	O
#
# NEW STRING
# warped	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Glee	-	-	O
#
# NEW STRING
# #Glee	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# X8W	-	-	O
#
# NEW STRING
# X8W	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# X8C	-	-	O
#
# NEW STRING
# X8C	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# X8G	-	-	O
#
# NEW STRING
# X8G	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# RC	-	-	O
#
# NEW STRING
# RC	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Quadcopter	-	-	O
#
# NEW STRING
# Quadcopter	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# CPA	-	-	O
#
# NEW STRING
# CPA	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #BOHO	-	-	O
#
# NEW STRING
# #BOHO	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #BKU	-	-	O
#
# NEW STRING
# #BKU	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Marwat	-	-	O
#
# NEW STRING
# #Marwat	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Saeb	-	-	O
#
# NEW STRING
# Saeb	-	-	I-PER
#
# OLD LABEL: O
#
# NEW LABEL: I-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# GHYR	-	-	O
#
# NEW STRING
# GHYR	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Blogopolis4D	-	-	O
#
# NEW STRING
# #Blogopolis4D	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# CEST	-	-	O
#
# NEW STRING
# CEST	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #bd	-	-	O
#
# NEW STRING
# #bd	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# asmii	-	-	O
#
# NEW STRING
# asmii	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# hibha	-	-	O
#
# NEW STRING
# hibha	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# T20	-	-	O
#
# NEW STRING
# T20	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Cricket	-	-	O
#
# NEW STRING
# Cricket	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Valentine	-	-	O
#
# NEW STRING
# Valentine	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Kira	-	-	O
#
# NEW STRING
# Kira	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #GRAMMYs	-	-	O
#
# NEW STRING
# #GRAMMYs	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ISL	-	-	O
#
# NEW STRING
# #ISL	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #BIGOLIVE	-	-	O
#
# NEW STRING
# #BIGOLIVE	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Chainsmokers	-	-	O
#
# NEW STRING
# Chainsmokers	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Hardwell	-	-	O
#
# NEW STRING
# Hardwell	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# A3174	-	-	O
#
# NEW STRING
# A3174	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# LTB	-	-	O
#
# NEW STRING
# LTB	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# japan	-	-	O
#
# NEW STRING
# japan	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# One	-	-	O
#
# NEW STRING
# One	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Direction	-	-	O
#
# NEW STRING
# Direction	-	-	I-ORG
#
# OLD LABEL: O
#
# NEW LABEL: I-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #BarunSobti	-	-	O
#
# NEW STRING
# #BarunSobti	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #SanayaIrani	-	-	O
#
# NEW STRING
# #SanayaIrani	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# JW	-	-	O
#
# NEW STRING
# JW	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #NissanPavilion	-	-	O
#
# NEW STRING
# #NissanPavilion	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# R&B	-	-	O
#
# NEW STRING
# R&B	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #KanhaiyaKumar	-	-	O
#
# NEW STRING
# #KanhaiyaKumar	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Yemen	-	-	O
#
# NEW STRING
# #Yemen	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Europe	-	-	O
#
# NEW STRING
# #Europe	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# AG	-	-	O
#
# NEW STRING
# AG	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #VOZEMPIRE	-	-	O
#
# NEW STRING
# #VOZEMPIRE	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #CountryFlo	-	-	O
#
# NEW STRING
# #CountryFlo	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #SoundCloud	-	-	O
#
# NEW STRING
# #SoundCloud	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Rajya	-	-	O
#
# NEW STRING
# Rajya	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Sabha	-	-	O
#
# NEW STRING
# Sabha	-	-	I-ORG
#
# OLD LABEL: O
#
# NEW LABEL: I-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# god	-	-	O
#
# NEW STRING
# god	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Kevlar	-	-	O
#
# NEW STRING
# Kevlar	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# MCGI	-	-	O
#
# NEW STRING
# MCGI	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #SEHUN	-	-	O
#
# NEW STRING
# #SEHUN	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Ichimoku	-	-	O
#
# NEW STRING
# #Ichimoku	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Cheyenne	-	-	O
#
# NEW STRING
# #Cheyenne	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #roma	-	-	O
#
# NEW STRING
# #roma	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Elementary	-	-	O
#
# NEW STRING
# #Elementary	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# R30000	-	-	O
#
# NEW STRING
# R30000	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Arctic	-	-	O
#
# NEW STRING
# #Arctic	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# sea	-	-	O
#
# NEW STRING
# sea	-	-	I-LOC
#
# OLD LABEL: O
#
# NEW LABEL: I-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# OnlyPiolou	-	-	O
#
# NEW STRING
# OnlyPiolou	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# La	-	-	O
#
# NEW STRING
# La	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Provence	-	-	O
#
# NEW STRING
# Provence	-	-	I-ORG
#
# OLD LABEL: O
#
# NEW LABEL: I-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #EURO2016	-	-	O
#
# NEW STRING
# #EURO2016	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #AUT	-	-	O
#
# NEW STRING
# #AUT	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ReverbNation	-	-	O
#
# NEW STRING
# #ReverbNation	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Tfry	-	-	O
#
# NEW STRING
# Tfry	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Trump	-	-	O
#
# NEW STRING
# #Trump	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Brimfield	-	-	O
#
# NEW STRING
# #Brimfield	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# elo	-	-	O
#
# NEW STRING
# elo	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Wade	-	-	O
#
# NEW STRING
# #Wade	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Everett	-	-	O
#
# NEW STRING
# #Everett	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ECF	-	-	O
#
# NEW STRING
# #ECF	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Ukraine	-	-	O
#
# NEW STRING
# #Ukraine	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Sentsov	-	-	O
#
# NEW STRING
# #Sentsov	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Afanasyev	-	-	O
#
# NEW STRING
# #Afanasyev	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Kolchenko	-	-	O
#
# NEW STRING
# #Kolchenko	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Soloshenko	-	-	O
#
# NEW STRING
# #Soloshenko	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Russia	-	-	O
#
# NEW STRING
# #Russia	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Discovery	-	-	O
#
# NEW STRING
# Discovery	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Baywatch	-	-	O
#
# NEW STRING
# #Baywatch	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #TimPeake	-	-	O
#
# NEW STRING
# #TimPeake	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# DUTERTE	-	-	B-PER
#
# NEW STRING
# DUTERTE	-	-	B-MISC
#
# OLD LABEL: B-PER
#
# NEW LABEL: B-MISC
#
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# GRAND	-	-	O
#
# NEW STRING
# GRAND	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# RALLY	-	-	O
#
# NEW STRING
# RALLY	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #GOPDebate	-	-	O
#
# NEW STRING
# #GOPDebate	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Cruz	-	-	O
#
# NEW STRING
# #Cruz	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Trump	-	-	O
#
# NEW STRING
# #Trump	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ThreatWire	-	-	O
#
# NEW STRING
# #ThreatWire	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ELEAGUE	-	-	O
#
# NEW STRING
# #ELEAGUE	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #tbs	-	-	O
#
# NEW STRING
# #tbs	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Zola	-	-	O
#
# NEW STRING
# Zola	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #GreenWall	-	-	O
#
# NEW STRING
# #GreenWall	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# B	-	-	O
#
# NEW STRING
# B	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# In.Sight	-	-	O
#
# NEW STRING
# In.Sight	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# k3	-	-	O
#
# NEW STRING
# k3	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# KKC	-	-	O
#
# NEW STRING
# KKC	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #ShawnWorldTourCologne	-	-	O
#
# NEW STRING
# #ShawnWorldTourCologne	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# United	-	-	O
#
# NEW STRING
# United	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# States	-	-	O
#
# NEW STRING
# States	-	-	I-LOC
#
# OLD LABEL: O
#
# NEW LABEL: I-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# of	-	-	O
#
# NEW STRING
# of	-	-	I-LOC
#
# OLD LABEL: O
#
# NEW LABEL: I-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# America	-	-	O
#
# NEW STRING
# America	-	-	I-LOC
#
# OLD LABEL: O
#
# NEW LABEL: I-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #AV/IT	-	-	O
#
# NEW STRING
# #AV/IT	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Leadership	-	-	B-MISC
#
# NEW STRING
# Leadership	-	-	I-MISC
#
# OLD LABEL: B-MISC
#
# NEW LABEL: I-MISC
#
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Daraa	-	-	O
#
# NEW STRING
# #Daraa	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Bishop	-	-	O
#
# NEW STRING
# Bishop	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Father	-	-	O
#
# NEW STRING
# Father	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# God	-	-	O
#
# NEW STRING
# God	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# MD	-	-	O
#
# NEW STRING
# MD	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# ZTD	-	-	O
#
# NEW STRING
# ZTD	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Sigma	-	-	O
#
# NEW STRING
# Sigma	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# AB	-	-	O
#
# NEW STRING
# AB	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Jesus	-	-	O
#
# NEW STRING
# #Jesus	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #velingrad	-	-	O
#
# NEW STRING
# #velingrad	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #JESUS	-	-	O
#
# NEW STRING
# #JESUS	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Murdoch	-	-	O
#
# NEW STRING
# #Murdoch	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #SouthBelfast	-	-	O
#
# NEW STRING
# #SouthBelfast	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# AR	-	-	O
#
# NEW STRING
# AR	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Greendale	-	-	O
#
# NEW STRING
# #Greendale	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# WI	-	-	O
#
# NEW STRING
# WI	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #PerdueCrew	-	-	O
#
# NEW STRING
# #PerdueCrew	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# FM	-	-	O
#
# NEW STRING
# FM	-	-	B-PER
#
# OLD LABEL: O
#
# NEW LABEL: B-PER
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Iran	-	-	O
#
# NEW STRING
# #Iran	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# KBS	-	-	O
#
# NEW STRING
# KBS	-	-	B-ORG
#
# OLD LABEL: O
#
# NEW LABEL: B-ORG
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #SJA	-	-	O
#
# NEW STRING
# #SJA	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #MedicalFirstResponders	-	-	O
#
# NEW STRING
# #MedicalFirstResponders	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Ontario	-	-	O
#
# NEW STRING
# #Ontario	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# #Championship	-	-	O
#
# NEW STRING
# #Championship	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# NO.X	-	-	O
#
# NEW STRING
# NO.X	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Hologram	-	-	O
#
# NEW STRING
# Hologram	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Qianxi	-	-	O
#
# NEW STRING
# Qianxi	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# OPPO	-	-	O
#
# NEW STRING
# OPPO	-	-	B-MISC
#
# OLD LABEL: O
#
# NEW LABEL: B-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# R9	-	-	O
#
# NEW STRING
# R9	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# CF	-	-	O
#
# NEW STRING
# CF	-	-	I-MISC
#
# OLD LABEL: O
#
# NEW LABEL: I-MISC
#
# ALSO NEW ADDITION AS WELL
# --------------------------------------------------
# CHANGED ADDITION
# OLD STRING
# Ireland	-	-	O
#
# NEW STRING
# Ireland	-	-	B-LOC
#
# OLD LABEL: O
#
# NEW LABEL: B-LOC
#
# ALSO NEW ADDITION AS WELL
# TOTAL OLD ENTITIES 1183
# TOTAL NEW ENTITIES 1334
# TOTAL CHANGED ADDITIONS 153
# TOTAL NEW ADDITIONS 151

# %%
original_merged_dataset_no_o =  original_dataset_merged[~(original_dataset_merged['FINAL NER Label'] == 'O')]
original_merged_dataset_no_o
# Out:
#     Sentence Index      Word  Start Word Index  End Word Index  POS Label  \
# 2                7       xb1                13              13  ['PROPN']
# 5               12       cod                14              14  ['PROPN']
# 36              50  benadryl                 1               1  ['PROPN']
# 61              68       ww1                12              12  ['PROPN']
# 76              81    sostar                 3               3  ['PROPN']
# ..             ...       ...               ...             ...        ...
# 0              656       sea                18              18        NaN
# 0              961    united                 9               9        NaN
# 0              961    states                10              10        NaN
# 0              961        of                11              11        NaN
# 0              961   america                12              12        NaN
#
#    NER Label                                              Tweet  \
# 2      ['O']  i 've entered for a chance to win a copy of @u...
# 5      ['O']  rt @user2437 : if you have short memory let me...
# 36     ['O']              @user1039 benadryl is your friend lol
# 61     ['O']  @user1651 with there boycotts and the way they...
# 76     ['O']                      @user2243 noo ... sostar !!!!
# ..       ...                                                ...
# 0        NaN  rt @user522 : “ it ’s a red flag ” — polar bea...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
# 0        NaN  rt @user1275 : @user737 @user1807 i like that ...
#
#                                      Tweet POS Labels  \
# 2   ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 5   ['X', 'X', 'PUNCT', 'SCONJ', 'PRON', 'VERB', '...
# 36  ['PROPN', 'PROPN', 'AUX', 'PRON', 'NOUN', 'INTJ']
# 61  ['PROPN', 'ADP', 'PRON', 'NOUN', 'CCONJ', 'DET...
# 76       ['PROPN', 'INTJ', 'PUNCT', 'PROPN', 'PUNCT']
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                      Tweet NER Labels PROPOSED NER Label  \
# 2   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                  O
# 5   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# 36                     ['O', 'O', 'O', 'O', 'O', 'O']             B-MISC
# 61  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             B-MISC
# 76                          ['O', 'O', 'O', 'O', 'O']                  O
# ..                                                ...                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#    FINAL NER Label
# 2            B-ORG
# 5           B-MISC
# 36          B-MISC
# 61          B-MISC
# 76          B-MISC
# ..             ...
# 0            I-LOC
# 0            B-LOC
# 0            I-LOC
# 0            I-LOC
# 0            I-LOC
#
# [156 rows x 11 columns]
