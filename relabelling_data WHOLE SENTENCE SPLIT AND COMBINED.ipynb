# %% [markdown]
# Leung Wai Liu <br>
# JPMC <br>
# July 25, 2022 <br>
# Twitter Relabelling WHOLE SENTENCE

# %%
import pandas as pd
import numpy as np
import wordninja
import spacy
import re
from collections import Counter

# %%
nlp = spacy.load('en_core_web_trf')

# %%
combined_df = pd.read_csv('logs/combined_final.tsv', sep='\t')
combined_df
# Out:
#            Word  Word Index POS Label NER Label  \
# 0       poutine          11     PROPN         O
# 1        friday           7     PROPN         O
# 2      @user444          17     PROPN         O
# 3     @user1598           1     PROPN         O
# 4        gospel           7     PROPN         O
# ...         ...         ...       ...       ...
# 1013    @user70           3     PROPN         O
# 1014   @user660           5     PROPN         O
# 1015  @user2046           0     PROPN         O
# 1016  @user2242          20     PROPN         O
# 1017   @user317           0     PROPN         O
#
#                                                   Tweet
# 0     rt @user1787 : i asked siri to remind me about...
# 1     rt @user912 : you know it 's friday when the p...
# 2     mikel obi & his girl olga diyachenko spend hol...
# 3     " @user1598 : super junior ’s siwon transforms...
# 4     " do n't move on from the gospel , move into t...
# ...                                                 ...
# 1013  rt @user2041 : @user70 happy birthday man ! le...
# 1014   rt @user1157 : happy birthday @user660 ! url1209
# 1015  @user2046 further you do the swedish social se...
# 1016  @user2046 further you do the swedish social se...
# 1017  @user317 we sure did . came out , and said it ...
#
# [1018 rows x 5 columns]

# %%
# Changing all @user to be B-PER for now
new_label = combined_df['NER Label'].tolist()
new_pos = combined_df['POS Label'].tolist()

for index, row in combined_df.iterrows():
    
    # retrieving the the information of a particular row
    particular_word = row['Word']
    particular_start_index = row['Word Index']
    original_sentence = row['Tweet']

    # splitting the original sentence
    original_sentence_split = original_sentence.split(' ')
    to_feed_sentence = original_sentence
    to_feed_split = original_sentence_split

    print('-' * 50)
    print('Original Particular word')
    print(particular_word)
    print("Original Sentence Split")     
    print(original_sentence_split)
    print("Original Start Index")
    print(particular_start_index)

    # setting up the initial parameters  
    char_index = 0
    iterate_word_index = 0
    is_hashtag = False
    encode = ''
    encode_len = 0

    # while iterate_word_index < particular_start_index:
    #     particular_word_in_sentence = original_sentence_split[iterate_word_index]
    #     char_index += len(particular_word_in_sentence)
        
    #     # accounting for the space
    #     char_index += 1
    #     iterate_word_index += 1

   

    # if a particular word is a user tag - label it has a person
    if '@user' in particular_word:
        print("CHANGE USER ONLY")
        print("-" * 50)
        new_label[index] = 'B-PER'
        new_pos[index] = 'User: No change'
    else:
        # PRE-PROCESSING THE ENTIRE SENTENCE
        print("FINDING ENTITY OF WORD")

        pre_processed_sentence_split = original_sentence_split
        pre_processed_word_start_index = particular_start_index
        pre_processed_char_start_index = 0
        pre_processed_char_start_index_mushed = 0
        pre_processed_sentence_split_string = original_sentence
        is_hashtag = False

        # if entity is hashtag
        pre_processed_sentence_split_combined = original_sentence_split
        pre_processed_word_start_index_combined = particular_start_index
        pre_processed_char_start_index_combined = 0
        pre_processed_char_start_index_mushed_combined = 0
        pre_processed_sentence_split_string_combined = original_sentence

        part_of_sentence_before_particular_word_combined = []
        part_of_sentence_before_particular_word_string_combined = ''
        pre_processed_char_start_index_combined = 0

        part_of_sentence_before_particular_word_string_mushed_combined = ''
        pre_processed_char_start_index_mushed_combined = 0

        combined_word_length = len(particular_word)
        split_word_length = 0
        

        # checking if a particular word is a hashtag or not
        particular_word_check_for_hashtag = particular_word[0:1]
        if particular_word_check_for_hashtag == '#':
            print("ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL")
            is_hashtag = True
            combined_word_length -= 1

        word_index = 0 
        while word_index in range(len(pre_processed_sentence_split)):
            word_in_sentence = pre_processed_sentence_split[word_index]
            check_for_hashtag = word_in_sentence[0:1]
            to_add_word_index = 1

            # if hashtag, split the sentence
            if check_for_hashtag == '#' or (check_for_hashtag != '#' and word_index == pre_processed_word_start_index):
                if is_hashtag == True:
                    word_in_sentence = word_in_sentence[1:]
                
                print(word_in_sentence)
                word_in_sentence = wordninja.split(word_in_sentence)
                print(word_in_sentence)
                to_add_word_index = len(word_in_sentence)
                to_add_word_string = ' '.join(word_in_sentence)
                to_add_word_string_length = len(to_add_word_string)

                # if check_for_hashtag != '#' and word_index == pre_processed_word_start_index:
                #     print(split_word_length)
                #     split_word_length = len(''.join(word_in_sentence))
                
                # replacing the original phrase with the split
                pre_processed_sentence_split = pre_processed_sentence_split[:(word_index)] + word_in_sentence + pre_processed_sentence_split[(word_index + 1):]

                if (word_index < pre_processed_word_start_index):
                    pre_processed_word_start_index += (to_add_word_index - 1)
             
            word_index += to_add_word_index
        
        

        pre_processed_sentence_split_string = ' '.join(pre_processed_sentence_split)

        # Getting the specific character of the post pre-processed sentence
        part_of_sentence_before_particular_word = pre_processed_sentence_split[:pre_processed_word_start_index]
        part_of_sentence_before_particular_word_string = ' '.join(part_of_sentence_before_particular_word)

        pre_processed_char_start_index = (len(part_of_sentence_before_particular_word_string)) + 1

        # Without getting the string without spaces
        part_of_sentence_before_particular_word_string_mushed = ''.join(part_of_sentence_before_particular_word)
        pre_processed_char_start_index_mushed = (len(part_of_sentence_before_particular_word_string_mushed))
        

        word_index = 0 
        while word_index in range(len(pre_processed_sentence_split_combined)):
            word_in_sentence = pre_processed_sentence_split_combined[word_index]
            check_for_hashtag = word_in_sentence[0:1]
            to_add_word_index = 1

            # if hashtag, split the sentence
            if check_for_hashtag == '#':
                pre_processed_sentence_split_combined[word_index] = word_in_sentence[1:]

                if word_index != pre_processed_word_start_index_combined:
                    word_in_sentence = wordninja.split(word_in_sentence)
                    to_add_word_index = len(word_in_sentence)
                    to_add_word_string = ' '.join(word_in_sentence)
                    to_add_word_string_length = len(to_add_word_string)
                    
                    # replacing the original phrase with the split
                    pre_processed_sentence_split_combined = pre_processed_sentence_split_combined[:(word_index)] + word_in_sentence + pre_processed_sentence_split_combined[(word_index + 1):]

                    if (word_index < pre_processed_word_start_index_combined):
                        pre_processed_word_start_index_combined += (to_add_word_index - 1)
            
            word_index += to_add_word_index

        pre_processed_sentence_split_string_combined = ' '.join(pre_processed_sentence_split_combined)

        # Getting the specific character of the post pre-processed sentence
        part_of_sentence_before_particular_word_combined = pre_processed_sentence_split[:pre_processed_word_start_index_combined]
        part_of_sentence_before_particular_word_string_combined = ' '.join(part_of_sentence_before_particular_word_combined)

        pre_processed_char_start_index_combined = (len(part_of_sentence_before_particular_word_string_combined)) + 1

        # Without getting the string without spaces
        part_of_sentence_before_particular_word_string_mushed_combined = ''.join(part_of_sentence_before_particular_word_combined)
        pre_processed_char_start_index_mushed_combined = (len(part_of_sentence_before_particular_word_string_mushed_combined))
            

        
        # encoding into spacy document to get the NER entity of each word
        sentence_doc = nlp(pre_processed_sentence_split_string) # splitted word phrase
        word_entities = [(e.text, e.ent_iob_, e.ent_type_, e.pos_) for e in sentence_doc]


        sentence_doc_combined = nlp(pre_processed_sentence_split_string_combined)
        word_entities_combined = [(f.text, f.ent_iob_, f.ent_type_, f.pos_) for f in sentence_doc_combined]
        

        # check if the length of the entities that fed in matches with the len of entities that came out
     
        print("FOR NON COMBINED WORDS")

        print("After processing")
        print(pre_processed_sentence_split)
        print("After processing joint sentence")
        print(pre_processed_sentence_split_string)
        print("Pre processed word start index")
        print(pre_processed_word_start_index)
        print("Pre processed char start index")
        print(pre_processed_char_start_index)
        print("Pre processed split string")
        print(pre_processed_sentence_split_string)
        print("Part of sentence before particular word")
        print(part_of_sentence_before_particular_word)
        print("Part of sentence before particular word string")
        print(part_of_sentence_before_particular_word_string)
        print("Part of sentence before particular word string mushed")
        print(part_of_sentence_before_particular_word_string_mushed)
        print("FINAL: Pre Processed char start index mushed")
        print(pre_processed_char_start_index_mushed)


        print("FOR COMBINED WORDS:")

        print("After processing combined")
        print(pre_processed_sentence_split_combined)
        print("After processing joint sentence combined")
        print(pre_processed_sentence_split_string_combined)
        print("Pre processed word start index combined")
        print(pre_processed_word_start_index_combined)
        print("Pre processed char start index combined")
        print(pre_processed_char_start_index_combined)
        print("Pre processed split string combined")
        print(pre_processed_sentence_split_string_combined)
        print("Part of sentence before particular word combined")
        print(part_of_sentence_before_particular_word_combined)
        print("Part of sentence before particular word string combined")
        print(part_of_sentence_before_particular_word_string_combined)
        print("Part of sentence before particular word string mushed combined")
        print(part_of_sentence_before_particular_word_string_mushed_combined)
        print("FINAL: Pre Processed char start index mushed combined")
        print(pre_processed_char_start_index_mushed)
        
        
        print('Word Entities result')
        print(word_entities)

        print("Word Entities COMBINED result")
        print(word_entities_combined)
       
  
        # retrieving the entities to verify:

        # NON COMBINED SENTENCE 
        entities_index_non_combined = 0
        entities_char_non_combined = 0

        word_entities_to_verify_non_combined = []
        print("PRINTING NON COMBINED")
        for entity in word_entities:
            if entities_char_non_combined < pre_processed_char_start_index_mushed:
                print(entity)
                particular_entity_word = entity[0]
                particular_entity_word_length = len(particular_entity_word)
                entities_index_non_combined += 1
                entities_char_non_combined += particular_entity_word_length
            
        
        while entities_char_non_combined < (pre_processed_char_start_index_mushed + combined_word_length):
            entity_to_append_non_combined = word_entities[entities_index_non_combined]
            word_entities_to_verify_non_combined.append(entity_to_append_non_combined)
            
            entities_char_non_combined += len(entity_to_append_non_combined[0])
            entities_index_non_combined += 1
        

        # COMBINED SENTENCE
        entities_index_combined = 0
        entities_char_combined = 0

        word_entities_to_verify_combined = []
        print("PRINTING COMBINED")
        for entity in word_entities_combined:
            if entities_char_combined < pre_processed_char_start_index_mushed_combined:
                print(entity)
                particular_entity_word_combined = entity[0]
                particular_entity_word_length_combined = len(particular_entity_word_combined)
                entities_index_combined += 1
                entities_char_combined += particular_entity_word_length_combined
            
        
        while entities_char_combined < (pre_processed_char_start_index_mushed_combined + combined_word_length):
            entity_to_append_combined = word_entities_combined[entities_index_combined]
            word_entities_to_verify_combined.append(entity_to_append_combined)
            
            entities_char_combined += len(entity_to_append_combined[0])
            entities_index_combined += 1


        print("ENTITIES TO VERIFY NON COMBINED")
        print(word_entities_to_verify_non_combined)

        print("ENTITIES TO VERIFY COMBINED")
        print(word_entities_to_verify_combined)

        # retrieving all the labels and pos tags from each phrase (if any)
        label = []
        pos = []

        
        # otherwise append all of the NER tags from the split word entity (if there are)
        for numents in range(len(word_entities_to_verify_non_combined)):
            if word_entities_to_verify_non_combined[numents][2] != '':
                label.append(word_entities_to_verify_non_combined[numents][2])
            pos.append(word_entities_to_verify_non_combined[numents][3])

        for numents in range(len(word_entities_to_verify_combined)):
            if word_entities_to_verify_combined[numents][2] != '':
                label.append(word_entities_to_verify_combined[numents][2])
            pos.append(word_entities_to_verify_combined[numents][3])
        
        print(label)
        print(pos)
        # Filtering - if the label list is not empty: 
        if label != []:
            # Find the most common label tagging
            label_counter = Counter(label)
            label_most_common = (label_counter.most_common(1))[0][0]
            
            # checking the label itself and then labeling it based on the Tweebank labelling standard
            if label_most_common == 'PERSON':
                new_label[index] = 'B-PER'
            elif label_most_common == 'FAC':
                new_label[index] = 'B-LOC'
            elif label_most_common == 'NORP':
                new_label[index] = 'B-ORG'
            elif label_most_common == 'ORG':
                new_label[index] = 'B-ORG'
            elif label_most_common != 'MONEY' or label_most_common != 'QUANTITY':
                new_label[index] = 'B-MISC'

            pos_counter = Counter(pos)
            pos_most_common = (pos_counter.most_common(1)[0][0])
            new_pos[index] = pos_most_common
            
        else: 
            # If label list is empty, Looking through pos taggings to see if we can classify anything
            # if there is a proper noun, then it can still be classified as miscellaneous
            if 'PROPN' in pos: 
                new_label[index] = 'B-MISC'
                new_pos[index] = 'PROPN'
            elif 'NOUN' in pos:
                new_label[index] = 'B-MISC'
                new_pos[index] = 'NOUN'
            else:
                # if it is not able to find a label, then we find what SPACY thinks the POS tagging is
                pos_counter = Counter(pos)
                pos_most_common = (pos_counter.most_common(1)[0][0])
                new_pos[index] = pos_most_common
# Out:
# --------------------------------------------------
# Original Particular word
# poutine
# Original Sentence Split
# ['rt', '@user1787', ':', 'i', 'asked', 'siri', 'to', 'remind', 'me', 'about', 'my', 'poutine', 'in', 'the', 'office', 'fridge', 'but', 'she', 'misinterpreted', 'and', 'probably', 'alerted', 'the', 'fbi', '.', 'url222', '…']
# Original Start Index
# 11
# FINDING ENTITY OF WORD
# poutine
# ['pout', 'in', 'e']
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user1787', ':', 'i', 'asked', 'siri', 'to', 'remind', 'me', 'about', 'my', 'pout', 'in', 'e', 'in', 'the', 'office', 'fridge', 'but', 'she', 'misinterpreted', 'and', 'probably', 'alerted', 'the', 'fbi', '.', 'url222', '…']
# After processing joint sentence
# rt @user1787 : i asked siri to remind me about my pout in e in the office fridge but she misinterpreted and probably alerted the fbi . url222 …
# Pre processed word start index
# 11
# Pre processed char start index
# 50
# Pre processed split string
# rt @user1787 : i asked siri to remind me about my pout in e in the office fridge but she misinterpreted and probably alerted the fbi . url222 …
# Part of sentence before particular word
# ['rt', '@user1787', ':', 'i', 'asked', 'siri', 'to', 'remind', 'me', 'about', 'my']
# Part of sentence before particular word string
# rt @user1787 : i asked siri to remind me about my
# Part of sentence before particular word string mushed
# rt@user1787:iaskedsiritoremindmeaboutmy
# FINAL: Pre Processed char start index mushed
# 39
# FOR COMBINED WORDS:
# After processing combined
# ['rt', '@user1787', ':', 'i', 'asked', 'siri', 'to', 'remind', 'me', 'about', 'my', 'poutine', 'in', 'the', 'office', 'fridge', 'but', 'she', 'misinterpreted', 'and', 'probably', 'alerted', 'the', 'fbi', '.', 'url222', '…']
# After processing joint sentence combined
# rt @user1787 : i asked siri to remind me about my poutine in the office fridge but she misinterpreted and probably alerted the fbi . url222 …
# Pre processed word start index combined
# 11
# Pre processed char start index combined
# 50
# Pre processed split string combined
# rt @user1787 : i asked siri to remind me about my poutine in the office fridge but she misinterpreted and probably alerted the fbi . url222 …
# Part of sentence before particular word combined
# ['rt', '@user1787', ':', 'i', 'asked', 'siri', 'to', 'remind', 'me', 'about', 'my']
# Part of sentence before particular word string combined
# rt @user1787 : i asked siri to remind me about my
# Part of sentence before particular word string mushed combined
# rt@user1787:iaskedsiritoremindmeaboutmy
# FINAL: Pre Processed char start index mushed combined
# 39
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user1787', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('i', 'O', '', 'PRON'), ('asked', 'O', '', 'VERB'), ('siri', 'O', '', 'PROPN'), ('to', 'O', '', 'PART'), ('remind', 'O', '', 'VERB'), ('me', 'O', '', 'PRON'), ('about', 'O', '', 'ADP'), ('my', 'O', '', 'PRON'), ('pout', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('e', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('office', 'O', '', 'NOUN'), ('fridge', 'O', '', 'NOUN'), ('but', 'O', '', 'CCONJ'), ('she', 'O', '', 'PRON'), ('misinterpreted', 'O', '', 'VERB'), ('and', 'O', '', 'CCONJ'), ('probably', 'O', '', 'ADV'), ('alerted', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('fbi', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('url222', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'PROPN'), ('@user1787', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('i', 'O', '', 'PRON'), ('asked', 'O', '', 'VERB'), ('siri', 'O', '', 'PROPN'), ('to', 'O', '', 'PART'), ('remind', 'O', '', 'VERB'), ('me', 'O', '', 'PRON'), ('about', 'O', '', 'ADP'), ('my', 'O', '', 'PRON'), ('poutine', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('office', 'O', '', 'NOUN'), ('fridge', 'O', '', 'NOUN'), ('but', 'O', '', 'CCONJ'), ('she', 'O', '', 'PRON'), ('misinterpreted', 'O', '', 'VERB'), ('and', 'O', '', 'CCONJ'), ('probably', 'O', '', 'ADV'), ('alerted', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('fbi', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('url222', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user1787', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# ('i', 'O', '', 'PRON')
# ('asked', 'O', '', 'VERB')
# ('siri', 'O', '', 'PROPN')
# ('to', 'O', '', 'PART')
# ('remind', 'O', '', 'VERB')
# ('me', 'O', '', 'PRON')
# ('about', 'O', '', 'ADP')
# ('my', 'O', '', 'PRON')
# PRINTING COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user1787', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# ('i', 'O', '', 'PRON')
# ('asked', 'O', '', 'VERB')
# ('siri', 'O', '', 'PROPN')
# ('to', 'O', '', 'PART')
# ('remind', 'O', '', 'VERB')
# ('me', 'O', '', 'PRON')
# ('about', 'O', '', 'ADP')
# ('my', 'O', '', 'PRON')
# ENTITIES TO VERIFY NON COMBINED
# [('pout', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('e', 'O', '', 'NOUN')]
# ENTITIES TO VERIFY COMBINED
# [('poutine', 'O', '', 'NOUN')]
# []
# ['NOUN', 'ADP', 'NOUN', 'NOUN']
# --------------------------------------------------
# Original Particular word
# friday
# Original Sentence Split
# ['rt', '@user912', ':', 'you', 'know', 'it', "'s", 'friday', 'when', 'the', 'port2port', 'newsletter', 'hits', 'your', 'inbox', '.', 'sign', 'up', 'if', 'you', 'like', 'fine', 'wines', 'too', '.', 'url1265', '…']
# Original Start Index
# 7
# FINDING ENTITY OF WORD
# friday
# ['friday']
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user912', ':', 'you', 'know', 'it', "'s", 'friday', 'when', 'the', 'port2port', 'newsletter', 'hits', 'your', 'inbox', '.', 'sign', 'up', 'if', 'you', 'like', 'fine', 'wines', 'too', '.', 'url1265', '…']
# After processing joint sentence
# rt @user912 : you know it 's friday when the port2port newsletter hits your inbox . sign up if you like fine wines too . url1265 …
# Pre processed word start index
# 7
# Pre processed char start index
# 29
# Pre processed split string
# rt @user912 : you know it 's friday when the port2port newsletter hits your inbox . sign up if you like fine wines too . url1265 …
# Part of sentence before particular word
# ['rt', '@user912', ':', 'you', 'know', 'it', "'s"]
# Part of sentence before particular word string
# rt @user912 : you know it 's
# Part of sentence before particular word string mushed
# rt@user912:youknowit's
# FINAL: Pre Processed char start index mushed
# 22
# FOR COMBINED WORDS:
# After processing combined
# ['rt', '@user912', ':', 'you', 'know', 'it', "'s", 'friday', 'when', 'the', 'port2port', 'newsletter', 'hits', 'your', 'inbox', '.', 'sign', 'up', 'if', 'you', 'like', 'fine', 'wines', 'too', '.', 'url1265', '…']
# After processing joint sentence combined
# rt @user912 : you know it 's friday when the port2port newsletter hits your inbox . sign up if you like fine wines too . url1265 …
# Pre processed word start index combined
# 7
# Pre processed char start index combined
# 29
# Pre processed split string combined
# rt @user912 : you know it 's friday when the port2port newsletter hits your inbox . sign up if you like fine wines too . url1265 …
# Part of sentence before particular word combined
# ['rt', '@user912', ':', 'you', 'know', 'it', "'s"]
# Part of sentence before particular word string combined
# rt @user912 : you know it 's
# Part of sentence before particular word string mushed combined
# rt@user912:youknowit's
# FINAL: Pre Processed char start index mushed combined
# 22
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user912', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('you', 'O', '', 'PRON'), ('know', 'O', '', 'VERB'), ('it', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('friday', 'O', '', 'PROPN'), ('when', 'O', '', 'SCONJ'), ('the', 'O', '', 'DET'), ('port2port', 'O', '', 'PROPN'), ('newsletter', 'O', '', 'NOUN'), ('hits', 'O', '', 'VERB'), ('your', 'O', '', 'PRON'), ('inbox', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('sign', 'O', '', 'VERB'), ('up', 'O', '', 'ADP'), ('if', 'O', '', 'SCONJ'), ('you', 'O', '', 'PRON'), ('like', 'O', '', 'VERB'), ('fine', 'O', '', 'ADJ'), ('wines', 'O', '', 'NOUN'), ('too', 'O', '', 'ADV'), ('.', 'O', '', 'PUNCT'), ('url1265', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'PROPN'), ('@user912', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('you', 'O', '', 'PRON'), ('know', 'O', '', 'VERB'), ('it', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('friday', 'O', '', 'PROPN'), ('when', 'O', '', 'SCONJ'), ('the', 'O', '', 'DET'), ('port2port', 'O', '', 'PROPN'), ('newsletter', 'O', '', 'NOUN'), ('hits', 'O', '', 'VERB'), ('your', 'O', '', 'PRON'), ('inbox', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('sign', 'O', '', 'VERB'), ('up', 'O', '', 'ADP'), ('if', 'O', '', 'SCONJ'), ('you', 'O', '', 'PRON'), ('like', 'O', '', 'VERB'), ('fine', 'O', '', 'ADJ'), ('wines', 'O', '', 'NOUN'), ('too', 'O', '', 'ADV'), ('.', 'O', '', 'PUNCT'), ('url1265', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user912', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('you', 'O', '', 'PRON')
# ('know', 'O', '', 'VERB')
# ('it', 'O', '', 'PRON')
# ("'s", 'O', '', 'AUX')
# PRINTING COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user912', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('you', 'O', '', 'PRON')
# ('know', 'O', '', 'VERB')
# ('it', 'O', '', 'PRON')
# ("'s", 'O', '', 'AUX')
# ENTITIES TO VERIFY NON COMBINED
# [('friday', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('friday', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# @user444
# Original Sentence Split
# ['mikel', 'obi', '&', 'his', 'girl', 'olga', 'diyachenko', 'spend', 'holiday', 'in', 'spain', 'with', 'their', 'kids', '…', 'url1219', 'via', '@user444']
# Original Start Index
# 17
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user1598
# Original Sentence Split
# ['"', '@user1598', ':', 'super', 'junior', '’s', 'siwon', 'transforms', 'into', '‘', 'captain', 'choi', '’', 'for', '“', 'poseidon', '”', 'url139', '"']
# Original Start Index
# 1
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# gospel
# Original Sentence Split
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# Original Start Index
# 7
# FINDING ENTITY OF WORD
# gospel
# ['gospel']
# FOR NON COMBINED WORDS
# After processing
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# After processing joint sentence
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Pre processed word start index
# 7
# Pre processed char start index
# 26
# Pre processed split string
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Part of sentence before particular word
# ['"', 'do', "n't", 'move', 'on', 'from', 'the']
# Part of sentence before particular word string
# " do n't move on from the
# Part of sentence before particular word string mushed
# "don'tmoveonfromthe
# FINAL: Pre Processed char start index mushed
# 19
# FOR COMBINED WORDS:
# After processing combined
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# After processing joint sentence combined
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Pre processed word start index combined
# 7
# Pre processed char start index combined
# 26
# Pre processed split string combined
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Part of sentence before particular word combined
# ['"', 'do', "n't", 'move', 'on', 'from', 'the']
# Part of sentence before particular word string combined
# " do n't move on from the
# Part of sentence before particular word string mushed combined
# "don'tmoveonfromthe
# FINAL: Pre Processed char start index mushed combined
# 19
# Word Entities result
# [('"', 'O', '', 'PUNCT'), ('do', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('move', 'O', '', 'VERB'), ('on', 'O', '', 'ADP'), ('from', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), (',', 'O', '', 'PUNCT'), ('move', 'O', '', 'VERB'), ('into', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT'), ('todd', 'B', 'PERSON', 'PROPN'), ('friel', 'I', 'PERSON', 'PROPN')]
# Word Entities COMBINED result
# [('"', 'O', '', 'PUNCT'), ('do', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('move', 'O', '', 'VERB'), ('on', 'O', '', 'ADP'), ('from', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), (',', 'O', '', 'PUNCT'), ('move', 'O', '', 'VERB'), ('into', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT'), ('todd', 'B', 'PERSON', 'PROPN'), ('friel', 'I', 'PERSON', 'PROPN')]
# PRINTING NON COMBINED
# ('"', 'O', '', 'PUNCT')
# ('do', 'O', '', 'AUX')
# ("n't", 'O', '', 'PART')
# ('move', 'O', '', 'VERB')
# ('on', 'O', '', 'ADP')
# ('from', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# PRINTING COMBINED
# ('"', 'O', '', 'PUNCT')
# ('do', 'O', '', 'AUX')
# ("n't", 'O', '', 'PART')
# ('move', 'O', '', 'VERB')
# ('on', 'O', '', 'ADP')
# ('from', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# ENTITIES TO VERIFY NON COMBINED
# [('gospel', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('gospel', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# gospel
# Original Sentence Split
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# Original Start Index
# 12
# FINDING ENTITY OF WORD
# gospel
# ['gospel']
# FOR NON COMBINED WORDS
# After processing
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# After processing joint sentence
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Pre processed word start index
# 12
# Pre processed char start index
# 49
# Pre processed split string
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Part of sentence before particular word
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the']
# Part of sentence before particular word string
# " do n't move on from the gospel , move into the
# Part of sentence before particular word string mushed
# "don'tmoveonfromthegospel,moveintothe
# FINAL: Pre Processed char start index mushed
# 37
# FOR COMBINED WORDS:
# After processing combined
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the', 'gospel', '!', '"', 'todd', 'friel']
# After processing joint sentence combined
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Pre processed word start index combined
# 12
# Pre processed char start index combined
# 49
# Pre processed split string combined
# " do n't move on from the gospel , move into the gospel ! " todd friel
# Part of sentence before particular word combined
# ['"', 'do', "n't", 'move', 'on', 'from', 'the', 'gospel', ',', 'move', 'into', 'the']
# Part of sentence before particular word string combined
# " do n't move on from the gospel , move into the
# Part of sentence before particular word string mushed combined
# "don'tmoveonfromthegospel,moveintothe
# FINAL: Pre Processed char start index mushed combined
# 37
# Word Entities result
# [('"', 'O', '', 'PUNCT'), ('do', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('move', 'O', '', 'VERB'), ('on', 'O', '', 'ADP'), ('from', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), (',', 'O', '', 'PUNCT'), ('move', 'O', '', 'VERB'), ('into', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT'), ('todd', 'B', 'PERSON', 'PROPN'), ('friel', 'I', 'PERSON', 'PROPN')]
# Word Entities COMBINED result
# [('"', 'O', '', 'PUNCT'), ('do', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('move', 'O', '', 'VERB'), ('on', 'O', '', 'ADP'), ('from', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), (',', 'O', '', 'PUNCT'), ('move', 'O', '', 'VERB'), ('into', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('gospel', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT'), ('todd', 'B', 'PERSON', 'PROPN'), ('friel', 'I', 'PERSON', 'PROPN')]
# PRINTING NON COMBINED
# ('"', 'O', '', 'PUNCT')
# ('do', 'O', '', 'AUX')
# ("n't", 'O', '', 'PART')
# ('move', 'O', '', 'VERB')
# ('on', 'O', '', 'ADP')
# ('from', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# ('gospel', 'O', '', 'PROPN')
# (',', 'O', '', 'PUNCT')
# ('move', 'O', '', 'VERB')
# ('into', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# PRINTING COMBINED
# ('"', 'O', '', 'PUNCT')
# ('do', 'O', '', 'AUX')
# ("n't", 'O', '', 'PART')
# ('move', 'O', '', 'VERB')
# ('on', 'O', '', 'ADP')
# ('from', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# ('gospel', 'O', '', 'PROPN')
# (',', 'O', '', 'PUNCT')
# ('move', 'O', '', 'VERB')
# ('into', 'O', '', 'ADP')
# ('the', 'O', '', 'DET')
# ENTITIES TO VERIFY NON COMBINED
# [('gospel', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('gospel', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# model
# Original Sentence Split
# ['#follow', 'us', '&', '#checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/', 'model', '@user779', 'aka', 'lady', 'boom', 'boom', 'url107']
# Original Start Index
# 15
# FINDING ENTITY OF WORD
# #follow
# ['follow']
# #checkout
# ['checkout']
# model
# ['model']
# FOR NON COMBINED WORDS
# After processing
# ['follow', 'us', '&', 'checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/', 'model', '@user779', 'aka', 'lady', 'boom', 'boom', 'url107']
# After processing joint sentence
# follow us & checkout the multi - talented spanglish / techno / pop singer / model @user779 aka lady boom boom url107
# Pre processed word start index
# 15
# Pre processed char start index
# 76
# Pre processed split string
# follow us & checkout the multi - talented spanglish / techno / pop singer / model @user779 aka lady boom boom url107
# Part of sentence before particular word
# ['follow', 'us', '&', 'checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/']
# Part of sentence before particular word string
# follow us & checkout the multi - talented spanglish / techno / pop singer /
# Part of sentence before particular word string mushed
# followus&checkoutthemulti-talentedspanglish/techno/popsinger/
# FINAL: Pre Processed char start index mushed
# 61
# FOR COMBINED WORDS:
# After processing combined
# ['follow', 'us', '&', 'checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/', 'model', '@user779', 'aka', 'lady', 'boom', 'boom', 'url107']
# After processing joint sentence combined
# follow us & checkout the multi - talented spanglish / techno / pop singer / model @user779 aka lady boom boom url107
# Pre processed word start index combined
# 15
# Pre processed char start index combined
# 76
# Pre processed split string combined
# follow us & checkout the multi - talented spanglish / techno / pop singer / model @user779 aka lady boom boom url107
# Part of sentence before particular word combined
# ['follow', 'us', '&', 'checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/']
# Part of sentence before particular word string combined
# follow us & checkout the multi - talented spanglish / techno / pop singer /
# Part of sentence before particular word string mushed combined
# followus&checkoutthemulti-talentedspanglish/techno/popsinger/
# FINAL: Pre Processed char start index mushed combined
# 61
# Word Entities result
# [('follow', 'O', '', 'VERB'), ('us', 'O', '', 'PRON'), ('&', 'O', '', 'CCONJ'), ('checkout', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('multi', 'O', '', 'ADJ'), ('-', 'O', '', 'PUNCT'), ('talented', 'O', '', 'ADJ'), ('spanglish', 'O', '', 'ADJ'), ('/', 'O', '', 'SYM'), ('techno', 'O', '', 'NOUN'), ('/', 'O', '', 'SYM'), ('pop', 'O', '', 'NOUN'), ('singer', 'O', '', 'NOUN'), ('/', 'O', '', 'SYM'), ('model', 'O', '', 'NOUN'), ('@user779', 'O', '', 'PROPN'), ('aka', 'O', '', 'ADV'), ('lady', 'O', '', 'PROPN'), ('boom', 'O', '', 'PROPN'), ('boom', 'O', '', 'PROPN'), ('url107', 'O', '', 'PROPN')]
# Word Entities COMBINED result
# [('follow', 'O', '', 'VERB'), ('us', 'O', '', 'PRON'), ('&', 'O', '', 'CCONJ'), ('checkout', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('multi', 'O', '', 'ADJ'), ('-', 'O', '', 'PUNCT'), ('talented', 'O', '', 'ADJ'), ('spanglish', 'O', '', 'ADJ'), ('/', 'O', '', 'SYM'), ('techno', 'O', '', 'NOUN'), ('/', 'O', '', 'SYM'), ('pop', 'O', '', 'NOUN'), ('singer', 'O', '', 'NOUN'), ('/', 'O', '', 'SYM'), ('model', 'O', '', 'NOUN'), ('@user779', 'O', '', 'PROPN'), ('aka', 'O', '', 'ADV'), ('lady', 'O', '', 'PROPN'), ('boom', 'O', '', 'PROPN'), ('boom', 'O', '', 'PROPN'), ('url107', 'O', '', 'PROPN')]
# PRINTING NON COMBINED
# ('follow', 'O', '', 'VERB')
# ('us', 'O', '', 'PRON')
# ('&', 'O', '', 'CCONJ')
# ('checkout', 'O', '', 'VERB')
# ('the', 'O', '', 'DET')
# ('multi', 'O', '', 'ADJ')
# ('-', 'O', '', 'PUNCT')
# ('talented', 'O', '', 'ADJ')
# ('spanglish', 'O', '', 'ADJ')
# ('/', 'O', '', 'SYM')
# ('techno', 'O', '', 'NOUN')
# ('/', 'O', '', 'SYM')
# ('pop', 'O', '', 'NOUN')
# ('singer', 'O', '', 'NOUN')
# ('/', 'O', '', 'SYM')
# PRINTING COMBINED
# ('follow', 'O', '', 'VERB')
# ('us', 'O', '', 'PRON')
# ('&', 'O', '', 'CCONJ')
# ('checkout', 'O', '', 'VERB')
# ('the', 'O', '', 'DET')
# ('multi', 'O', '', 'ADJ')
# ('-', 'O', '', 'PUNCT')
# ('talented', 'O', '', 'ADJ')
# ('spanglish', 'O', '', 'ADJ')
# ('/', 'O', '', 'SYM')
# ('techno', 'O', '', 'NOUN')
# ('/', 'O', '', 'SYM')
# ('pop', 'O', '', 'NOUN')
# ('singer', 'O', '', 'NOUN')
# ('/', 'O', '', 'SYM')
# ENTITIES TO VERIFY NON COMBINED
# [('model', 'O', '', 'NOUN')]
# ENTITIES TO VERIFY COMBINED
# [('model', 'O', '', 'NOUN')]
# []
# ['NOUN', 'NOUN']
# --------------------------------------------------
# Original Particular word
# @user779
# Original Sentence Split
# ['#follow', 'us', '&', '#checkout', 'the', 'multi', '-', 'talented', 'spanglish', '/', 'techno', '/', 'pop', 'singer', '/', 'model', '@user779', 'aka', 'lady', 'boom', 'boom', 'url107']
# Original Start Index
# 16
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# #fridaynightlights
# Original Sentence Split
# ['#fridaynightlights', 'viewing', 'party', 'at', 'stick', '&', 'stein', 'in', 'el', 'segundo', '!', 'who', "'s", 'with', 'me', '??']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# fridaynightlights
# ['friday', 'night', 'lights']
# FOR NON COMBINED WORDS
# After processing
# ['friday', 'night', 'lights', 'viewing', 'party', 'at', 'stick', '&', 'stein', 'in', 'el', 'segundo', '!', 'who', "'s", 'with', 'me', '??']
# After processing joint sentence
# friday night lights viewing party at stick & stein in el segundo ! who 's with me ??
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# friday night lights viewing party at stick & stein in el segundo ! who 's with me ??
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# FOR COMBINED WORDS:
# After processing combined
# ['fridaynightlights', 'viewing', 'party', 'at', 'stick', '&', 'stein', 'in', 'el', 'segundo', '!', 'who', "'s", 'with', 'me', '??']
# After processing joint sentence combined
# fridaynightlights viewing party at stick & stein in el segundo ! who 's with me ??
# Pre processed word start index combined
# 0
# Pre processed char start index combined
# 1
# Pre processed split string combined
# fridaynightlights viewing party at stick & stein in el segundo ! who 's with me ??
# Part of sentence before particular word combined
# []
# Part of sentence before particular word string combined
#
# Part of sentence before particular word string mushed combined
#
# FINAL: Pre Processed char start index mushed combined
# 0
# Word Entities result
# [('friday', 'B', 'EVENT', 'PROPN'), ('night', 'I', 'EVENT', 'PROPN'), ('lights', 'I', 'EVENT', 'PROPN'), ('viewing', 'O', '', 'NOUN'), ('party', 'O', '', 'NOUN'), ('at', 'O', '', 'ADP'), ('stick', 'B', 'ORG', 'PROPN'), ('&', 'I', 'ORG', 'CCONJ'), ('stein', 'I', 'ORG', 'PROPN'), ('in', 'O', '', 'ADP'), ('el', 'B', 'GPE', 'PROPN'), ('segundo', 'I', 'GPE', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('who', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('with', 'O', '', 'ADP'), ('me', 'O', '', 'PRON'), ('?', 'O', '', 'PUNCT'), ('?', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('fridaynightlights', 'O', '', 'PROPN'), ('viewing', 'O', '', 'NOUN'), ('party', 'O', '', 'NOUN'), ('at', 'O', '', 'ADP'), ('stick', 'B', 'ORG', 'PROPN'), ('&', 'I', 'ORG', 'CCONJ'), ('stein', 'I', 'ORG', 'PROPN'), ('in', 'O', '', 'ADP'), ('el', 'B', 'GPE', 'PROPN'), ('segundo', 'I', 'GPE', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('who', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('with', 'O', '', 'ADP'), ('me', 'O', '', 'PRON'), ('?', 'O', '', 'PUNCT'), ('?', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# PRINTING COMBINED
# ENTITIES TO VERIFY NON COMBINED
# [('friday', 'B', 'EVENT', 'PROPN'), ('night', 'I', 'EVENT', 'PROPN'), ('lights', 'I', 'EVENT', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('fridaynightlights', 'O', '', 'PROPN')]
# ['EVENT', 'EVENT', 'EVENT']
# ['PROPN', 'PROPN', 'PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# #harrypotter
# Original Sentence Split
# ['#harrypotter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# harrypotter
# ['harry', 'potter']
# FOR NON COMBINED WORDS
# After processing
# ['harry', 'potter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# After processing joint sentence
# harry potter marathon while i write my papers .
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# harry potter marathon while i write my papers .
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# FOR COMBINED WORDS:
# After processing combined
# ['harrypotter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# After processing joint sentence combined
# harrypotter marathon while i write my papers .
# Pre processed word start index combined
# 0
# Pre processed char start index combined
# 1
# Pre processed split string combined
# harrypotter marathon while i write my papers .
# Part of sentence before particular word combined
# []
# Part of sentence before particular word string combined
#
# Part of sentence before particular word string mushed combined
#
# FINAL: Pre Processed char start index mushed combined
# 0
# Word Entities result
# [('harry', 'B', 'PERSON', 'PROPN'), ('potter', 'I', 'PERSON', 'PROPN'), ('marathon', 'I', 'PERSON', 'PROPN'), ('while', 'O', '', 'SCONJ'), ('i', 'O', '', 'PRON'), ('write', 'O', '', 'VERB'), ('my', 'O', '', 'PRON'), ('papers', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('harrypotter', 'B', 'WORK_OF_ART', 'PROPN'), ('marathon', 'I', 'WORK_OF_ART', 'PROPN'), ('while', 'O', '', 'SCONJ'), ('i', 'O', '', 'PRON'), ('write', 'O', '', 'VERB'), ('my', 'O', '', 'PRON'), ('papers', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# PRINTING COMBINED
# ENTITIES TO VERIFY NON COMBINED
# [('harry', 'B', 'PERSON', 'PROPN'), ('potter', 'I', 'PERSON', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('harrypotter', 'B', 'WORK_OF_ART', 'PROPN')]
# ['PERSON', 'PERSON', 'WORK_OF_ART']
# ['PROPN', 'PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# marathon
# Original Sentence Split
# ['#harrypotter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# Original Start Index
# 1
# FINDING ENTITY OF WORD
# #harrypotter
# ['harry', 'potter']
# marathon
# ['marathon']
# FOR NON COMBINED WORDS
# After processing
# ['harry', 'potter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# After processing joint sentence
# harry potter marathon while i write my papers .
# Pre processed word start index
# 2
# Pre processed char start index
# 13
# Pre processed split string
# harry potter marathon while i write my papers .
# Part of sentence before particular word
# ['harry', 'potter']
# Part of sentence before particular word string
# harry potter
# Part of sentence before particular word string mushed
# harrypotter
# FINAL: Pre Processed char start index mushed
# 11
# FOR COMBINED WORDS:
# After processing combined
# ['harry', 'potter', 'marathon', 'while', 'i', 'write', 'my', 'papers', '.']
# After processing joint sentence combined
# harry potter marathon while i write my papers .
# Pre processed word start index combined
# 2
# Pre processed char start index combined
# 13
# Pre processed split string combined
# harry potter marathon while i write my papers .
# Part of sentence before particular word combined
# ['harry', 'potter']
# Part of sentence before particular word string combined
# harry potter
# Part of sentence before particular word string mushed combined
# harrypotter
# FINAL: Pre Processed char start index mushed combined
# 11
# Word Entities result
# [('harry', 'B', 'PERSON', 'PROPN'), ('potter', 'I', 'PERSON', 'PROPN'), ('marathon', 'I', 'PERSON', 'PROPN'), ('while', 'O', '', 'SCONJ'), ('i', 'O', '', 'PRON'), ('write', 'O', '', 'VERB'), ('my', 'O', '', 'PRON'), ('papers', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('harry', 'B', 'PERSON', 'PROPN'), ('potter', 'I', 'PERSON', 'PROPN'), ('marathon', 'I', 'PERSON', 'PROPN'), ('while', 'O', '', 'SCONJ'), ('i', 'O', '', 'PRON'), ('write', 'O', '', 'VERB'), ('my', 'O', '', 'PRON'), ('papers', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# ('harry', 'B', 'PERSON', 'PROPN')
# ('potter', 'I', 'PERSON', 'PROPN')
# PRINTING COMBINED
# ('harry', 'B', 'PERSON', 'PROPN')
# ('potter', 'I', 'PERSON', 'PROPN')
# ENTITIES TO VERIFY NON COMBINED
# [('marathon', 'I', 'PERSON', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('marathon', 'I', 'PERSON', 'PROPN')]
# ['PERSON', 'PERSON']
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# #lebronshould
# Original Sentence Split
# ['#lebronshould', 'know', 'his', 'only', 'championship', 'is', "'", 'slam', 'dunk', "'", '.', '@user2004']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# lebronshould
# ['lebron', 'should']
# FOR NON COMBINED WORDS
# After processing
# ['lebron', 'should', 'know', 'his', 'only', 'championship', 'is', "'", 'slam', 'dunk', "'", '.', '@user2004']
# After processing joint sentence
# lebron should know his only championship is ' slam dunk ' . @user2004
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# lebron should know his only championship is ' slam dunk ' . @user2004
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# FOR COMBINED WORDS:
# After processing combined
# ['lebronshould', 'know', 'his', 'only', 'championship', 'is', "'", 'slam', 'dunk', "'", '.', '@user2004']
# After processing joint sentence combined
# lebronshould know his only championship is ' slam dunk ' . @user2004
# Pre processed word start index combined
# 0
# Pre processed char start index combined
# 1
# Pre processed split string combined
# lebronshould know his only championship is ' slam dunk ' . @user2004
# Part of sentence before particular word combined
# []
# Part of sentence before particular word string combined
#
# Part of sentence before particular word string mushed combined
#
# FINAL: Pre Processed char start index mushed combined
# 0
# Word Entities result
# [('lebron', 'B', 'PERSON', 'PROPN'), ('should', 'O', '', 'AUX'), ('know', 'O', '', 'VERB'), ('his', 'O', '', 'PRON'), ('only', 'O', '', 'ADJ'), ('championship', 'O', '', 'NOUN'), ('is', 'O', '', 'AUX'), ("'", 'O', '', 'PUNCT'), ('slam', 'O', '', 'NOUN'), ('dunk', 'O', '', 'NOUN'), ("'", 'O', '', 'PUNCT'), ('.', 'O', '', 'PUNCT'), ('@user2004', 'O', '', 'X')]
# Word Entities COMBINED result
# [('lebronshould', 'O', '', 'PRON'), ('know', 'O', '', 'VERB'), ('his', 'O', '', 'PRON'), ('only', 'O', '', 'ADJ'), ('championship', 'O', '', 'NOUN'), ('is', 'O', '', 'AUX'), ("'", 'O', '', 'PUNCT'), ('slam', 'O', '', 'NOUN'), ('dunk', 'O', '', 'NOUN'), ("'", 'O', '', 'PUNCT'), ('.', 'O', '', 'PUNCT'), ('@user2004', 'O', '', 'X')]
# PRINTING NON COMBINED
# PRINTING COMBINED
# ENTITIES TO VERIFY NON COMBINED
# [('lebron', 'B', 'PERSON', 'PROPN'), ('should', 'O', '', 'AUX')]
# ENTITIES TO VERIFY COMBINED
# [('lebronshould', 'O', '', 'PRON')]
# ['PERSON']
# ['PROPN', 'AUX', 'PRON']
# --------------------------------------------------
# Original Particular word
# #teamceltics
# Original Sentence Split
# ['#teamceltics', '.', 'lakers', 'we', 'coming', 'for', 'you', '.']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# teamceltics
# ['team', 'celtics']
# FOR NON COMBINED WORDS
# After processing
# ['team', 'celtics', '.', 'lakers', 'we', 'coming', 'for', 'you', '.']
# After processing joint sentence
# team celtics . lakers we coming for you .
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# team celtics . lakers we coming for you .
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# FOR COMBINED WORDS:
# After processing combined
# ['teamceltics', '.', 'lakers', 'we', 'coming', 'for', 'you', '.']
# After processing joint sentence combined
# teamceltics . lakers we coming for you .
# Pre processed word start index combined
# 0
# Pre processed char start index combined
# 1
# Pre processed split string combined
# teamceltics . lakers we coming for you .
# Part of sentence before particular word combined
# []
# Part of sentence before particular word string combined
#
# Part of sentence before particular word string mushed combined
#
# FINAL: Pre Processed char start index mushed combined
# 0
# Word Entities result
# [('team', 'O', '', 'NOUN'), ('celtics', 'O', '', 'PROPN'), ('.', 'O', '', 'PUNCT'), ('lakers', 'O', '', 'PROPN'), ('we', 'O', '', 'PRON'), ('coming', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('you', 'O', '', 'PRON'), ('.', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('teamceltics', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('lakers', 'O', '', 'PROPN'), ('we', 'O', '', 'PRON'), ('coming', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('you', 'O', '', 'PRON'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# PRINTING COMBINED
# ENTITIES TO VERIFY NON COMBINED
# [('team', 'O', '', 'NOUN'), ('celtics', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('teamceltics', 'O', '', 'NOUN')]
# []
# ['NOUN', 'PROPN', 'NOUN']
# --------------------------------------------------
# Original Particular word
# #jordanheels
# Original Sentence Split
# ['#jordanheels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# jordanheels
# ['jordan', 'heels']
# FOR NON COMBINED WORDS
# After processing
# ['jordan', 'heels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# After processing joint sentence
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# FOR COMBINED WORDS:
# After processing combined
# ['jordanheels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# After processing joint sentence combined
# jordanheels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Pre processed word start index combined
# 0
# Pre processed char start index combined
# 1
# Pre processed split string combined
# jordanheels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Part of sentence before particular word combined
# []
# Part of sentence before particular word string combined
#
# Part of sentence before particular word string mushed combined
#
# FINAL: Pre Processed char start index mushed combined
# 0
# Word Entities result
# [('jordan', 'O', '', 'PROPN'), ('heels', 'O', '', 'NOUN'), ('are', 'O', '', 'AUX'), ('very', 'O', '', 'ADV'), ('useful', 'O', '', 'ADJ'), ('in', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('fight', 'O', '', 'NOUN'), ('cause', 'O', '', 'SCONJ'), ('a', 'O', '', 'DET'), ('hoodrat', 'O', '', 'NOUN'), ('will', 'O', '', 'AUX'), ('put', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('jordan', 'O', '', 'PROPN'), ('stamp', 'O', '', 'NOUN'), ('n', 'O', '', 'X'), ('hole', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('ur', 'O', '', 'PRON'), ('dome', 'O', '', 'NOUN'), ('lls', 'O', '', 'NOUN')]
# Word Entities COMBINED result
# [('jordanheels', 'O', '', 'PROPN'), ('are', 'O', '', 'AUX'), ('very', 'O', '', 'ADV'), ('useful', 'O', '', 'ADJ'), ('in', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('fight', 'O', '', 'NOUN'), ('cause', 'O', '', 'SCONJ'), ('a', 'O', '', 'DET'), ('hoodrat', 'O', '', 'NOUN'), ('will', 'O', '', 'AUX'), ('put', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('jordan', 'O', '', 'PROPN'), ('stamp', 'O', '', 'NOUN'), ('n', 'O', '', 'X'), ('hole', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('ur', 'O', '', 'PRON'), ('dome', 'O', '', 'NOUN'), ('lls', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# PRINTING COMBINED
# ENTITIES TO VERIFY NON COMBINED
# [('jordan', 'O', '', 'PROPN'), ('heels', 'O', '', 'NOUN')]
# ENTITIES TO VERIFY COMBINED
# [('jordanheels', 'O', '', 'PROPN')]
# []
# ['PROPN', 'NOUN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# jordan
# Original Sentence Split
# ['#jordanheels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# Original Start Index
# 13
# FINDING ENTITY OF WORD
# #jordanheels
# ['jordan', 'heels']
# jordan
# ['jordan']
# FOR NON COMBINED WORDS
# After processing
# ['jordan', 'heels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# After processing joint sentence
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Pre processed word start index
# 14
# Pre processed char start index
# 67
# Pre processed split string
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Part of sentence before particular word
# ['jordan', 'heels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a']
# Part of sentence before particular word string
# jordan heels are very useful in a fight cause a hoodrat will put a
# Part of sentence before particular word string mushed
# jordanheelsareveryusefulinafightcauseahoodratwillputa
# FINAL: Pre Processed char start index mushed
# 53
# FOR COMBINED WORDS:
# After processing combined
# ['jordan', 'heels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a', 'jordan', 'stamp', 'n', 'hole', 'in', 'ur', 'dome', 'lls']
# After processing joint sentence combined
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Pre processed word start index combined
# 14
# Pre processed char start index combined
# 67
# Pre processed split string combined
# jordan heels are very useful in a fight cause a hoodrat will put a jordan stamp n hole in ur dome lls
# Part of sentence before particular word combined
# ['jordan', 'heels', 'are', 'very', 'useful', 'in', 'a', 'fight', 'cause', 'a', 'hoodrat', 'will', 'put', 'a']
# Part of sentence before particular word string combined
# jordan heels are very useful in a fight cause a hoodrat will put a
# Part of sentence before particular word string mushed combined
# jordanheelsareveryusefulinafightcauseahoodratwillputa
# FINAL: Pre Processed char start index mushed combined
# 53
# Word Entities result
# [('jordan', 'O', '', 'PROPN'), ('heels', 'O', '', 'NOUN'), ('are', 'O', '', 'AUX'), ('very', 'O', '', 'ADV'), ('useful', 'O', '', 'ADJ'), ('in', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('fight', 'O', '', 'NOUN'), ('cause', 'O', '', 'SCONJ'), ('a', 'O', '', 'DET'), ('hoodrat', 'O', '', 'NOUN'), ('will', 'O', '', 'AUX'), ('put', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('jordan', 'O', '', 'PROPN'), ('stamp', 'O', '', 'NOUN'), ('n', 'O', '', 'X'), ('hole', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('ur', 'O', '', 'PRON'), ('dome', 'O', '', 'NOUN'), ('lls', 'O', '', 'NOUN')]
# Word Entities COMBINED result
# [('jordan', 'O', '', 'PROPN'), ('heels', 'O', '', 'NOUN'), ('are', 'O', '', 'AUX'), ('very', 'O', '', 'ADV'), ('useful', 'O', '', 'ADJ'), ('in', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('fight', 'O', '', 'NOUN'), ('cause', 'O', '', 'SCONJ'), ('a', 'O', '', 'DET'), ('hoodrat', 'O', '', 'NOUN'), ('will', 'O', '', 'AUX'), ('put', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('jordan', 'O', '', 'PROPN'), ('stamp', 'O', '', 'NOUN'), ('n', 'O', '', 'X'), ('hole', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('ur', 'O', '', 'PRON'), ('dome', 'O', '', 'NOUN'), ('lls', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# ('jordan', 'O', '', 'PROPN')
# ('heels', 'O', '', 'NOUN')
# ('are', 'O', '', 'AUX')
# ('very', 'O', '', 'ADV')
# ('useful', 'O', '', 'ADJ')
# ('in', 'O', '', 'ADP')
# ('a', 'O', '', 'DET')
# ('fight', 'O', '', 'NOUN')
# ('cause', 'O', '', 'SCONJ')
# ('a', 'O', '', 'DET')
# ('hoodrat', 'O', '', 'NOUN')
# ('will', 'O', '', 'AUX')
# ('put', 'O', '', 'VERB')
# ('a', 'O', '', 'DET')
# PRINTING COMBINED
# ('jordan', 'O', '', 'PROPN')
# ('heels', 'O', '', 'NOUN')
# ('are', 'O', '', 'AUX')
# ('very', 'O', '', 'ADV')
# ('useful', 'O', '', 'ADJ')
# ('in', 'O', '', 'ADP')
# ('a', 'O', '', 'DET')
# ('fight', 'O', '', 'NOUN')
# ('cause', 'O', '', 'SCONJ')
# ('a', 'O', '', 'DET')
# ('hoodrat', 'O', '', 'NOUN')
# ('will', 'O', '', 'AUX')
# ('put', 'O', '', 'VERB')
# ('a', 'O', '', 'DET')
# ENTITIES TO VERIFY NON COMBINED
# [('jordan', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('jordan', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# dj
# Original Sentence Split
# ['#np', 'dj', 'got', 'us', '-', 'falling', 'in', 'love', 'ag', '-', 'u$her', 'ft.', 'pitbull']
# Original Start Index
# 1
# FINDING ENTITY OF WORD
# #np
# ['np']
# dj
# ['dj']
# FOR NON COMBINED WORDS
# After processing
# ['np', 'dj', 'got', 'us', '-', 'falling', 'in', 'love', 'ag', '-', 'u$her', 'ft.', 'pitbull']
# After processing joint sentence
# np dj got us - falling in love ag - u$her ft. pitbull
# Pre processed word start index
# 1
# Pre processed char start index
# 3
# Pre processed split string
# np dj got us - falling in love ag - u$her ft. pitbull
# Part of sentence before particular word
# ['np']
# Part of sentence before particular word string
# np
# Part of sentence before particular word string mushed
# np
# FINAL: Pre Processed char start index mushed
# 2
# FOR COMBINED WORDS:
# After processing combined
# ['np', 'dj', 'got', 'us', '-', 'falling', 'in', 'love', 'ag', '-', 'u$her', 'ft.', 'pitbull']
# After processing joint sentence combined
# np dj got us - falling in love ag - u$her ft. pitbull
# Pre processed word start index combined
# 1
# Pre processed char start index combined
# 3
# Pre processed split string combined
# np dj got us - falling in love ag - u$her ft. pitbull
# Part of sentence before particular word combined
# ['np']
# Part of sentence before particular word string combined
# np
# Part of sentence before particular word string mushed combined
# np
# FINAL: Pre Processed char start index mushed combined
# 2
# Word Entities result
# [('np', 'O', '', 'PROPN'), ('dj', 'O', '', 'PROPN'), ('got', 'O', '', 'VERB'), ('us', 'O', '', 'PRON'), ('-', 'O', '', 'PUNCT'), ('falling', 'O', '', 'VERB'), ('in', 'O', '', 'ADP'), ('love', 'O', '', 'NOUN'), ('ag', 'O', '', 'ADP'), ('-', 'O', '', 'PUNCT'), ('u$her', 'O', '', 'PROPN'), ('ft', 'O', '', 'VERB'), ('.', 'O', '', 'X'), ('pitbull', 'B', 'PERSON', 'PROPN')]
# Word Entities COMBINED result
# [('np', 'O', '', 'PROPN'), ('dj', 'O', '', 'PROPN'), ('got', 'O', '', 'VERB'), ('us', 'O', '', 'PRON'), ('-', 'O', '', 'PUNCT'), ('falling', 'O', '', 'VERB'), ('in', 'O', '', 'ADP'), ('love', 'O', '', 'NOUN'), ('ag', 'O', '', 'ADP'), ('-', 'O', '', 'PUNCT'), ('u$her', 'O', '', 'PROPN'), ('ft', 'O', '', 'VERB'), ('.', 'O', '', 'X'), ('pitbull', 'B', 'PERSON', 'PROPN')]
# PRINTING NON COMBINED
# ('np', 'O', '', 'PROPN')
# PRINTING COMBINED
# ('np', 'O', '', 'PROPN')
# ENTITIES TO VERIFY NON COMBINED
# [('dj', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('dj', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# @user676
# Original Sentence Split
# ['#teamnevertoobusytotweet', 'we', 'are', 'on', 'it', '!!!', '@user676', 'url196']
# Original Start Index
# 6
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# d
# Original Sentence Split
# ['3-0', '!!', 'phew', '!!!', 'good', 'no', 'td', '!!!', 'go', 'job', 'd', '!!!', '#birdgang']
# Original Start Index
# 10
# FINDING ENTITY OF WORD
# d
# ['d']
# #birdgang
# ['bird', 'gang']
# FOR NON COMBINED WORDS
# After processing
# ['3-0', '!!', 'phew', '!!!', 'good', 'no', 'td', '!!!', 'go', 'job', 'd', '!!!', 'bird', 'gang']
# After processing joint sentence
# 3-0 !! phew !!! good no td !!! go job d !!! bird gang
# Pre processed word start index
# 10
# Pre processed char start index
# 38
# Pre processed split string
# 3-0 !! phew !!! good no td !!! go job d !!! bird gang
# Part of sentence before particular word
# ['3-0', '!!', 'phew', '!!!', 'good', 'no', 'td', '!!!', 'go', 'job']
# Part of sentence before particular word string
# 3-0 !! phew !!! good no td !!! go job
# Part of sentence before particular word string mushed
# 3-0!!phew!!!goodnotd!!!gojob
# FINAL: Pre Processed char start index mushed
# 28
# FOR COMBINED WORDS:
# After processing combined
# ['3-0', '!!', 'phew', '!!!', 'good', 'no', 'td', '!!!', 'go', 'job', 'd', '!!!', 'bird', 'gang']
# After processing joint sentence combined
# 3-0 !! phew !!! good no td !!! go job d !!! bird gang
# Pre processed word start index combined
# 10
# Pre processed char start index combined
# 38
# Pre processed split string combined
# 3-0 !! phew !!! good no td !!! go job d !!! bird gang
# Part of sentence before particular word combined
# ['3-0', '!!', 'phew', '!!!', 'good', 'no', 'td', '!!!', 'go', 'job']
# Part of sentence before particular word string combined
# 3-0 !! phew !!! good no td !!! go job
# Part of sentence before particular word string mushed combined
# 3-0!!phew!!!goodnotd!!!gojob
# FINAL: Pre Processed char start index mushed combined
# 28
# Word Entities result
# [('3', 'O', '', 'NUM'), ('-', 'O', '', 'X'), ('0', 'O', '', 'NUM'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('phew', 'O', '', 'INTJ'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('good', 'O', '', 'ADJ'), ('no', 'O', '', 'DET'), ('td', 'O', '', 'NOUN'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('go', 'O', '', 'VERB'), ('job', 'O', '', 'NOUN'), ('d', 'O', '', 'NOUN'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('bird', 'O', '', 'PROPN'), ('gang', 'O', '', 'PROPN')]
# Word Entities COMBINED result
# ...
# After processing joint sentence combined
# rt @user619 : iran - syria : no2rouhani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Pre processed word start index combined
# 7
# Pre processed char start index combined
# 29
# Pre processed split string combined
# rt @user619 : iran - syria : no2rouhani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Part of sentence before particular word combined
# ['rt', '@user619', ':', 'iran', '-', 'syria', ':']
# Part of sentence before particular word string combined
# rt @user619 : iran - syria :
# Part of sentence before particular word string mushed combined
# rt@user619:iran-syria:
# FINAL: Pre Processed char start index mushed combined
# 22
# Word Entities result
# [('rt', 'O', '', 'X'), ('@user619', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('iran', 'O', '', 'PROPN'), ('-', 'O', '', 'PUNCT'), ('syria', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('no', 'O', '', 'PRON'), ('2', 'O', '', 'NUM'), ('rou', 'O', '', 'PROPN'), ('hani', 'O', '', 'PROPN'), ('rally', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('austria', 'O', '', 'PROPN'), ('url289', 'O', '', 'X'), ('@user2011', 'O', '', 'X'), ('@user18', 'O', '', 'X'), ('@user1276', 'O', '', 'X'), ('url219', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'PROPN'), ('@user619', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('iran', 'O', '', 'PROPN'), ('-', 'O', '', 'PUNCT'), ('syria', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('no2rouhani', 'O', '', 'PROPN'), ('rally', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('austria', 'O', '', 'PROPN'), ('url289', 'O', '', 'X'), ('@user2011', 'O', '', 'X'), ('@user18', 'O', '', 'X'), ('@user1276', 'O', '', 'X'), ('url219', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'X')
# ('@user619', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('iran', 'O', '', 'PROPN')
# ('-', 'O', '', 'PUNCT')
# ('syria', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# PRINTING COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user619', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('iran', 'O', '', 'PROPN')
# ('-', 'O', '', 'PUNCT')
# ('syria', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# ENTITIES TO VERIFY NON COMBINED
# [('no', 'O', '', 'PRON'), ('2', 'O', '', 'NUM'), ('rou', 'O', '', 'PROPN'), ('hani', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('no2rouhani', 'O', '', 'PROPN')]
# []
# ['PRON', 'NUM', 'PROPN', 'PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# #austria
# Original Sentence Split
# ['rt', '@user619', ':', '#iran', '-', '#syria', ':', '#no2rouhani', 'rally', 'in', '#austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# Original Start Index
# 10
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# iran
# ['iran']
# syria
# ['syria']
# no2rouhani
# ['no', '2', 'rou', 'hani']
# austria
# ['austria']
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user619', ':', 'iran', '-', 'syria', ':', 'no', '2', 'rou', 'hani', 'rally', 'in', 'austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# After processing joint sentence
# rt @user619 : iran - syria : no 2 rou hani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Pre processed word start index
# 13
# Pre processed char start index
# 52
# Pre processed split string
# rt @user619 : iran - syria : no 2 rou hani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Part of sentence before particular word
# ['rt', '@user619', ':', 'iran', '-', 'syria', ':', 'no', '2', 'rou', 'hani', 'rally', 'in']
# Part of sentence before particular word string
# rt @user619 : iran - syria : no 2 rou hani rally in
# Part of sentence before particular word string mushed
# rt@user619:iran-syria:no2rouhanirallyin
# FINAL: Pre Processed char start index mushed
# 39
# FOR COMBINED WORDS:
# After processing combined
# ['rt', '@user619', ':', 'iran', '-', 'syria', ':', 'no', '2', 'rou', 'hani', 'rally', 'in', 'austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# After processing joint sentence combined
# rt @user619 : iran - syria : no 2 rou hani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Pre processed word start index combined
# 13
# Pre processed char start index combined
# 52
# Pre processed split string combined
# rt @user619 : iran - syria : no 2 rou hani rally in austria url289 @user2011 @user18 @user1276 url219 …
# Part of sentence before particular word combined
# ['rt', '@user619', ':', 'iran', '-', 'syria', ':', 'no', '2', 'rou', 'hani', 'rally', 'in']
# Part of sentence before particular word string combined
# rt @user619 : iran - syria : no 2 rou hani rally in
# Part of sentence before particular word string mushed combined
# rt@user619:iran-syria:no2rouhanirallyin
# FINAL: Pre Processed char start index mushed combined
# 39
# Word Entities result
# [('rt', 'O', '', 'X'), ('@user619', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('iran', 'O', '', 'PROPN'), ('-', 'O', '', 'PUNCT'), ('syria', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('no', 'O', '', 'PRON'), ('2', 'O', '', 'NUM'), ('rou', 'O', '', 'PROPN'), ('hani', 'O', '', 'PROPN'), ('rally', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('austria', 'O', '', 'PROPN'), ('url289', 'O', '', 'X'), ('@user2011', 'O', '', 'X'), ('@user18', 'O', '', 'X'), ('@user1276', 'O', '', 'X'), ('url219', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'X'), ('@user619', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('iran', 'O', '', 'PROPN'), ('-', 'O', '', 'PUNCT'), ('syria', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('no', 'O', '', 'PRON'), ('2', 'O', '', 'NUM'), ('rou', 'O', '', 'PROPN'), ('hani', 'O', '', 'PROPN'), ('rally', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('austria', 'O', '', 'PROPN'), ('url289', 'O', '', 'X'), ('@user2011', 'O', '', 'X'), ('@user18', 'O', '', 'X'), ('@user1276', 'O', '', 'X'), ('url219', 'O', '', 'X'), ('…', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'X')
# ('@user619', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('iran', 'O', '', 'PROPN')
# ('-', 'O', '', 'PUNCT')
# ('syria', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# ('no', 'O', '', 'PRON')
# ('2', 'O', '', 'NUM')
# ('rou', 'O', '', 'PROPN')
# ('hani', 'O', '', 'PROPN')
# ('rally', 'O', '', 'NOUN')
# ('in', 'O', '', 'ADP')
# PRINTING COMBINED
# ('rt', 'O', '', 'X')
# ('@user619', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('iran', 'O', '', 'PROPN')
# ('-', 'O', '', 'PUNCT')
# ('syria', 'O', '', 'PROPN')
# (':', 'O', '', 'PUNCT')
# ('no', 'O', '', 'PRON')
# ('2', 'O', '', 'NUM')
# ('rou', 'O', '', 'PROPN')
# ('hani', 'O', '', 'PROPN')
# ('rally', 'O', '', 'NOUN')
# ('in', 'O', '', 'ADP')
# ENTITIES TO VERIFY NON COMBINED
# [('austria', 'O', '', 'PROPN')]
# ENTITIES TO VERIFY COMBINED
# [('austria', 'O', '', 'PROPN')]
# []
# ['PROPN', 'PROPN']
# --------------------------------------------------
# Original Particular word
# @user2011
# Original Sentence Split
# ['rt', '@user619', ':', '#iran', '-', '#syria', ':', '#no2rouhani', 'rally', 'in', '#austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# Original Start Index
# 12
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user18
# Original Sentence Split
# ['rt', '@user619', ':', '#iran', '-', '#syria', ':', '#no2rouhani', 'rally', 'in', '#austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# Original Start Index
# 13
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user1276
# Original Sentence Split
# ['rt', '@user619', ':', '#iran', '-', '#syria', ':', '#no2rouhani', 'rally', 'in', '#austria', 'url289', '@user2011', '@user18', '@user1276', 'url219', '…']
# Original Start Index
# 14
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# #iceland
# Original Sentence Split
# ['rt', '@user604', ':', '11', 'ways', '#iceland', 'is', '"', 'cool', '"', '😎', 'url1312', 'url549']
# Original Start Index
# 5
# FINDING ENTITY OF WORD
# ENTITY IS HASHTAG, WILL RUN FOR COMBINED HASHTAG AS WELL
# iceland
# ['iceland']
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user604', ':', '11', 'ways', 'iceland', 'is', '"', 'cool', '"', '😎', 'url1312', 'url549']
# After processing joint sentence
# rt @user604 : 11 ways iceland is " cool " 😎 url1312 url549
# Pre processed word start index
# 5
# Pre processed char start index
# 22
# Pre processed split string
# rt @user604 : 11 ways iceland is " cool " 😎 url1312 url549
# Part of sentence before particular word
# ['rt', '@user604', ':', '11', 'ways']
# Part of sentence before particular word string
# rt @user604 : 11 ways
# Part of sentence before particular word string mushed
# rt@user604:11ways
# FINAL: Pre Processed char start index mushed
# 17
# FOR COMBINED WORDS:
# After processing combined
# ['rt', '@user604', ':', '11', 'ways', 'iceland', 'is', '"', 'cool', '"', '😎', 'url1312', 'url549']
# After processing joint sentence combined
# rt @user604 : 11 ways iceland is " cool " 😎 url1312 url549
# Pre processed word start index combined
# 5
# Pre processed char start index combined
# 22
# Pre processed split string combined
# rt @user604 : 11 ways iceland is " cool " 😎 url1312 url549
# Part of sentence before particular word combined
# ['rt', '@user604', ':', '11', 'ways']
# Part of sentence before particular word string combined
# rt @user604 : 11 ways
# Part of sentence before particular word string mushed combined
# rt@user604:11ways
# FINAL: Pre Processed char start index mushed combined
# 17
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user604', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('11', 'O', '', 'NUM'), ('ways', 'O', '', 'NOUN'), ('iceland', 'O', '', 'NOUN'), ('is', 'O', '', 'AUX'), ('"', 'O', '', 'PUNCT'), ('cool', 'O', '', 'ADJ'), ('"', 'O', '', 'PUNCT'), ('😎', 'O', '', 'PUNCT'), ('url1312', 'O', '', 'X'), ('url549', 'O', '', 'X')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'PROPN'), ('@user604', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('11', 'O', '', 'NUM'), ('ways', 'O', '', 'NOUN'), ('iceland', 'O', '', 'NOUN'), ('is', 'O', '', 'AUX'), ('"', 'O', '', 'PUNCT'), ('cool', 'O', '', 'ADJ'), ('"', 'O', '', 'PUNCT'), ('😎', 'O', '', 'PUNCT'), ('url1312', 'O', '', 'X'), ('url549', 'O', '', 'X')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user604', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('11', 'O', '', 'NUM')
# ('ways', 'O', '', 'NOUN')
# PRINTING COMBINED
# ('rt', 'O', '', 'PROPN')
# ('@user604', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('11', 'O', '', 'NUM')
# ('ways', 'O', '', 'NOUN')
# ENTITIES TO VERIFY NON COMBINED
# [('iceland', 'O', '', 'NOUN')]
# ENTITIES TO VERIFY COMBINED
# [('iceland', 'O', '', 'NOUN')]
# []
# ['NOUN', 'NOUN']
# --------------------------------------------------
# Original Particular word
# @user323
# Original Sentence Split
# ['@user323', 'it', "'s", 'okay', 'and', 'i', 'love', 'it', '.', '😍']
# Original Start Index
# 0
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# r&b
# Original Sentence Split
# ['rt', '@user428', ':', 'real', 'r&b', 'url143']
# Original Start Index
# 4
# FINDING ENTITY OF WORD
# r&b
# ['r', 'b']
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user428', ':', 'real', 'r', 'b', 'url143']
# After processing joint sentence
# rt @user428 : real r b url143
# Pre processed word start index
# 4
# Pre processed char start index
# 19
# Pre processed split string
# rt @user428 : real r b url143
# Part of sentence before particular word
# ['rt', '@user428', ':', 'real']
# Part of sentence before particular word string
# rt @user428 : real
# Part of sentence before particular word string mushed
# rt@user428:real
# FINAL: Pre Processed char start index mushed
# 15
# FOR COMBINED WORDS:
# After processing combined
# ['rt', '@user428', ':', 'real', 'r&b', 'url143']
# After processing joint sentence combined
# rt @user428 : real r&b url143
# Pre processed word start index combined
# 4
# Pre processed char start index combined
# 19
# Pre processed split string combined
# rt @user428 : real r&b url143
# Part of sentence before particular word combined
# ['rt', '@user428', ':', 'real']
# Part of sentence before particular word string combined
# rt @user428 : real
# Part of sentence before particular word string mushed combined
# rt@user428:real
# FINAL: Pre Processed char start index mushed combined
# 15
# Word Entities result
# [('rt', 'O', '', 'NOUN'), ('@user428', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('real', 'O', '', 'ADJ'), ('r', 'O', '', 'NOUN'), ('b', 'O', '', 'NOUN'), ('url143', 'O', '', 'NOUN')]
# Word Entities COMBINED result
# [('rt', 'O', '', 'X'), ('@user428', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('real', 'O', '', 'ADJ'), ('r&b', 'O', '', 'NOUN'), ('url143', 'O', '', 'X')]
# PRINTING NON COMBINED
# ('rt', 'O', '', 'NOUN')
# ('@user428', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('real', 'O', '', 'ADJ')
# PRINTING COMBINED
# ('rt', 'O', '', 'X')
# ('@user428', 'O', '', 'X')
# (':', 'O', '', 'PUNCT')
# ('real', 'O', '', 'ADJ')
# ENTITIES TO VERIFY NON COMBINED
# [('r', 'O', '', 'NOUN'), ('b', 'O', '', 'NOUN'), ('url143', 'O', '', 'NOUN')]
# ENTITIES TO VERIFY COMBINED
# [('r&b', 'O', '', 'NOUN')]
# []
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# --------------------------------------------------
# Original Particular word
# @user1523
# Original Sentence Split
# ['happy', 'birthday', 'bae', '@user1523', '😘']
# Original Start Index
# 3
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user925
# Original Sentence Split
# ['@user925', 'that', 'is', 'worrying', '.', 'can', 'you', 'try', 'another', 'atm', 'as', 'others', 'are', 'working', '.', 'please', 'accept', 'my', 'apologies', 'for', 'the', 'inconvenience', 'caused', '.']
# Original Start Index
# 0
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user1791
# Original Sentence Split
# ['rt', '@user2237', ':', '#wfas2016', '@user1791', 'is', 'kicking', 'off', 'the', 'workshop', ',', 'starting', 'your', 'first', '100', 'days', '#hranalytics', 'url1447']
# Original Start Index
# 4
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user70
# Original Sentence Split
# ['rt', '@user2041', ':', '@user70', 'happy', 'birthday', 'man', '!', 'let', "'s", 'hit', 'up', 'the', 'gym', 'sometime']
# Original Start Index
# 3
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user660
# Original Sentence Split
# ['rt', '@user1157', ':', 'happy', 'birthday', '@user660', '!', 'url1209']
# Original Start Index
# 5
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user2046
# Original Sentence Split
# ['@user2046', 'further', 'you', 'do', 'the', 'swedish', 'social', 'security', 'reform', 'of', '1990', ':', 'semi-fully', 'funded', '(', 'automatic', 'balancer', ')', ',', 'semi-privatized', '@user2242']
# Original Start Index
# 0
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user2242
# Original Sentence Split
# ['@user2046', 'further', 'you', 'do', 'the', 'swedish', 'social', 'security', 'reform', 'of', '1990', ':', 'semi-fully', 'funded', '(', 'automatic', 'balancer', ')', ',', 'semi-privatized', '@user2242']
# Original Start Index
# 20
# CHANGE USER ONLY
# --------------------------------------------------
# --------------------------------------------------
# Original Particular word
# @user317
# Original Sentence Split
# ['@user317', 'we', 'sure', 'did', '.', 'came', 'out', ',', 'and', 'said', 'it', 'was', "n't", 'bad', 'enough', ',', 'despite', 'the', 'fact', 'we', 'saw', 'sparking', '.', 'wish', 'i', 'was', 'in', 'a', '#groundtosky', 'zone', '.']
# Original Start Index
# 0
# CHANGE USER ONLY
# --------------------------------------------------

# %%
new_df = combined_df
new_df['Spacy POS Label'] = new_pos
new_df['Spacy NER Label'] = new_label

new_df = new_df.reindex(columns = ['Word', 'POS Label', 'NER Label', 'Spacy POS Label', 'Spacy NER Label', 'Tweet'])
new_df
# Out:
#            Word POS Label NER Label  Spacy POS Label Spacy NER Label  \
# 0       poutine     PROPN         O             NOUN          B-MISC
# 1        friday     PROPN         O            PROPN          B-MISC
# 2      @user444     PROPN         O  User: No change           B-PER
# 3     @user1598     PROPN         O  User: No change           B-PER
# 4        gospel     PROPN         O            PROPN          B-MISC
# ...         ...       ...       ...              ...             ...
# 1013    @user70     PROPN         O  User: No change           B-PER
# 1014   @user660     PROPN         O  User: No change           B-PER
# 1015  @user2046     PROPN         O  User: No change           B-PER
# 1016  @user2242     PROPN         O  User: No change           B-PER
# 1017   @user317     PROPN         O  User: No change           B-PER
#
#                                                   Tweet
# 0     rt @user1787 : i asked siri to remind me about...
# 1     rt @user912 : you know it 's friday when the p...
# 2     mikel obi & his girl olga diyachenko spend hol...
# 3     " @user1598 : super junior ’s siwon transforms...
# 4     " do n't move on from the gospel , move into t...
# ...                                                 ...
# 1013  rt @user2041 : @user70 happy birthday man ! le...
# 1014   rt @user1157 : happy birthday @user660 ! url1209
# 1015  @user2046 further you do the swedish social se...
# 1016  @user2046 further you do the swedish social se...
# 1017  @user317 we sure did . came out , and said it ...
#
# [1018 rows x 6 columns]

# %%
new_df.to_csv('logs/relabelled_data_spacy_pass_entire_sentence.tsv', sep='\t', index=False)
