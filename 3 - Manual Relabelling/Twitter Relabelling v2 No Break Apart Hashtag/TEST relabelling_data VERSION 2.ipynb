# %% [markdown]
# Leung Wai Liu <br>
# JPMorgan AI Research<br>
# August 8, 2022 <br>
# Twitter Relabelling TESTING - VERSION 2

# %%
import pandas as pd
import numpy as np
import wordninja
import spacy
from collections import Counter
from labels_to_tweebank import labels_to_tweebank

# %%
nlp = spacy.load('en_core_web_trf')

# %%
nlp.get_pipe("ner").labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
combined_df = pd.read_csv('logs/combined_test_labels_FINAL.tsv', sep='\t')
combined_df
# Out:
#           Word  Start Word Index  End Word Index  POS Label NER Label  \
# 0     @user415                11              11  ['PROPN']     ['O']
# 1    @user1136                11              11  ['PROPN']     ['O']
# 2          xb1                13              13  ['PROPN']     ['O']
# 3    @user1071                15              15  ['PROPN']     ['O']
# 4     @user718                18              18  ['PROPN']     ['O']
# ..         ...               ...             ...        ...       ...
# 702    ireland                 5               5  ['PROPN']     ['O']
# 703  @user1311                 0               0  ['PROPN']     ['O']
# 704  @user1132                 0               0  ['PROPN']     ['O']
# 705          t                 9               9  ['PROPN']     ['O']
# 706  @user1812                 0               0  ['PROPN']     ['O']
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 2    i 've entered for a chance to win a copy of @u...
# 3    i 've entered for a chance to win a copy of @u...
# 4    i 've entered for a chance to win a copy of @u...
# ..                                                 ...
# 702  rt @user1391 : now northern ireland and polish...
# 703  @user1311 if i had one of these i would go bac...
# 704  @user1132 gon na have to buy a rico riders t s...
# 705  @user1132 gon na have to buy a rico riders t s...
# 706  @user1812 no , i 'm not . it 's definitely not...
#
#                                       Tweet POS Labels  \
# 0    ['ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'NOUN'...
# 1    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 2    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 3    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# 4    ['PRON', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', ...
# ..                                                 ...
# 702  ['X', 'X', 'PUNCT', 'ADV', 'ADJ', 'PROPN', 'CC...
# 703  ['PROPN', 'SCONJ', 'PRON', 'VERB', 'NUM', 'ADP...
# 704  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
# 705  ['PROPN', 'VERB', 'PART', 'VERB', 'PART', 'VER...
# 706  ['PROPN', 'INTJ', 'PUNCT', 'PRON', 'AUX', 'PAR...
#
#                                       Tweet NER Labels
# 0    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 1    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ..                                                 ...
# 702  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', ...
# 703  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 704  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
# 705  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', '...
# 706  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
# [707 rows x 8 columns]

# %%
new_label = combined_df['NER Label'].tolist()
new_label_before_convert = list(new_label)
new_pos = combined_df['POS Label'].tolist()
new_pos_before_convert = list(new_pos)
new_stand_out_tweet = combined_df['Tweet'].tolist()

for index, row in combined_df.iterrows():
    
    # retrieving the the information of a particular row
    particular_word = row['Word']
    particular_start_index = row['Start Word Index']
    particular_end_index = row['End Word Index'] + 1
    num_words_particular = particular_end_index - particular_start_index
    original_sentence = row['Tweet']

    # splitting the original sentence
    original_sentence_split = original_sentence.split(' ')

    # putting the brackets in the original sentence to signify word phrase:
    word_phrase_stand_out = list(original_sentence_split)
    word_phrase_stand_out[particular_start_index] = "<[" + word_phrase_stand_out[particular_start_index]
    word_phrase_stand_out[particular_end_index - 1] = word_phrase_stand_out[particular_end_index - 1] + "]>"
    word_phrase_stand_out_string = ' '.join(word_phrase_stand_out)
    new_stand_out_tweet[index] = word_phrase_stand_out_string
    
    
    print('-' * 50)
    print('Original Particular word')
    print(particular_word)
    print("Original Sentence Split")     
    print(original_sentence_split)
    print("Original Start Index")
    print(particular_start_index)

    # setting up the initial parameters  
    char_index = 0
    iterate_word_index = 0
    is_hashtag = False
    is_user = False
    encode = ''
    encode_len = 0

    print("FINDING ENTITY OF WORD")

    pre_processed_sentence_split = list(original_sentence_split)
    pre_processed_word_start_index = particular_start_index
    pre_processed_word_end_index = particular_end_index
    pre_processed_char_start_index = 0
    pre_processed_char_start_index_mushed = 0
    pre_processed_sentence_split_string = ""

    # NO SPLITTING, FEEDING @USER TAG IN IT

    word_index = 0 
    while word_index in range(len(pre_processed_sentence_split)):
        word_in_sentence = pre_processed_sentence_split[word_index]
        check_for_hashtag = word_in_sentence[0:1]

        # if hashtag, remove the hashtag
        if check_for_hashtag == '#':
            word_in_sentence = word_in_sentence[1:]
            pre_processed_sentence_split[word_index] = word_in_sentence
        
        to_add_word_string_length = len(word_in_sentence)

        word_index += 1
    
    

    pre_processed_sentence_split_string = ' '.join(pre_processed_sentence_split)

    # Getting the specific character of the post pre-processed sentence
    part_of_sentence_before_particular_word = pre_processed_sentence_split[:pre_processed_word_start_index]
    part_of_sentence_before_particular_word_string = ' '.join(part_of_sentence_before_particular_word)

    pre_processed_char_start_index = (len(part_of_sentence_before_particular_word_string)) + 1

    # Without getting the string without spaces
    part_of_sentence_before_particular_word_string_mushed = ''.join(part_of_sentence_before_particular_word)
    pre_processed_char_start_index_mushed = (len(part_of_sentence_before_particular_word_string_mushed))

    # processing particular word phrase after pre-processing
    particular_word_after_processing = pre_processed_sentence_split[pre_processed_word_start_index: pre_processed_word_end_index]
    particular_word_string_after_processing = ''.join(particular_word_after_processing)
    len_particular_word_string_after_processing_mushed = len(particular_word_string_after_processing)

    # encoding into spacy document to get the NER entity of each word
    sentence_doc = nlp(pre_processed_sentence_split_string) # splitted word phrase
    word_entities = [(e.text, e.ent_iob_, e.ent_type_, e.pos_) for e in sentence_doc]

    # check if the length of the entities that fed in matches with the len of entities that came out
    
    print("FOR NON COMBINED WORDS")

    print("After processing")
    print(pre_processed_sentence_split)
    print("After processing joint sentence")
    print(pre_processed_sentence_split_string)
    print("Pre processed word start index")
    print(pre_processed_word_start_index)
    print("Pre processed char start index")
    print(pre_processed_char_start_index)
    print("Pre processed split string")
    print(pre_processed_sentence_split_string)
    print("Part of sentence before particular word")
    print(part_of_sentence_before_particular_word)
    print("Part of sentence before particular word string")
    print(part_of_sentence_before_particular_word_string)
    print("Part of sentence before particular word string mushed")
    print(part_of_sentence_before_particular_word_string_mushed)
    print("FINAL: Pre Processed char start index mushed")
    print(pre_processed_char_start_index_mushed)    
    print("LEN OF WORD PHRASE AFTER MUSHED")
    print(len_particular_word_string_after_processing_mushed)
    
    print('Word Entities result')
    print(word_entities)

    # retrieving the entities to verify:

    # NON COMBINED SENTENCE 
    entities_index_non_combined = 0
    entities_char_non_combined = 0

    word_entities_to_verify_non_combined = []
    
    for entity in word_entities:
        if entities_char_non_combined < pre_processed_char_start_index_mushed:
            particular_entity_word = entity[0]
            particular_entity_word_length = len(particular_entity_word)
            entities_index_non_combined += 1
            entities_char_non_combined += particular_entity_word_length
        
    
    while entities_char_non_combined < (pre_processed_char_start_index_mushed + len_particular_word_string_after_processing_mushed):
        entity_to_append_non_combined = word_entities[entities_index_non_combined]
        word_entities_to_verify_non_combined.append(entity_to_append_non_combined)
        
        entities_char_non_combined += len(entity_to_append_non_combined[0])
        entities_index_non_combined += 1
    
    print("PRINTING NON COMBINED")
    print(word_entities_to_verify_non_combined)

    # retrieving all the labels and pos tags from each phrase (if any)
    label = []
    pos = []
    
    # otherwise append all of the NER tags from the split word entity (if there are)
    for numents in range(len(word_entities_to_verify_non_combined)):
        if word_entities_to_verify_non_combined[numents][2] != '':
            label.append(word_entities_to_verify_non_combined[numents][2])
        pos.append(word_entities_to_verify_non_combined[numents][3])
    
    print(label)
    print(pos)

    if label != []:
        new_label_before_convert[index] = list(label)
    else:
        new_label_before_convert[index] = []

    new_pos_before_convert[index] = list(pos)
    
    # Filtering - if the label list is not empty: 
    if label != []:
        label = [labels_to_tweebank[label_item] for label_item in label]
        
        if len(label) == num_words_particular:
            for num_word in range(len(label)):
                if num_word == 0:
                    label[num_word] = 'B-' + label[num_word]
                else:
                    label[num_word] = 'I-' + label[num_word]
        elif len(label) > num_words_particular:
            for num_word in range(num_words_particular):
                if num_word == 0:
                    label[num_word] = 'B-' + label[num_word]
                else:
                    label[num_word] = 'I-' + label[num_word]
        elif len(label) < num_words_particular:
            label_counter = Counter(label)
            most_common_label = label_counter.most_common(1)[0][0]
            label = []
            for num_word in range(num_words_particular):
                if num_word == 0:
                    label.append('B-' + most_common_label)
                else:
                    label.append('I-' + most_common_label)
        
        new_label[index] = label
        new_pos[index] = pos

    else:
        if '@user' in particular_word:
            new_label[index] = ['B-PER']
            new_pos[index] = pos
        elif 'PROPN' in pos:
            label = []
            for num_word in range(num_words_particular):
                if num_word == 0:
                    label.append('B-' + 'MISC')
                else:
                    label.append('I-' + 'MISC')
            new_label[index] = label
            new_pos[index] = pos
        else:
            new_pos[index] = pos
# Out:
# --------------------------------------------------
# Original Particular word
# @user415
# Original Sentence Split
# ['new', 'unique', 'backpack', '!', 'combines', 'vintage', 'with', 'modern', '!', 'url1283', 'via', '@user415']
# Original Start Index
# 11
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['new', 'unique', 'backpack', '!', 'combines', 'vintage', 'with', 'modern', '!', 'url1283', 'via', '@user415']
# After processing joint sentence
# new unique backpack ! combines vintage with modern ! url1283 via @user415
# Pre processed word start index
# 11
# Pre processed char start index
# 65
# Pre processed split string
# new unique backpack ! combines vintage with modern ! url1283 via @user415
# Part of sentence before particular word
# ['new', 'unique', 'backpack', '!', 'combines', 'vintage', 'with', 'modern', '!', 'url1283', 'via']
# Part of sentence before particular word string
# new unique backpack ! combines vintage with modern ! url1283 via
# Part of sentence before particular word string mushed
# newuniquebackpack!combinesvintagewithmodern!url1283via
# FINAL: Pre Processed char start index mushed
# 54
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('new', 'O', '', 'ADJ'), ('unique', 'O', '', 'ADJ'), ('backpack', 'O', '', 'NOUN'), ('!', 'O', '', 'PUNCT'), ('combines', 'O', '', 'VERB'), ('vintage', 'O', '', 'NOUN'), ('with', 'O', '', 'ADP'), ('modern', 'O', '', 'ADJ'), ('!', 'O', '', 'PUNCT'), ('url1283', 'O', '', 'X'), ('via', 'O', '', 'ADP'), ('@user415', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user415', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user1136
# Original Sentence Split
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# Original Start Index
# 11
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# After processing joint sentence
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Pre processed word start index
# 11
# Pre processed char start index
# 44
# Pre processed split string
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Part of sentence before particular word
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of']
# Part of sentence before particular word string
# i 've entered for a chance to win a copy of
# Part of sentence before particular word string mushed
# i'veenteredforachancetowinacopyof
# FINAL: Pre Processed char start index mushed
# 33
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('ve', 'O', '', 'AUX'), ('entered', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('chance', 'O', '', 'NOUN'), ('to', 'O', '', 'PART'), ('win', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('copy', 'O', '', 'NOUN'), ('of', 'O', '', 'ADP'), ('@user1136', 'O', '', 'PROPN'), ('on', 'O', '', 'ADP'), ('xb1', 'O', '', 'NOUN'), ('from', 'O', '', 'ADP'), ('@user1071', 'O', '', 'NOUN'), ('thanks', 'O', '', 'NOUN'), ('to', 'O', '', 'ADP'), ('@user718', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('enter', 'O', '', 'VERB'), ('here', 'O', '', 'ADV'), (':', 'O', '', 'PUNCT'), ('url1617', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user1136', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# xb1
# Original Sentence Split
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# Original Start Index
# 13
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# After processing joint sentence
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Pre processed word start index
# 13
# Pre processed char start index
# 57
# Pre processed split string
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Part of sentence before particular word
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on']
# Part of sentence before particular word string
# i 've entered for a chance to win a copy of @user1136 on
# Part of sentence before particular word string mushed
# i'veenteredforachancetowinacopyof@user1136on
# FINAL: Pre Processed char start index mushed
# 44
# LEN OF WORD PHRASE AFTER MUSHED
# 3
# Word Entities result
# [('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('ve', 'O', '', 'AUX'), ('entered', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('chance', 'O', '', 'NOUN'), ('to', 'O', '', 'PART'), ('win', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('copy', 'O', '', 'NOUN'), ('of', 'O', '', 'ADP'), ('@user1136', 'O', '', 'PROPN'), ('on', 'O', '', 'ADP'), ('xb1', 'O', '', 'NOUN'), ('from', 'O', '', 'ADP'), ('@user1071', 'O', '', 'NOUN'), ('thanks', 'O', '', 'NOUN'), ('to', 'O', '', 'ADP'), ('@user718', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('enter', 'O', '', 'VERB'), ('here', 'O', '', 'ADV'), (':', 'O', '', 'PUNCT'), ('url1617', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('xb1', 'O', '', 'NOUN')]
# []
# ['NOUN']
# --------------------------------------------------
# Original Particular word
# @user1071
# Original Sentence Split
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# Original Start Index
# 15
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# After processing joint sentence
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Pre processed word start index
# 15
# Pre processed char start index
# 66
# Pre processed split string
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Part of sentence before particular word
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from']
# Part of sentence before particular word string
# i 've entered for a chance to win a copy of @user1136 on xb1 from
# Part of sentence before particular word string mushed
# i'veenteredforachancetowinacopyof@user1136onxb1from
# FINAL: Pre Processed char start index mushed
# 51
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('ve', 'O', '', 'AUX'), ('entered', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('chance', 'O', '', 'NOUN'), ('to', 'O', '', 'PART'), ('win', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('copy', 'O', '', 'NOUN'), ('of', 'O', '', 'ADP'), ('@user1136', 'O', '', 'PROPN'), ('on', 'O', '', 'ADP'), ('xb1', 'O', '', 'NOUN'), ('from', 'O', '', 'ADP'), ('@user1071', 'O', '', 'NOUN'), ('thanks', 'O', '', 'NOUN'), ('to', 'O', '', 'ADP'), ('@user718', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('enter', 'O', '', 'VERB'), ('here', 'O', '', 'ADV'), (':', 'O', '', 'PUNCT'), ('url1617', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user1071', 'O', '', 'NOUN')]
# []
# ['NOUN']
# --------------------------------------------------
# Original Particular word
# @user718
# Original Sentence Split
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# Original Start Index
# 18
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to', '@user718', '!', 'enter', 'here', ':', 'url1617']
# After processing joint sentence
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Pre processed word start index
# 18
# Pre processed char start index
# 86
# Pre processed split string
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to @user718 ! enter here : url1617
# Part of sentence before particular word
# ['i', "'ve", 'entered', 'for', 'a', 'chance', 'to', 'win', 'a', 'copy', 'of', '@user1136', 'on', 'xb1', 'from', '@user1071', 'thanks', 'to']
# Part of sentence before particular word string
# i 've entered for a chance to win a copy of @user1136 on xb1 from @user1071 thanks to
# Part of sentence before particular word string mushed
# i'veenteredforachancetowinacopyof@user1136onxb1from@user1071thanksto
# FINAL: Pre Processed char start index mushed
# 68
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('ve', 'O', '', 'AUX'), ('entered', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('a', 'O', '', 'DET'), ('chance', 'O', '', 'NOUN'), ('to', 'O', '', 'PART'), ('win', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('copy', 'O', '', 'NOUN'), ('of', 'O', '', 'ADP'), ('@user1136', 'O', '', 'PROPN'), ('on', 'O', '', 'ADP'), ('xb1', 'O', '', 'NOUN'), ('from', 'O', '', 'ADP'), ('@user1071', 'O', '', 'NOUN'), ('thanks', 'O', '', 'NOUN'), ('to', 'O', '', 'ADP'), ('@user718', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT'), ('enter', 'O', '', 'VERB'), ('here', 'O', '', 'ADV'), (':', 'O', '', 'PUNCT'), ('url1617', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user718', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# cod
# Original Sentence Split
# ['rt', '@user2437', ':', 'if', 'you', 'have', 'short', 'memory', 'let', 'me', 'inform', 'you', 'after', 'signing', 'cod', 'benazir', 'made', 'infamous', 'nro', 'deal', 'with', 'mushi', '.', '☺', 'url224', '…']
# Original Start Index
# 14
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user2437', ':', 'if', 'you', 'have', 'short', 'memory', 'let', 'me', 'inform', 'you', 'after', 'signing', 'cod', 'benazir', 'made', 'infamous', 'nro', 'deal', 'with', 'mushi', '.', '☺', 'url224', '…']
# After processing joint sentence
# rt @user2437 : if you have short memory let me inform you after signing cod benazir made infamous nro deal with mushi . ☺ url224 …
# Pre processed word start index
# 14
# Pre processed char start index
# 72
# Pre processed split string
# rt @user2437 : if you have short memory let me inform you after signing cod benazir made infamous nro deal with mushi . ☺ url224 …
# Part of sentence before particular word
# ['rt', '@user2437', ':', 'if', 'you', 'have', 'short', 'memory', 'let', 'me', 'inform', 'you', 'after', 'signing']
# Part of sentence before particular word string
# rt @user2437 : if you have short memory let me inform you after signing
# Part of sentence before particular word string mushed
# rt@user2437:ifyouhaveshortmemoryletmeinformyouaftersigning
# FINAL: Pre Processed char start index mushed
# 58
# LEN OF WORD PHRASE AFTER MUSHED
# 3
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user2437', 'O', '', 'PROPN'), (':', 'O', '', 'PUNCT'), ('if', 'O', '', 'SCONJ'), ('you', 'O', '', 'PRON'), ('have', 'O', '', 'VERB'), ('short', 'O', '', 'ADJ'), ('memory', 'O', '', 'NOUN'), ('let', 'O', '', 'VERB'), ('me', 'O', '', 'PRON'), ('inform', 'O', '', 'VERB'), ('you', 'O', '', 'PRON'), ('after', 'O', '', 'ADP'), ('signing', 'O', '', 'VERB'), ('cod', 'O', '', 'PROPN'), ('benazir', 'O', '', 'PROPN'), ('made', 'O', '', 'VERB'), ('infamous', 'O', '', 'ADJ'), ('nro', 'O', '', 'PROPN'), ('deal', 'O', '', 'NOUN'), ('with', 'O', '', 'ADP'), ('mushi', 'O', '', 'PROPN'), ('.', 'O', '', 'PUNCT'), ('☺', 'O', '', 'PUNCT'), ('url224', 'O', '', 'PROPN'), ('…', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('cod', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user265
# Original Sentence Split
# ['rt', '@user1218', ':', '@user265', 'blessed', 'sunday', '😊']
# Original Start Index
# 3
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user1218', ':', '@user265', 'blessed', 'sunday', '😊']
# After processing joint sentence
# rt @user1218 : @user265 blessed sunday 😊
# Pre processed word start index
# 3
# Pre processed char start index
# 15
# Pre processed split string
# rt @user1218 : @user265 blessed sunday 😊
# Part of sentence before particular word
# ['rt', '@user1218', ':']
# Part of sentence before particular word string
# rt @user1218 :
# Part of sentence before particular word string mushed
# rt@user1218:
# FINAL: Pre Processed char start index mushed
# 12
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('rt', 'O', '', 'X'), ('@user1218', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('@user265', 'O', '', 'X'), ('blessed', 'O', '', 'VERB'), ('sunday', 'B', 'DATE', 'PROPN'), ('😊', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user265', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# sunday
# Original Sentence Split
# ['rt', '@user1218', ':', '@user265', 'blessed', 'sunday', '😊']
# Original Start Index
# 5
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user1218', ':', '@user265', 'blessed', 'sunday', '😊']
# After processing joint sentence
# rt @user1218 : @user265 blessed sunday 😊
# Pre processed word start index
# 5
# Pre processed char start index
# 32
# Pre processed split string
# rt @user1218 : @user265 blessed sunday 😊
# Part of sentence before particular word
# ['rt', '@user1218', ':', '@user265', 'blessed']
# Part of sentence before particular word string
# rt @user1218 : @user265 blessed
# Part of sentence before particular word string mushed
# rt@user1218:@user265blessed
# FINAL: Pre Processed char start index mushed
# 27
# LEN OF WORD PHRASE AFTER MUSHED
# 6
# Word Entities result
# [('rt', 'O', '', 'X'), ('@user1218', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('@user265', 'O', '', 'X'), ('blessed', 'O', '', 'VERB'), ('sunday', 'B', 'DATE', 'PROPN'), ('😊', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('sunday', 'B', 'DATE', 'PROPN')]
# ['DATE']
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user1771
# Original Sentence Split
# ['"', '@user1771', ':', 'denial', 'has', 'become', 'such', 'a', 'comfort', 'for', 'some', 'that', 'the', 'truth', 'has', 'become', 'an', 'illusion', '.', '"']
# Original Start Index
# 1
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['"', '@user1771', ':', 'denial', 'has', 'become', 'such', 'a', 'comfort', 'for', 'some', 'that', 'the', 'truth', 'has', 'become', 'an', 'illusion', '.', '"']
# After processing joint sentence
# " @user1771 : denial has become such a comfort for some that the truth has become an illusion . "
# Pre processed word start index
# 1
# Pre processed char start index
# 2
# Pre processed split string
# " @user1771 : denial has become such a comfort for some that the truth has become an illusion . "
# Part of sentence before particular word
# ['"']
# Part of sentence before particular word string
# "
# Part of sentence before particular word string mushed
# "
# FINAL: Pre Processed char start index mushed
# 1
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('"', 'O', '', 'PUNCT'), ('@user1771', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('denial', 'O', '', 'NOUN'), ('has', 'O', '', 'AUX'), ('become', 'O', '', 'VERB'), ('such', 'O', '', 'DET'), ('a', 'O', '', 'DET'), ('comfort', 'O', '', 'NOUN'), ('for', 'O', '', 'ADP'), ('some', 'O', '', 'PRON'), ('that', 'O', '', 'SCONJ'), ('the', 'O', '', 'DET'), ('truth', 'O', '', 'NOUN'), ('has', 'O', '', 'AUX'), ('become', 'O', '', 'VERB'), ('an', 'O', '', 'DET'), ('illusion', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user1771', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# denial
# Original Sentence Split
# ['"', '@user1771', ':', 'denial', 'has', 'become', 'such', 'a', 'comfort', 'for', 'some', 'that', 'the', 'truth', 'has', 'become', 'an', 'illusion', '.', '"']
# Original Start Index
# 3
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['"', '@user1771', ':', 'denial', 'has', 'become', 'such', 'a', 'comfort', 'for', 'some', 'that', 'the', 'truth', 'has', 'become', 'an', 'illusion', '.', '"']
# After processing joint sentence
# " @user1771 : denial has become such a comfort for some that the truth has become an illusion . "
# Pre processed word start index
# 3
# Pre processed char start index
# 14
# Pre processed split string
# " @user1771 : denial has become such a comfort for some that the truth has become an illusion . "
# Part of sentence before particular word
# ['"', '@user1771', ':']
# Part of sentence before particular word string
# " @user1771 :
# Part of sentence before particular word string mushed
# "@user1771:
# FINAL: Pre Processed char start index mushed
# 11
# LEN OF WORD PHRASE AFTER MUSHED
# 6
# Word Entities result
# [('"', 'O', '', 'PUNCT'), ('@user1771', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('denial', 'O', '', 'NOUN'), ('has', 'O', '', 'AUX'), ('become', 'O', '', 'VERB'), ('such', 'O', '', 'DET'), ('a', 'O', '', 'DET'), ('comfort', 'O', '', 'NOUN'), ('for', 'O', '', 'ADP'), ('some', 'O', '', 'PRON'), ('that', 'O', '', 'SCONJ'), ('the', 'O', '', 'DET'), ('truth', 'O', '', 'NOUN'), ('has', 'O', '', 'AUX'), ('become', 'O', '', 'VERB'), ('an', 'O', '', 'DET'), ('illusion', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT'), ('"', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('denial', 'O', '', 'NOUN')]
# []
# ['NOUN']
# --------------------------------------------------
# Original Particular word
# @user1659
# Original Sentence Split
# ['#nowplaying', 'get', 'another', 'boyfriend', 'of', '@user1659']
# Original Start Index
# 5
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['nowplaying', 'get', 'another', 'boyfriend', 'of', '@user1659']
# After processing joint sentence
# nowplaying get another boyfriend of @user1659
# Pre processed word start index
# 5
# Pre processed char start index
# 36
# Pre processed split string
# nowplaying get another boyfriend of @user1659
# Part of sentence before particular word
# ['nowplaying', 'get', 'another', 'boyfriend', 'of']
# Part of sentence before particular word string
# nowplaying get another boyfriend of
# Part of sentence before particular word string mushed
# nowplayinggetanotherboyfriendof
# FINAL: Pre Processed char start index mushed
# 31
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('nowplaying', 'O', '', 'X'), ('get', 'O', '', 'VERB'), ('another', 'O', '', 'DET'), ('boyfriend', 'O', '', 'NOUN'), ('of', 'O', '', 'ADP'), ('@user1659', 'O', '', 'PROPN')]
# PRINTING NON COMBINED
# [('@user1659', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user1012
# Original Sentence Split
# ['.', '@user1012', '&', 'i', 'are', 'talking', 'about', 'optics', 'entrepreneurship', '&', '"', 'the', 'actuality', 'story', '"', 'tonight', 'media', 'lab', 'e14', '-', '525', '6', 'p', '-', '8', 'p', 'for', 'url51']
# Original Start Index
# 1
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['.', '@user1012', '&', 'i', 'are', 'talking', 'about', 'optics', 'entrepreneurship', '&', '"', 'the', 'actuality', 'story', '"', 'tonight', 'media', 'lab', 'e14', '-', '525', '6', 'p', '-', '8', 'p', 'for', 'url51']
# After processing joint sentence
# . @user1012 & i are talking about optics entrepreneurship & " the actuality story " tonight media lab e14 - 525 6 p - 8 p for url51
# Pre processed word start index
# 1
# Pre processed char start index
# 2
# Pre processed split string
# . @user1012 & i are talking about optics entrepreneurship & " the actuality story " tonight media lab e14 - 525 6 p - 8 p for url51
# Part of sentence before particular word
# ['.']
# Part of sentence before particular word string
# .
# Part of sentence before particular word string mushed
# .
# FINAL: Pre Processed char start index mushed
# 1
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('.', 'O', '', 'PUNCT'), ('@user1012', 'O', '', 'PROPN'), ('&', 'O', '', 'CCONJ'), ('i', 'O', '', 'PRON'), ('are', 'O', '', 'AUX'), ('talking', 'O', '', 'VERB'), ('about', 'O', '', 'ADP'), ('optics', 'O', '', 'NOUN'), ('entrepreneurship', 'O', '', 'NOUN'), ('&', 'O', '', 'CCONJ'), ('"', 'B', 'WORK_OF_ART', 'PUNCT'), ('the', 'I', 'WORK_OF_ART', 'DET'), ('actuality', 'I', 'WORK_OF_ART', 'PROPN'), ('story', 'I', 'WORK_OF_ART', 'PROPN'), ('"', 'I', 'WORK_OF_ART', 'PUNCT'), ('tonight', 'O', '', 'NOUN'), ('media', 'O', '', 'NOUN'), ('lab', 'O', '', 'NOUN'), ('e14', 'O', '', 'NUM'), ('-', 'O', '', 'PUNCT'), ('525', 'O', '', 'NUM'), ('6', 'O', '', 'NUM'), ('p', 'O', '', 'NOUN'), ('-', 'O', '', 'SYM'), ('8', 'O', '', 'NUM'), ('p', 'O', '', 'NOUN'), ('for', 'O', '', 'ADP'), ('url51', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# [('@user1012', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user90
# Original Sentence Split
# ['@user90', 'nbc', 'is', 'going', 'to', 'have', 'the', 'nyc', 'fireworks', 'on', '.', 'they', 'are', 'amazing', '-', 'at', 'least', 'in', 'person', 'they', 'were', 'two', 'years', 'ago', '.']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user90', 'nbc', 'is', 'going', 'to', 'have', 'the', 'nyc', 'fireworks', 'on', '.', 'they', 'are', 'amazing', '-', 'at', 'least', 'in', 'person', 'they', 'were', 'two', 'years', 'ago', '.']
# After processing joint sentence
# @user90 nbc is going to have the nyc fireworks on . they are amazing - at least in person they were two years ago .
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user90 nbc is going to have the nyc fireworks on . they are amazing - at least in person they were two years ago .
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 7
# Word Entities result
# [('@user90', 'O', '', 'X'), ('nbc', 'B', 'ORG', 'PROPN'), ('is', 'O', '', 'AUX'), ('going', 'O', '', 'VERB'), ('to', 'O', '', 'PART'), ('have', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('nyc', 'O', '', 'PROPN'), ('fireworks', 'O', '', 'NOUN'), ('on', 'O', '', 'ADP'), ('.', 'O', '', 'PUNCT'), ('they', 'O', '', 'PRON'), ('are', 'O', '', 'AUX'), ('amazing', 'O', '', 'ADJ'), ('-', 'O', '', 'PUNCT'), ('at', 'O', '', 'ADP'), ('least', 'O', '', 'ADJ'), ('in', 'O', '', 'ADP'), ('person', 'O', '', 'NOUN'), ('they', 'O', '', 'PRON'), ('were', 'O', '', 'AUX'), ('two', 'B', 'DATE', 'NUM'), ('years', 'I', 'DATE', 'NOUN'), ('ago', 'I', 'DATE', 'ADV'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user90', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user153
# Original Sentence Split
# ['@user153', 'i', "'m", 'scoopin', 'jo', 'right', 'now']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user153', 'i', "'m", 'scoopin', 'jo', 'right', 'now']
# After processing joint sentence
# @user153 i 'm scoopin jo right now
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user153 i 'm scoopin jo right now
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user153', 'O', '', 'PROPN'), ('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('m', 'O', '', 'AUX'), ('scoopin', 'O', '', 'VERB'), ('jo', 'O', '', 'PROPN'), ('right', 'O', '', 'ADV'), ('now', 'O', '', 'ADV')]
# PRINTING NON COMBINED
# [('@user153', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user272
# Original Sentence Split
# ['@user272', 'i', "'m", 'from', 'england', '.', 'where', "'s", 'missiuri', '?']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user272', 'i', "'m", 'from', 'england', '.', 'where', "'s", 'missiuri', '?']
# After processing joint sentence
# @user272 i 'm from england . where 's missiuri ?
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user272 i 'm from england . where 's missiuri ?
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user272', 'O', '', 'PROPN'), ('i', 'O', '', 'PRON'), ("'", 'O', '', 'VERB'), ('m', 'O', '', 'VERB'), ('from', 'O', '', 'ADP'), ('england', 'O', '', 'PROPN'), ('.', 'O', '', 'PUNCT'), ('where', 'O', '', 'SCONJ'), ("'s", 'O', '', 'AUX'), ('missiuri', 'B', 'PERSON', 'PROPN'), ('?', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user272', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user288
# Original Sentence Split
# ['@user288', 'i', 'did', 'tooo', '!', 'this', 'is', 'getting', 'goood', '.', 'lol']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user288', 'i', 'did', 'tooo', '!', 'this', 'is', 'getting', 'goood', '.', 'lol']
# After processing joint sentence
# @user288 i did tooo ! this is getting goood . lol
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user288 i did tooo ! this is getting goood . lol
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user288', 'O', '', 'PROPN'), ('i', 'O', '', 'PRON'), ('did', 'O', '', 'AUX'), ('tooo', 'O', '', 'INTJ'), ('!', 'O', '', 'PUNCT'), ('this', 'O', '', 'PRON'), ('is', 'O', '', 'AUX'), ('getting', 'O', '', 'VERB'), ('goood', 'O', '', 'ADJ'), ('.', 'O', '', 'PUNCT'), ('lol', 'O', '', 'INTJ')]
# PRINTING NON COMBINED
# [('@user288', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user312
# Original Sentence Split
# ['@user312', 'well', 'i', "'m", 'fuckn', 'amazin', '..', 'lol', '...', 'tottaly', 'awsome', 'who', "'s", 'bad', 'now', 'lol']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user312', 'well', 'i', "'m", 'fuckn', 'amazin', '..', 'lol', '...', 'tottaly', 'awsome', 'who', "'s", 'bad', 'now', 'lol']
# After processing joint sentence
# @user312 well i 'm fuckn amazin .. lol ... tottaly awsome who 's bad now lol
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user312 well i 'm fuckn amazin .. lol ... tottaly awsome who 's bad now lol
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user312', 'O', '', 'PROPN'), ('well', 'O', '', 'INTJ'), ('i', 'O', '', 'PRON'), ("'", 'O', '', 'AUX'), ('m', 'O', '', 'AUX'), ('fuckn', 'O', '', 'ADV'), ('amazin', 'O', '', 'VERB'), ('..', 'O', '', 'PUNCT'), ('lol', 'O', '', 'INTJ'), ('...', 'O', '', 'PUNCT'), ('tottaly', 'O', '', 'PROPN'), ('awsome', 'O', '', 'PROPN'), ('who', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('bad', 'O', '', 'ADJ'), ('now', 'O', '', 'ADV'), ('lol', 'O', '', 'INTJ')]
# PRINTING NON COMBINED
# [('@user312', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user349
# Original Sentence Split
# ['@user349', 'i', 'already', 'have', 'sis', '!!!', 'girl', 'they', 'hate', 'me', '!']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user349', 'i', 'already', 'have', 'sis', '!!!', 'girl', 'they', 'hate', 'me', '!']
# After processing joint sentence
# @user349 i already have sis !!! girl they hate me !
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user349 i already have sis !!! girl they hate me !
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user349', 'O', '', 'PROPN'), ('i', 'O', '', 'PRON'), ('already', 'O', '', 'ADV'), ('have', 'O', '', 'VERB'), ('sis', 'O', '', 'NOUN'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('girl', 'O', '', 'INTJ'), ('they', 'O', '', 'PRON'), ('hate', 'O', '', 'VERB'), ('me', 'O', '', 'PRON'), ('!', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user349', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user355
# Original Sentence Split
# ['@user355', 'yea', 'i', 'was', 'wondering', 'if', 'after', 'they', 'banned', 'the', 'indian', 'we', 'got', 'a', 'new', 'one']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user355', 'yea', 'i', 'was', 'wondering', 'if', 'after', 'they', 'banned', 'the', 'indian', 'we', 'got', 'a', 'new', 'one']
# After processing joint sentence
# @user355 yea i was wondering if after they banned the indian we got a new one
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user355 yea i was wondering if after they banned the indian we got a new one
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user355', 'O', '', 'PROPN'), ('yea', 'O', '', 'INTJ'), ('i', 'O', '', 'PRON'), ('was', 'O', '', 'AUX'), ('wondering', 'O', '', 'VERB'), ('if', 'O', '', 'SCONJ'), ('after', 'O', '', 'SCONJ'), ('they', 'O', '', 'PRON'), ('banned', 'O', '', 'VERB'), ('the', 'O', '', 'DET'), ('indian', 'O', '', 'PROPN'), ('we', 'O', '', 'PRON'), ('got', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('new', 'O', '', 'ADJ'), ('one', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# [('@user355', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user357
# Original Sentence Split
# ['@user357', ':d']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user357', ':d']
# After processing joint sentence
# @user357 :d
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user357 :d
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user357', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('d', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user357', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user367
# Original Sentence Split
# ['@user367', 'lmbo']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user367', 'lmbo']
# After processing joint sentence
# @user367 lmbo
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user367 lmbo
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user367', 'O', '', 'X'), ('lmbo', 'O', '', 'PROPN')]
# PRINTING NON COMBINED
# [('@user367', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user403
# Original Sentence Split
# ['@user403', 'the', 'one', 'you', 'said', 'you', 'was', 'gon', 'na', 'make', '.', 'the', 'one', 'i', 'bought', 'everything', 'for', 'and', 'have', 'been', 'waiting', 'for', '?']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user403', 'the', 'one', 'you', 'said', 'you', 'was', 'gon', 'na', 'make', '.', 'the', 'one', 'i', 'bought', 'everything', 'for', 'and', 'have', 'been', 'waiting', 'for', '?']
# After processing joint sentence
# @user403 the one you said you was gon na make . the one i bought everything for and have been waiting for ?
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user403 the one you said you was gon na make . the one i bought everything for and have been waiting for ?
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user403', 'O', '', 'PROPN'), ('the', 'O', '', 'DET'), ('one', 'O', '', 'NOUN'), ('you', 'O', '', 'PRON'), ('said', 'O', '', 'VERB'), ('you', 'O', '', 'PRON'), ('was', 'O', '', 'AUX'), ('gon', 'O', '', 'VERB'), ('na', 'O', '', 'PART'), ('make', 'O', '', 'VERB'), ('.', 'O', '', 'PUNCT'), ('the', 'O', '', 'DET'), ('one', 'O', '', 'NOUN'), ('i', 'O', '', 'PRON'), ('bought', 'O', '', 'VERB'), ('everything', 'O', '', 'PRON'), ('for', 'O', '', 'ADP'), ('and', 'O', '', 'CCONJ'), ('have', 'O', '', 'AUX'), ('been', 'O', '', 'AUX'), ('waiting', 'O', '', 'VERB'), ('for', 'O', '', 'ADP'), ('?', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user403', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user446
# Original Sentence Split
# ['@user446', 'how', '??!']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user446', 'how', '??!']
# After processing joint sentence
# @user446 how ??!
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user446 how ??!
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user446', 'O', '', 'X'), ('how', 'O', '', 'SCONJ'), ('?', 'O', '', 'PUNCT'), ('?', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user446', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user447
# Original Sentence Split
# ['@user447', 'miss', 'yhuuuu', '!']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user447', 'miss', 'yhuuuu', '!']
# After processing joint sentence
# @user447 miss yhuuuu !
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user447 miss yhuuuu !
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user447', 'O', '', 'X'), ('miss', 'O', '', 'PROPN'), ('yhuuuu', 'O', '', 'PROPN'), ('!', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user447', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user547
# Original Sentence Split
# ['@user547', 'that', 'is', 'the', 'most', 'stunning', 'creature', 'i', 'have', 'ever', 'seen']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user547', 'that', 'is', 'the', 'most', 'stunning', 'creature', 'i', 'have', 'ever', 'seen']
# After processing joint sentence
# @user547 that is the most stunning creature i have ever seen
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user547 that is the most stunning creature i have ever seen
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user547', 'O', '', 'PROPN'), ('that', 'O', '', 'PRON'), ('is', 'O', '', 'AUX'), ('the', 'O', '', 'DET'), ('most', 'O', '', 'ADV'), ('stunning', 'O', '', 'ADJ'), ('creature', 'O', '', 'NOUN'), ('i', 'O', '', 'PRON'), ('have', 'O', '', 'AUX'), ('ever', 'O', '', 'ADV'), ('seen', 'O', '', 'VERB')]
# PRINTING NON COMBINED
# [('@user547', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user600
# Original Sentence Split
# ['@user600', 'yeah', 'i', 'm', 'goodie', 'just', 'in', 'the', 'lab', 'working', '...', 'wow', '!', 'i', 'need', 'to', 'be', 'where', 'you', 'at', '!', 'lol', 'let', 'me', 'visit']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user600', 'yeah', 'i', 'm', 'goodie', 'just', 'in', 'the', 'lab', 'working', '...', 'wow', '!', 'i', 'need', 'to', 'be', 'where', 'you', 'at', '!', 'lol', 'let', 'me', 'visit']
# After processing joint sentence
# @user600 yeah i m goodie just in the lab working ... wow ! i need to be where you at ! lol let me visit
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user600 yeah i m goodie just in the lab working ... wow ! i need to be where you at ! lol let me visit
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user600', 'O', '', 'X'), ('yeah', 'O', '', 'INTJ'), ('i', 'O', '', 'PRON'), ('m', 'O', '', 'VERB'), ('goodie', 'O', '', 'ADJ'), ('just', 'O', '', 'ADV'), ('in', 'O', '', 'ADP'), ('the', 'O', '', 'DET'), ('lab', 'O', '', 'NOUN'), ('working', 'O', '', 'VERB'), ('...', 'O', '', 'PUNCT'), ('wow', 'O', '', 'INTJ'), ('!', 'O', '', 'PUNCT'), ('i', 'O', '', 'PRON'), ('need', 'O', '', 'VERB'), ('to', 'O', '', 'PART'), ('be', 'O', '', 'AUX'), ('where', 'O', '', 'SCONJ'), ('you', 'O', '', 'PRON'), ('at', 'O', '', 'ADV'), ('!', 'O', '', 'PUNCT'), ('lol', 'O', '', 'INTJ'), ('let', 'O', '', 'VERB'), ('me', 'O', '', 'PRON'), ('visit', 'O', '', 'VERB')]
# PRINTING NON COMBINED
# [('@user600', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user678
# Original Sentence Split
# ['@user678', 'that', "'s", 'a', 'tight', 'score', '.']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user678', 'that', "'s", 'a', 'tight', 'score', '.']
# After processing joint sentence
# @user678 that 's a tight score .
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user678 that 's a tight score .
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user678', 'O', '', 'PROPN'), ('that', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('a', 'O', '', 'DET'), ('tight', 'O', '', 'ADJ'), ('score', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user678', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user688
# Original Sentence Split
# ['@user688', 'i', 'hear', 'enough', 'talking', ',', 'just', 'turn', 'round', 'keep', 'walking', 'haha', 'in', 'that', 'part']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user688', 'i', 'hear', 'enough', 'talking', ',', 'just', 'turn', 'round', 'keep', 'walking', 'haha', 'in', 'that', 'part']
# After processing joint sentence
# @user688 i hear enough talking , just turn round keep walking haha in that part
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user688 i hear enough talking , just turn round keep walking haha in that part
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user688', 'O', '', 'X'), ('i', 'O', '', 'PRON'), ('hear', 'O', '', 'VERB'), ('enough', 'O', '', 'ADJ'), ('talking', 'O', '', 'NOUN'), (',', 'O', '', 'PUNCT'), ('just', 'O', '', 'ADV'), ('turn', 'O', '', 'VERB'), ('round', 'O', '', 'ADV'), ('keep', 'O', '', 'VERB'), ('walking', 'O', '', 'VERB'), ('haha', 'O', '', 'INTJ'), ('in', 'O', '', 'ADP'), ('that', 'O', '', 'DET'), ('part', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# [('@user688', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user771
# Original Sentence Split
# ['@user771', 'that', "'s", 'ladybug']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user771', 'that', "'s", 'ladybug']
# After processing joint sentence
# @user771 that 's ladybug
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user771 that 's ladybug
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user771', 'O', '', 'X'), ('that', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('ladybug', 'O', '', 'PROPN')]
# PRINTING NON COMBINED
# [('@user771', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user842
# Original Sentence Split
# ['@user842', 'hi', ',', 'how', 'are', 'you', 'good', '?', 'url142']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user842', 'hi', ',', 'how', 'are', 'you', 'good', '?', 'url142']
# After processing joint sentence
# @user842 hi , how are you good ? url142
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user842 hi , how are you good ? url142
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user842', 'O', '', 'PROPN'), ('hi', 'O', '', 'INTJ'), (',', 'O', '', 'PUNCT'), ('how', 'O', '', 'SCONJ'), ('are', 'O', '', 'AUX'), ('you', 'O', '', 'PRON'), ('good', 'O', '', 'ADJ'), ('?', 'O', '', 'PUNCT'), ('url142', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user842', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user915
# Original Sentence Split
# ['@user915', 'oh', 'nasty', 'perv', 'lol']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user915', 'oh', 'nasty', 'perv', 'lol']
# After processing joint sentence
# @user915 oh nasty perv lol
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user915 oh nasty perv lol
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user915', 'O', '', 'X'), ('oh', 'O', '', 'INTJ'), ('nasty', 'O', '', 'ADJ'), ('perv', 'O', '', 'NOUN'), ('lol', 'O', '', 'INTJ')]
# PRINTING NON COMBINED
# [('@user915', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user935
# Original Sentence Split
# ['@user935', 'aight', 'leaving', 'my', 'crib', 'in', '20', 'minutes']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user935', 'aight', 'leaving', 'my', 'crib', 'in', '20', 'minutes']
# After processing joint sentence
# @user935 aight leaving my crib in 20 minutes
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user935 aight leaving my crib in 20 minutes
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user935', 'O', '', 'PROPN'), ('aight', 'O', '', 'X'), ('leaving', 'O', '', 'VERB'), ('my', 'O', '', 'PRON'), ('crib', 'O', '', 'NOUN'), ('in', 'O', '', 'ADP'), ('20', 'O', '', 'NUM'), ('minutes', 'O', '', 'NOUN')]
# PRINTING NON COMBINED
# [('@user935', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user1007
# Original Sentence Split
# ['@user1007', 'has', 'no', 'sense', '!!!', 'lol']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1007', 'has', 'no', 'sense', '!!!', 'lol']
# After processing joint sentence
# @user1007 has no sense !!! lol
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user1007 has no sense !!! lol
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('@user1007', 'O', '', 'NOUN'), ('has', 'O', '', 'VERB'), ('no', 'O', '', 'DET'), ('sense', 'O', '', 'NOUN'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('!', 'O', '', 'PUNCT'), ('lol', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user1007', 'O', '', 'NOUN')]
# []
# ['NOUN']
# --------------------------------------------------
# Original Particular word
# @user1022
# Original Sentence Split
# ['@user1022', 'i', 'had', 'potted', 'shrimp', 'last', 'night', '.', 'except', 'someone', 'else', 'ordered', 'it', '&', 'i', 'could', "n't", 'work', 'out', 'why', 'we', 'had', 'creme', 'brulee', 'for', 'a', 'starter', '...']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1022', 'i', 'had', 'potted', 'shrimp', 'last', 'night', '.', 'except', 'someone', 'else', 'ordered', 'it', '&', 'i', 'could', "n't", 'work', 'out', 'why', 'we', 'had', 'creme', 'brulee', 'for', 'a', 'starter', '...']
# After processing joint sentence
# @user1022 i had potted shrimp last night . except someone else ordered it & i could n't work out why we had creme brulee for a starter ...
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user1022 i had potted shrimp last night . except someone else ordered it & i could n't work out why we had creme brulee for a starter ...
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# ...
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('@user519', 'O', '', 'X'), ('@user1903', 'O', '', 'X'), ('this', 'O', '', 'PRON'), ('deserves', 'O', '', 'VERB'), ('many', 'O', '', 'ADJ'), ('favorites', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user519', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user1903
# Original Sentence Split
# ['@user519', '@user1903', 'this', 'deserves', 'many', 'favorites', '.']
# Original Start Index
# 1
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user519', '@user1903', 'this', 'deserves', 'many', 'favorites', '.']
# After processing joint sentence
# @user519 @user1903 this deserves many favorites .
# Pre processed word start index
# 1
# Pre processed char start index
# 9
# Pre processed split string
# @user519 @user1903 this deserves many favorites .
# Part of sentence before particular word
# ['@user519']
# Part of sentence before particular word string
# @user519
# Part of sentence before particular word string mushed
# @user519
# FINAL: Pre Processed char start index mushed
# 8
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('@user519', 'O', '', 'X'), ('@user1903', 'O', '', 'X'), ('this', 'O', '', 'PRON'), ('deserves', 'O', '', 'VERB'), ('many', 'O', '', 'ADJ'), ('favorites', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user1903', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# ii
# Original Sentence Split
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# After processing joint sentence
# ii guess ii wo n't be getting what ii want tonight ..
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# ii guess ii wo n't be getting what ii want tonight ..
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 2
# Word Entities result
# [('ii', 'O', '', 'X'), ('guess', 'O', '', 'VERB'), ('ii', 'O', '', 'PRON'), ('wo', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('be', 'O', '', 'AUX'), ('getting', 'O', '', 'VERB'), ('what', 'O', '', 'PRON'), ('ii', 'O', '', 'PRON'), ('want', 'O', '', 'VERB'), ('tonight', 'B', 'TIME', 'NOUN'), ('..', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('ii', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# ii
# Original Sentence Split
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# Original Start Index
# 2
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# After processing joint sentence
# ii guess ii wo n't be getting what ii want tonight ..
# Pre processed word start index
# 2
# Pre processed char start index
# 9
# Pre processed split string
# ii guess ii wo n't be getting what ii want tonight ..
# Part of sentence before particular word
# ['ii', 'guess']
# Part of sentence before particular word string
# ii guess
# Part of sentence before particular word string mushed
# iiguess
# FINAL: Pre Processed char start index mushed
# 7
# LEN OF WORD PHRASE AFTER MUSHED
# 2
# Word Entities result
# [('ii', 'O', '', 'X'), ('guess', 'O', '', 'VERB'), ('ii', 'O', '', 'PRON'), ('wo', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('be', 'O', '', 'AUX'), ('getting', 'O', '', 'VERB'), ('what', 'O', '', 'PRON'), ('ii', 'O', '', 'PRON'), ('want', 'O', '', 'VERB'), ('tonight', 'B', 'TIME', 'NOUN'), ('..', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('ii', 'O', '', 'PRON')]
# []
# ['PRON']
# --------------------------------------------------
# Original Particular word
# ii
# Original Sentence Split
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# Original Start Index
# 8
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what', 'ii', 'want', 'tonight', '..']
# After processing joint sentence
# ii guess ii wo n't be getting what ii want tonight ..
# Pre processed word start index
# 8
# Pre processed char start index
# 35
# Pre processed split string
# ii guess ii wo n't be getting what ii want tonight ..
# Part of sentence before particular word
# ['ii', 'guess', 'ii', 'wo', "n't", 'be', 'getting', 'what']
# Part of sentence before particular word string
# ii guess ii wo n't be getting what
# Part of sentence before particular word string mushed
# iiguessiiwon'tbegettingwhat
# FINAL: Pre Processed char start index mushed
# 27
# LEN OF WORD PHRASE AFTER MUSHED
# 2
# Word Entities result
# [('ii', 'O', '', 'X'), ('guess', 'O', '', 'VERB'), ('ii', 'O', '', 'PRON'), ('wo', 'O', '', 'AUX'), ("n't", 'O', '', 'PART'), ('be', 'O', '', 'AUX'), ('getting', 'O', '', 'VERB'), ('what', 'O', '', 'PRON'), ('ii', 'O', '', 'PRON'), ('want', 'O', '', 'VERB'), ('tonight', 'B', 'TIME', 'NOUN'), ('..', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('ii', 'O', '', 'PRON')]
# []
# ['PRON']
# --------------------------------------------------
# Original Particular word
# @user450
# Original Sentence Split
# ['rt', '@user501', ':', 'beach', 'party', 'with', '@user450', 'and', '@user1886', 'looks', 'fun', 'af', '☀️', '🌴', '#aimhvideo', 'url457', 'url1365']
# Original Start Index
# 6
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user501', ':', 'beach', 'party', 'with', '@user450', 'and', '@user1886', 'looks', 'fun', 'af', '☀️', '🌴', 'aimhvideo', 'url457', 'url1365']
# After processing joint sentence
# rt @user501 : beach party with @user450 and @user1886 looks fun af ☀️ 🌴 aimhvideo url457 url1365
# Pre processed word start index
# 6
# Pre processed char start index
# 31
# Pre processed split string
# rt @user501 : beach party with @user450 and @user1886 looks fun af ☀️ 🌴 aimhvideo url457 url1365
# Part of sentence before particular word
# ['rt', '@user501', ':', 'beach', 'party', 'with']
# Part of sentence before particular word string
# rt @user501 : beach party with
# Part of sentence before particular word string mushed
# rt@user501:beachpartywith
# FINAL: Pre Processed char start index mushed
# 25
# LEN OF WORD PHRASE AFTER MUSHED
# 8
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user501', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('beach', 'O', '', 'NOUN'), ('party', 'O', '', 'NOUN'), ('with', 'O', '', 'ADP'), ('@user450', 'O', '', 'X'), ('and', 'O', '', 'CCONJ'), ('@user1886', 'O', '', 'X'), ('looks', 'O', '', 'VERB'), ('fun', 'O', '', 'ADJ'), ('af', 'O', '', 'ADV'), ('☀', 'O', '', 'PUNCT'), ('️', 'O', '', 'AUX'), ('🌴', 'O', '', 'AUX'), ('aimhvideo', 'O', '', 'X'), ('url457', 'O', '', 'X'), ('url1365', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user450', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# @user1886
# Original Sentence Split
# ['rt', '@user501', ':', 'beach', 'party', 'with', '@user450', 'and', '@user1886', 'looks', 'fun', 'af', '☀️', '🌴', '#aimhvideo', 'url457', 'url1365']
# Original Start Index
# 8
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user501', ':', 'beach', 'party', 'with', '@user450', 'and', '@user1886', 'looks', 'fun', 'af', '☀️', '🌴', 'aimhvideo', 'url457', 'url1365']
# After processing joint sentence
# rt @user501 : beach party with @user450 and @user1886 looks fun af ☀️ 🌴 aimhvideo url457 url1365
# Pre processed word start index
# 8
# Pre processed char start index
# 44
# Pre processed split string
# rt @user501 : beach party with @user450 and @user1886 looks fun af ☀️ 🌴 aimhvideo url457 url1365
# Part of sentence before particular word
# ['rt', '@user501', ':', 'beach', 'party', 'with', '@user450', 'and']
# Part of sentence before particular word string
# rt @user501 : beach party with @user450 and
# Part of sentence before particular word string mushed
# rt@user501:beachpartywith@user450and
# FINAL: Pre Processed char start index mushed
# 36
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user501', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('beach', 'O', '', 'NOUN'), ('party', 'O', '', 'NOUN'), ('with', 'O', '', 'ADP'), ('@user450', 'O', '', 'X'), ('and', 'O', '', 'CCONJ'), ('@user1886', 'O', '', 'X'), ('looks', 'O', '', 'VERB'), ('fun', 'O', '', 'ADJ'), ('af', 'O', '', 'ADV'), ('☀', 'O', '', 'PUNCT'), ('️', 'O', '', 'AUX'), ('🌴', 'O', '', 'AUX'), ('aimhvideo', 'O', '', 'X'), ('url457', 'O', '', 'X'), ('url1365', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('@user1886', 'O', '', 'X')]
# []
# ['X']
# --------------------------------------------------
# Original Particular word
# ireland
# Original Sentence Split
# ['rt', '@user1391', ':', 'now', 'northern', 'ireland', 'and', 'polish', 'fans', 'are', 'fighting', 'in', 'nice', '!', 'url1472']
# Original Start Index
# 5
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['rt', '@user1391', ':', 'now', 'northern', 'ireland', 'and', 'polish', 'fans', 'are', 'fighting', 'in', 'nice', '!', 'url1472']
# After processing joint sentence
# rt @user1391 : now northern ireland and polish fans are fighting in nice ! url1472
# Pre processed word start index
# 5
# Pre processed char start index
# 28
# Pre processed split string
# rt @user1391 : now northern ireland and polish fans are fighting in nice ! url1472
# Part of sentence before particular word
# ['rt', '@user1391', ':', 'now', 'northern']
# Part of sentence before particular word string
# rt @user1391 : now northern
# Part of sentence before particular word string mushed
# rt@user1391:nownorthern
# FINAL: Pre Processed char start index mushed
# 23
# LEN OF WORD PHRASE AFTER MUSHED
# 7
# Word Entities result
# [('rt', 'O', '', 'PROPN'), ('@user1391', 'O', '', 'X'), (':', 'O', '', 'PUNCT'), ('now', 'O', '', 'ADV'), ('northern', 'O', '', 'PROPN'), ('ireland', 'O', '', 'PROPN'), ('and', 'O', '', 'CCONJ'), ('polish', 'O', '', 'ADJ'), ('fans', 'O', '', 'NOUN'), ('are', 'O', '', 'AUX'), ('fighting', 'O', '', 'VERB'), ('in', 'O', '', 'ADP'), ('nice', 'O', '', 'ADJ'), ('!', 'O', '', 'PUNCT'), ('url1472', 'O', '', 'X')]
# PRINTING NON COMBINED
# [('ireland', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user1311
# Original Sentence Split
# ['@user1311', 'if', 'i', 'had', 'one', 'of', 'these', 'i', 'would', 'go', 'back', 'to', '2008', 'and', 'never', 'connect', 'with', 'u', 'guys', 'url629']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1311', 'if', 'i', 'had', 'one', 'of', 'these', 'i', 'would', 'go', 'back', 'to', '2008', 'and', 'never', 'connect', 'with', 'u', 'guys', 'url629']
# After processing joint sentence
# @user1311 if i had one of these i would go back to 2008 and never connect with u guys url629
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user1311 if i had one of these i would go back to 2008 and never connect with u guys url629
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('@user1311', 'O', '', 'PROPN'), ('if', 'O', '', 'SCONJ'), ('i', 'O', '', 'PRON'), ('had', 'O', '', 'VERB'), ('one', 'O', '', 'NUM'), ('of', 'O', '', 'ADP'), ('these', 'O', '', 'PRON'), ('i', 'O', '', 'PRON'), ('would', 'O', '', 'AUX'), ('go', 'O', '', 'VERB'), ('back', 'O', '', 'ADV'), ('to', 'O', '', 'ADP'), ('2008', 'O', '', 'NUM'), ('and', 'O', '', 'CCONJ'), ('never', 'O', '', 'ADV'), ('connect', 'O', '', 'VERB'), ('with', 'O', '', 'ADP'), ('u', 'O', '', 'PRON'), ('guys', 'O', '', 'NOUN'), ('url629', 'O', '', 'PROPN')]
# PRINTING NON COMBINED
# [('@user1311', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# @user1132
# Original Sentence Split
# ['@user1132', 'gon', 'na', 'have', 'to', 'buy', 'a', 'rico', 'riders', 't', 'shirt', 'soon', '..']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1132', 'gon', 'na', 'have', 'to', 'buy', 'a', 'rico', 'riders', 't', 'shirt', 'soon', '..']
# After processing joint sentence
# @user1132 gon na have to buy a rico riders t shirt soon ..
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user1132 gon na have to buy a rico riders t shirt soon ..
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('@user1132', 'O', '', 'PROPN'), ('gon', 'O', '', 'AUX'), ('na', 'O', '', 'AUX'), ('have', 'O', '', 'VERB'), ('to', 'O', '', 'PART'), ('buy', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('rico', 'O', '', 'PROPN'), ('riders', 'O', '', 'PROPN'), ('t', 'O', '', 'NOUN'), ('shirt', 'O', '', 'NOUN'), ('soon', 'O', '', 'ADV'), ('..', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user1132', 'O', '', 'PROPN')]
# []
# ['PROPN']
# --------------------------------------------------
# Original Particular word
# t
# Original Sentence Split
# ['@user1132', 'gon', 'na', 'have', 'to', 'buy', 'a', 'rico', 'riders', 't', 'shirt', 'soon', '..']
# Original Start Index
# 9
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1132', 'gon', 'na', 'have', 'to', 'buy', 'a', 'rico', 'riders', 't', 'shirt', 'soon', '..']
# After processing joint sentence
# @user1132 gon na have to buy a rico riders t shirt soon ..
# Pre processed word start index
# 9
# Pre processed char start index
# 43
# Pre processed split string
# @user1132 gon na have to buy a rico riders t shirt soon ..
# Part of sentence before particular word
# ['@user1132', 'gon', 'na', 'have', 'to', 'buy', 'a', 'rico', 'riders']
# Part of sentence before particular word string
# @user1132 gon na have to buy a rico riders
# Part of sentence before particular word string mushed
# @user1132gonnahavetobuyaricoriders
# FINAL: Pre Processed char start index mushed
# 34
# LEN OF WORD PHRASE AFTER MUSHED
# 1
# Word Entities result
# [('@user1132', 'O', '', 'PROPN'), ('gon', 'O', '', 'AUX'), ('na', 'O', '', 'AUX'), ('have', 'O', '', 'VERB'), ('to', 'O', '', 'PART'), ('buy', 'O', '', 'VERB'), ('a', 'O', '', 'DET'), ('rico', 'O', '', 'PROPN'), ('riders', 'O', '', 'PROPN'), ('t', 'O', '', 'NOUN'), ('shirt', 'O', '', 'NOUN'), ('soon', 'O', '', 'ADV'), ('..', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('t', 'O', '', 'NOUN')]
# []
# ['NOUN']
# --------------------------------------------------
# Original Particular word
# @user1812
# Original Sentence Split
# ['@user1812', 'no', ',', 'i', "'m", 'not', '.', 'it', "'s", 'definitely', 'not', 'a', 'rapper', '.']
# Original Start Index
# 0
# FINDING ENTITY OF WORD
# FOR NON COMBINED WORDS
# After processing
# ['@user1812', 'no', ',', 'i', "'m", 'not', '.', 'it', "'s", 'definitely', 'not', 'a', 'rapper', '.']
# After processing joint sentence
# @user1812 no , i 'm not . it 's definitely not a rapper .
# Pre processed word start index
# 0
# Pre processed char start index
# 1
# Pre processed split string
# @user1812 no , i 'm not . it 's definitely not a rapper .
# Part of sentence before particular word
# []
# Part of sentence before particular word string
#
# Part of sentence before particular word string mushed
#
# FINAL: Pre Processed char start index mushed
# 0
# LEN OF WORD PHRASE AFTER MUSHED
# 9
# Word Entities result
# [('@user1812', 'O', '', 'PROPN'), ('no', 'O', '', 'INTJ'), (',', 'O', '', 'PUNCT'), ('i', 'O', '', 'PRON'), ("'", 'O', '', 'VERB'), ('m', 'O', '', 'VERB'), ('not', 'O', '', 'PART'), ('.', 'O', '', 'PUNCT'), ('it', 'O', '', 'PRON'), ("'s", 'O', '', 'AUX'), ('definitely', 'O', '', 'ADV'), ('not', 'O', '', 'PART'), ('a', 'O', '', 'DET'), ('rapper', 'O', '', 'NOUN'), ('.', 'O', '', 'PUNCT')]
# PRINTING NON COMBINED
# [('@user1812', 'O', '', 'PROPN')]
# []
# ['PROPN']

# %%
new_df = combined_df
new_df['Spacy NER Label'] = new_label_before_convert
new_df['Spacy POS Label'] = new_pos_before_convert

new_df['Final NER Label'] = new_label
new_df['Final POS Label'] = new_pos

new_df['Candidate Label'] = new_stand_out_tweet

new_df = new_df.reindex(columns = ['Word', 'Start Word Index', 'End Word Index', 'POS Label', 'Spacy POS Label', 'Final POS Label', 'NER Label', 'Spacy NER Label', 'Final NER Label', 'Tweet', 'Candidate Label'])
new_df
# Out:
#           Word  Start Word Index  End Word Index  POS Label Spacy POS Label  \
# 0     @user415                11              11  ['PROPN']             [X]
# 1    @user1136                11              11  ['PROPN']         [PROPN]
# 2          xb1                13              13  ['PROPN']          [NOUN]
# 3    @user1071                15              15  ['PROPN']          [NOUN]
# 4     @user718                18              18  ['PROPN']         [PROPN]
# ..         ...               ...             ...        ...             ...
# 702    ireland                 5               5  ['PROPN']         [PROPN]
# 703  @user1311                 0               0  ['PROPN']         [PROPN]
# 704  @user1132                 0               0  ['PROPN']         [PROPN]
# 705          t                 9               9  ['PROPN']          [NOUN]
# 706  @user1812                 0               0  ['PROPN']         [PROPN]
#
#     Final POS Label NER Label Spacy NER Label Final NER Label  \
# 0               [X]     ['O']              []         [B-PER]
# 1           [PROPN]     ['O']              []         [B-PER]
# 2            [NOUN]     ['O']              []           ['O']
# 3            [NOUN]     ['O']              []         [B-PER]
# 4           [PROPN]     ['O']              []         [B-PER]
# ..              ...       ...             ...             ...
# 702         [PROPN]     ['O']              []        [B-MISC]
# 703         [PROPN]     ['O']              []         [B-PER]
# 704         [PROPN]     ['O']              []         [B-PER]
# 705          [NOUN]     ['O']              []           ['O']
# 706         [PROPN]     ['O']              []         [B-PER]
#
#                                                  Tweet  \
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of @u...
# 2    i 've entered for a chance to win a copy of @u...
# 3    i 've entered for a chance to win a copy of @u...
# 4    i 've entered for a chance to win a copy of @u...
# ..                                                 ...
# 702  rt @user1391 : now northern ireland and polish...
# 703  @user1311 if i had one of these i would go bac...
# 704  @user1132 gon na have to buy a rico riders t s...
# 705  @user1132 gon na have to buy a rico riders t s...
# 706  @user1812 no , i 'm not . it 's definitely not...
#
#                                        Candidate Label
# 0    new unique backpack ! combines vintage with mo...
# 1    i 've entered for a chance to win a copy of <[...
# 2    i 've entered for a chance to win a copy of @u...
# 3    i 've entered for a chance to win a copy of @u...
# 4    i 've entered for a chance to win a copy of @u...
# ..                                                 ...
# 702  rt @user1391 : now northern <[ireland]> and po...
# 703  <[@user1311]> if i had one of these i would go...
# 704  <[@user1132]> gon na have to buy a rico riders...
# 705  @user1132 gon na have to buy a rico riders <[t...
# 706  <[@user1812]> no , i 'm not . it 's definitely...
#
# [707 rows x 11 columns]

# %%
new_df.to_csv('logs/TEST_relabelled_data_spacy_pass_entire_sentence_no_break_apart.tsv', sep='\t', index=False)
